# %%
import numpy as np


def poly_lr_scheduler(optimizer, init_lr, iter, lr_decay_iter=1,
                      max_iter=300, power=0.9):
    """Polynomial decay of learning rate
            :param init_lr is base learning rate
            :param iter is a current iteration
            :param lr_decay_iter how frequently decay occurs, default is 1
            :param max_iter is number of maximum iterations
            :param power is a polymomial power

    """
    # if iter % lr_decay_iter or iter > max_iter:
    # 	return optimizer

    lr = init_lr*(1 - iter/max_iter)**power
    optimizer.param_groups[0]['lr'] = lr
    return lr
    # return lr


def fast_hist(a, b, n):
    '''
    a and b are label and prediction respectively
    n is the number of classes
    '''
    k = (a >= 0) & (a < n)
    return np.bincount(n * a[k].astype(int) + b[k], minlength=n ** 2).reshape(n, n)


def per_class_iou(hist):
    epsilon = 1e-5
    return (np.diag(hist)) / (hist.sum(1) + hist.sum(0) - np.diag(hist) + epsilon)

# %%
import torch
from torchvision import models


class resnet18(torch.nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.features = models.resnet18(pretrained=pretrained)
        self.conv1 = self.features.conv1
        self.bn1 = self.features.bn1
        self.relu = self.features.relu
        self.maxpool1 = self.features.maxpool
        self.layer1 = self.features.layer1
        self.layer2 = self.features.layer2
        self.layer3 = self.features.layer3
        self.layer4 = self.features.layer4

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu(self.bn1(x))
        x = self.maxpool1(x)
        feature1 = self.layer1(x)  # 1 / 4
        feature2 = self.layer2(feature1)  # 1 / 8
        feature3 = self.layer3(feature2)  # 1 / 16
        feature4 = self.layer4(feature3)  # 1 / 32
        # global average pooling to build tail
        tail = torch.mean(feature4, 3, keepdim=True)
        tail = torch.mean(tail, 2, keepdim=True)
        return feature3, feature4, tail


class resnet101(torch.nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.features = models.resnet101(pretrained=pretrained)
        self.conv1 = self.features.conv1
        self.bn1 = self.features.bn1
        self.relu = self.features.relu
        self.maxpool1 = self.features.maxpool
        self.layer1 = self.features.layer1
        self.layer2 = self.features.layer2
        self.layer3 = self.features.layer3
        self.layer4 = self.features.layer4

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu(self.bn1(x))
        x = self.maxpool1(x)
        feature1 = self.layer1(x)  # 1 / 4
        feature2 = self.layer2(feature1)  # 1 / 8
        feature3 = self.layer3(feature2)  # 1 / 16
        feature4 = self.layer4(feature3)  # 1 / 32
        # global average pooling to build tail
        tail = torch.mean(feature4, 3, keepdim=True)
        tail = torch.mean(tail, 2, keepdim=True)
        return feature3, feature4, tail


def build_contextpath(name):
    model = {
        'resnet18': resnet18(pretrained=True),
        'resnet101': resnet101(pretrained=True)
    }
    return model[name]

# %%
import torch
from torch import nn
import warnings
warnings.filterwarnings(action='ignore')


class ConvBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size,
                               stride=stride, padding=padding, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, input):
        x = self.conv1(input)
        return self.relu(self.bn(x))


class Spatial_path(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.convblock1 = ConvBlock(in_channels=3, out_channels=64)
        self.convblock2 = ConvBlock(in_channels=64, out_channels=128)
        self.convblock3 = ConvBlock(in_channels=128, out_channels=256)

    def forward(self, input):
        x = self.convblock1(input)
        x = self.convblock2(x)
        x = self.convblock3(x)
        return x


class AttentionRefinementModule(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.sigmoid = nn.Sigmoid()
        self.in_channels = in_channels
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

    def forward(self, input):
        # global average pooling
        x = self.avgpool(input)
        assert self.in_channels == x.size(1), 'in_channels and out_channels should all be {}'.format(x.size(1))
        x = self.conv(x)
        x = self.sigmoid(self.bn(x))
        # x = self.sigmoid(x)
        # channels of input and x should be same
        x = torch.mul(input, x)
        return x


class FeatureFusionModule(torch.nn.Module):
    def __init__(self, num_classes, in_channels):
        super().__init__()
        # self.in_channels = input_1.channels + input_2.channels
        # resnet101 3328 = 256(from spatial path) + 1024(from context path) + 2048(from context path)
        # resnet18  1024 = 256(from spatial path) + 256(from context path) + 512(from context path)
        self.in_channels = in_channels

        self.convblock = ConvBlock(in_channels=self.in_channels, out_channels=num_classes, stride=1)
        self.conv1 = nn.Conv2d(num_classes, num_classes, kernel_size=1)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(num_classes, num_classes, kernel_size=1)
        self.sigmoid = nn.Sigmoid()
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

    def forward(self, input_1, input_2):
        x = torch.cat((input_1, input_2), dim=1)
        assert self.in_channels == x.size(1), 'in_channels of ConvBlock should be {}'.format(x.size(1))
        feature = self.convblock(x)
        x = self.avgpool(feature)

        x = self.relu(self.conv1(x))
        x = self.sigmoid(self.conv2(x))
        x = torch.mul(feature, x)
        x = torch.add(x, feature)
        return x


class BiSeNet(torch.nn.Module):
    def __init__(self, num_classes, context_path):
        super().__init__()
        # build spatial path
        self.saptial_path = Spatial_path()

        # build context path
        self.context_path = build_contextpath(name=context_path)

        # build attention refinement module  for resnet 101
        if context_path == 'resnet101':
            self.attention_refinement_module1 = AttentionRefinementModule(1024, 1024)
            self.attention_refinement_module2 = AttentionRefinementModule(2048, 2048)
            # supervision block
            self.supervision1 = nn.Conv2d(in_channels=1024, out_channels=num_classes, kernel_size=1)
            self.supervision2 = nn.Conv2d(in_channels=2048, out_channels=num_classes, kernel_size=1)
            # build feature fusion module
            self.feature_fusion_module = FeatureFusionModule(num_classes, 3328)

        elif context_path == 'resnet18':
            # build attention refinement module  for resnet 18
            self.attention_refinement_module1 = AttentionRefinementModule(256, 256)
            self.attention_refinement_module2 = AttentionRefinementModule(512, 512)
            # supervision block
            self.supervision1 = nn.Conv2d(in_channels=256, out_channels=num_classes, kernel_size=1)
            self.supervision2 = nn.Conv2d(in_channels=512, out_channels=num_classes, kernel_size=1)
            # build feature fusion module
            self.feature_fusion_module = FeatureFusionModule(num_classes, 1024)
        else:
            print('Error: unspport context_path network \n')

        # build final convolution
        self.conv = nn.Conv2d(in_channels=num_classes, out_channels=num_classes, kernel_size=1)

        self.init_weight()

        self.mul_lr = []
        self.mul_lr.append(self.saptial_path)
        self.mul_lr.append(self.attention_refinement_module1)
        self.mul_lr.append(self.attention_refinement_module2)
        self.mul_lr.append(self.supervision1)
        self.mul_lr.append(self.supervision2)
        self.mul_lr.append(self.feature_fusion_module)
        self.mul_lr.append(self.conv)

    def init_weight(self):
        for name, m in self.named_modules():
            if 'context_path' not in name:
                if isinstance(m, nn.Conv2d):
                    nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                elif isinstance(m, nn.BatchNorm2d):
                    m.eps = 1e-5
                    m.momentum = 0.1
                    nn.init.constant_(m.weight, 1)
                    nn.init.constant_(m.bias, 0)

    def forward(self, input):
        # output of spatial path
        sx = self.saptial_path(input)

        # output of context path
        cx1, cx2, tail = self.context_path(input)
        cx1 = self.attention_refinement_module1(cx1)
        cx2 = self.attention_refinement_module2(cx2)
        cx2 = torch.mul(cx2, tail)
        # upsampling
        cx1 = torch.nn.functional.interpolate(cx1, size=sx.size()[-2:], mode='bilinear')
        cx2 = torch.nn.functional.interpolate(cx2, size=sx.size()[-2:], mode='bilinear')
        cx = torch.cat((cx1, cx2), dim=1)

        if self.training == True:
            cx1_sup = self.supervision1(cx1)
            cx2_sup = self.supervision2(cx2)
            cx1_sup = torch.nn.functional.interpolate(cx1_sup, size=input.size()[-2:], mode='bilinear')
            cx2_sup = torch.nn.functional.interpolate(cx2_sup, size=input.size()[-2:], mode='bilinear')

        # output of feature fusion module
        result = self.feature_fusion_module(sx, cx)

        # upsampling
        result = torch.nn.functional.interpolate(result, scale_factor=8, mode='bilinear')
        result = self.conv(result)

        if self.training == True:
            return result, cx1_sup, cx2_sup

        return result

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from typing import Tuple


class CityScapes(Dataset):
    def __init__(self, root_dir, split='train', transform=None, target_transform=None):
        super(CityScapes, self).__init__()
        self.root_dir = root_dir
        self.split = split
        self.transform = transform
        self.target_transform = target_transform

        self.images_dir = os.path.join(root_dir, 'leftImg8bit', split)
        self.labels_dir = os.path.join(root_dir, 'gtFine', split)

        self.images = []
        self.labels = []

        for city in os.listdir(self.images_dir):
            img_dir = os.path.join(self.images_dir, city)
            lbl_dir = os.path.join(self.labels_dir, city)

            for file_name in os.listdir(img_dir):
                if file_name.endswith('_leftImg8bit.png'):
                    img_path = os.path.join(img_dir, file_name)
                    lbl_path = os.path.join(lbl_dir, file_name.replace('_leftImg8bit.png', '_gtFine_labelTrainIds.png'))

                    if not os.path.exists(img_path):
                        print(f"Image file does not exist: {img_path}")
                    if not os.path.exists(lbl_path):
                        print(f"Label file does not exist: {lbl_path}")

                    self.images.append(img_path)
                    self.labels.append(lbl_path)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        lbl_path = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        label = Image.open(lbl_path)

        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)

        return image, label

    def get_class_names(self):
        return ['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light', 'traffic sign',
                'vegetation', 'terrain', 'sky', 'person', 'rider', 'car', 'truck', 'bus', 'train',
                'motorcycle', 'bicycle']

# %%
import os
from PIL import Image, UnidentifiedImageError
import torch
from torch.utils.data import Dataset
import numpy as np
from torchvision import transforms

class GTA5(Dataset):
    def __init__(self, root_dir, transform=None, target_transform=None):
        super(GTA5, self).__init__()
        self.root_dir = root_dir
        self.transform = transform
        self.target_transform = target_transform

        self.images_dir = os.path.join(self.root_dir, 'images')
        self.labels_dir = os.path.join(self.root_dir, 'labels')

        self.images = []
        self.labels = []

        for image in os.listdir(self.images_dir):
            image_path = os.path.join(self.images_dir, image)
            label_path = os.path.join(self.labels_dir, image)
            if os.path.exists(label_path):
                self.images.append(image_path)
                self.labels.append(label_path)

        # Map from color to corresponding class of Cityscapes
        self.color_to_id = {
            (128, 64, 128): 0,   # road
            (244, 35, 232): 1,   # sidewalk
            (70, 70, 70): 2,     # building
            (102, 102, 156): 3,  # wall
            (190, 153, 153): 4,  # fence
            (153, 153, 153): 5,  # pole
            (250, 170, 30): 6,   # light
            (220, 220, 0): 7,    # sign
            (107, 142, 35): 8,   # vegetation
            (152, 251, 152): 9,  # terrain
            (70, 130, 180): 10,  # sky
            (220, 20, 60): 11,   # person
            (255, 0, 0): 12,     # rider
            (0, 0, 142): 13,     # car
            (0, 0, 70): 14,      # truck
            (0, 60, 100): 15,    # bus
            (0, 80, 100): 16,    # train
            (0, 0, 230): 17,     # motorcycle
            (119, 11, 32): 18    # bicycle
        }

    def __getitem__(self, idx):
        try:
            image = Image.open(self.images[idx]).convert('RGB')
            label = Image.open(self.labels[idx]).convert('RGB')
        except (UnidentifiedImageError, FileNotFoundError) as e:
            print(f"Error loading image {self.images[idx]} or label {self.labels[idx]}, skipping...")
            return self.__getitem__((idx + 1) % len(self.images))

        if self.transform is not None:
            image = self.transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)
            label = self.map_color_to_class(label)

        return image, label

    def __len__(self):
        return len(self.images)

    def map_color_to_class(self, label):
        # Convert the RGB image to a single integer value
        label_int = label[:, :, 0] * 256 * 256 + label[:, :, 1] * 256 + label[:, :, 2]

        # Create a tensor of the same shape as the input image, filled with 255 (the class for 'unlabeled')
        class_id_image = torch.full_like(label_int, 255)

        # Replace each unique color value with the corresponding class
        for color, class_id in self.color_to_id.items():
            color_int = color[0] * 256 * 256 + color[1] * 256 + color[2]
            class_id_image = torch.where(label_int == color_int, class_id, class_id_image)

        return class_id_image

# %%
from torchvision import transforms
import random

resize_transform = transforms.Resize((720, 1280))

# Augmentation Set 1
augmentations_1 = transforms.Compose([
    resize_transform,
    transforms.RandomApply([transforms.GaussianBlur(kernel_size=5)], p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Augmentation Set 2
augmentations_2 = transforms.Compose([
    resize_transform,
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Combined Augmentations (Aug. 1 + Aug. 2)
class CombinedTransform:
    def __init__(self, transform_1, transform_2):
        self.transform_1 = transform_1
        self.transform_2 = transform_2

    def __call__(self, img):
        if random.random() < 0.5:
            img = self.transform_1(img)
        else:
            img = self.transform_2(img)
        return img

combined_augmentations = CombinedTransform(augmentations_1, augmentations_2)


gta5_target_transform = transforms.Compose([
    transforms.Resize((720, 1280), interpolation=Image.NEAREST),
    transforms.Lambda(lambda lbl: torch.tensor(np.array(lbl), dtype=torch.long)),
])

cityscapes_transform = transforms.Compose([
    transforms.Resize((512,1024)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

cityscapes_target_transform = transforms.Compose([
    transforms.Resize((512,1024), interpolation=Image.NEAREST),
    transforms.Lambda(lambda lbl: torch.tensor(np.array(lbl), dtype=torch.long)),
])

# %%
from torchvision import transforms
from torch.utils.data import DataLoader

gta5_root = '/content/drive/MyDrive/MLDLMLDL/GTA5'

# Dataset and DataLoader with Aug. 1
gta5_dataset_1 = GTA5(gta5_root, transform=augmentations_1, target_transform=gta5_target_transform)
gta5_loader_1 = DataLoader(gta5_dataset_1, batch_size=8, shuffle=True, num_workers=12)

# Dataset and DataLoader with Aug. 2
gta5_dataset_2 = GTA5(gta5_root, transform=augmentations_2, target_transform=gta5_target_transform)
gta5_loader_2 = DataLoader(gta5_dataset_2, batch_size=8, shuffle=True, num_workers=12)

# Dataset and DataLoader with combined Aug. 1 + Aug. 2
gta5_dataset_combined = GTA5(gta5_root, transform=combined_augmentations, target_transform=gta5_target_transform)
gta5_loader_combined = DataLoader(gta5_dataset_combined, batch_size=8, shuffle=True, num_workers=12)

cityscapes_root = '/content/drive/MyDrive/MLDLMLDL/Cityscapes/Cityscapes/Cityspaces'
cityscapes_dataset = CityScapes(root_dir=cityscapes_root, split='val', transform=cityscapes_transform, target_transform=cityscapes_target_transform)
cityscapes_loader = DataLoader(cityscapes_dataset, batch_size=8, shuffle=False, num_workers=12)

# %%
print(len(gta5_dataset_1))
print(len(gta5_dataset_2))
print(len(gta5_dataset_combined))
print(len(cityscapes_dataset))
# Out:
# 2500
# 2500
# 2500
# 500

# %%
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BiSeNet(num_classes=19, context_path='resnet18').to(device)

# Hyperparameters
num_epochs = 50
learning_rate = 2e-2
batch_size = 4
num_classes = 19
# Loss and Optimizer
criterion = nn.CrossEntropyLoss(ignore_index=255)
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

class_names = cityscapes_dataset.get_class_names()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 191MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [00:00<00:00, 223MB/s]

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np

# Initialize variables to store training losses, validation losses, training mIoUs, and validation mIoUs for each augmentation set
train_losses_all = {'Aug. 1': [], 'Aug. 2': [], 'Aug. 1 + Aug. 2': []}
val_losses_all = {'Aug. 1': [], 'Aug. 2': [], 'Aug. 1 + Aug. 2': []}
train_mIoUs_all = {'Aug. 1': [], 'Aug. 2': [], 'Aug. 1 + Aug. 2': []}
val_mIoUs_all = {'Aug. 1': [], 'Aug. 2': [], 'Aug. 1 + Aug. 2': []}

# Loop through the different augmentation sets
for gta5_loader, aug_type in zip([gta5_loader_1, gta5_loader_2, gta5_loader_combined], ['Aug. 1', 'Aug. 2', 'Aug. 1 + Aug. 2']):
    best_mIoU = 0.0
    train_losses = []
    val_losses = []
    train_mIoUs = []
    val_mIoUs = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        hist_train = np.zeros((num_classes, num_classes))
        for iter, (images, labels) in enumerate(gta5_loader):
            images = images.to(device)
            labels = labels.to(device).long()

            # Forward pass
            optimizer.zero_grad()
            outputs, _, _ = model(images)
            loss = criterion(outputs, labels)

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            # Update learning rate
            current_iter = epoch * len(gta5_loader) + iter
            poly_lr_scheduler(optimizer, learning_rate, current_iter, max_iter=num_epochs * len(gta5_loader))

            running_loss += loss.item()

            # Calculate training mIoU
            preds_train = torch.argmax(outputs, dim=1)
            hist_train += fast_hist(labels.cpu().numpy().flatten(), preds_train.cpu().numpy().flatten(), num_classes)

            if (iter + 1) % 10 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{iter+1}/{len(gta5_loader)}], Loss: {loss.item():.4f}')

        avg_train_loss = running_loss / len(gta5_loader)
        train_losses.append(avg_train_loss)
        train_mIoUs_epoch = per_class_iou(hist_train)
        avg_train_mIoU = np.mean(train_mIoUs_epoch)
        train_mIoUs.append(avg_train_mIoU)
        print(f'Epoch [{epoch+1}/{num_epochs}], {aug_type} Training Loss: {avg_train_loss:.4f}, Train Mean mIoU: {avg_train_mIoU:.4f}')

        # Validation
        model.eval()
        hist_val = np.zeros((num_classes, num_classes))
        running_val_loss = 0.0
        with torch.no_grad():
            for images, labels in cityscapes_loader:
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass
                outputs = model(images)
                preds_val = torch.argmax(outputs, dim=1)
                val_loss = criterion(outputs, labels)
                running_val_loss += val_loss.item()

                hist_val += fast_hist(labels.cpu().numpy().flatten(), preds_val.cpu().numpy().flatten(), num_classes)

        avg_val_loss = running_val_loss / len(cityscapes_loader)
        val_losses.append(avg_val_loss)
        val_mIoUs_epoch = per_class_iou(hist_val)
        avg_val_mIoU = np.mean(val_mIoUs_epoch)
        val_mIoUs.append(avg_val_mIoU)
        print(f'Epoch [{epoch+1}/{num_epochs}], {aug_type} Validation Loss: {avg_val_loss:.4f}, Val Mean mIoU: {avg_val_mIoU:.4f}')
        for i, iou in enumerate(val_mIoUs_epoch):
            print(f'{class_names[i]}: Val mIoU = {iou:.4f}')

        # Save the model if it has the best mIoU so far
        if avg_val_mIoU > best_mIoU:
            best_mIoU = avg_val_mIoU
            torch.save(model.state_dict(), f'/content/drive/MyDrive/MLDLMLDL/best_model_{aug_type.replace(" ", "_")}.pth')
            print(f'Model saved with Mean mIoU: {avg_val_mIoU:.4f}')

        # Clear cache to free up memory
        torch.cuda.empty_cache()

    # Store the results for plotting
    train_losses_all[aug_type] = train_losses
    val_losses_all[aug_type] = val_losses
    train_mIoUs_all[aug_type] = train_mIoUs
    val_mIoUs_all[aug_type] = val_mIoUs

#
# Out:
# Streaming output truncated to the last 5000 lines.
# traffic light: Val mIoU = 0.0608
# traffic sign: Val mIoU = 0.0282
# vegetation: Val mIoU = 0.6626
# terrain: Val mIoU = 0.0243
# sky: Val mIoU = 0.6040
# person: Val mIoU = 0.3044
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.5944
# truck: Val mIoU = 0.0509
# bus: Val mIoU = 0.0076
# train: Val mIoU = 0.0610
# motorcycle: Val mIoU = 0.0408
# bicycle: Val mIoU = 0.0000
# Epoch [7/50], Step [10/313], Loss: 0.3491
# Epoch [7/50], Step [20/313], Loss: 0.4170
# Epoch [7/50], Step [30/313], Loss: 0.5008
# Epoch [7/50], Step [40/313], Loss: 0.3333
# Epoch [7/50], Step [50/313], Loss: 0.5314
# Epoch [7/50], Step [60/313], Loss: 0.3195
# Epoch [7/50], Step [70/313], Loss: 0.3004
# Epoch [7/50], Step [80/313], Loss: 0.3059
# Epoch [7/50], Step [90/313], Loss: 0.2516
# Epoch [7/50], Step [100/313], Loss: 0.3835
# Epoch [7/50], Step [110/313], Loss: 0.4788
# Epoch [7/50], Step [120/313], Loss: 0.4709
# Epoch [7/50], Step [130/313], Loss: 0.3322
# Epoch [7/50], Step [140/313], Loss: 0.3042
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [7/50], Step [150/313], Loss: 0.5125
# Epoch [7/50], Step [160/313], Loss: 0.3802
# Epoch [7/50], Step [170/313], Loss: 0.3956
# Epoch [7/50], Step [180/313], Loss: 0.3157
# Epoch [7/50], Step [190/313], Loss: 0.4871
# Epoch [7/50], Step [200/313], Loss: 0.3411
# Epoch [7/50], Step [210/313], Loss: 0.4402
# Epoch [7/50], Step [220/313], Loss: 0.2767
# Epoch [7/50], Step [230/313], Loss: 0.2471
# Epoch [7/50], Step [240/313], Loss: 0.5469
# Epoch [7/50], Step [250/313], Loss: 0.4056
# Epoch [7/50], Step [260/313], Loss: 0.2301
# Epoch [7/50], Step [270/313], Loss: 0.4108
# Epoch [7/50], Step [280/313], Loss: 0.4856
# Epoch [7/50], Step [290/313], Loss: 0.5269
# Epoch [7/50], Step [300/313], Loss: 0.4450
# Epoch [7/50], Step [310/313], Loss: 0.3097
# Epoch [7/50], Aug. 2 Training Loss: 0.4178, Train Mean mIoU: 0.4428
# Epoch [7/50], Aug. 2 Validation Loss: 2.0442, Val Mean mIoU: 0.1777
# road: Val mIoU = 0.2315
# sidewalk: Val mIoU = 0.0108
# building: Val mIoU = 0.6314
# wall: Val mIoU = 0.0412
# fence: Val mIoU = 0.1426
# pole: Val mIoU = 0.1103
# traffic light: Val mIoU = 0.0568
# traffic sign: Val mIoU = 0.0449
# vegetation: Val mIoU = 0.6151
# terrain: Val mIoU = 0.0213
# sky: Val mIoU = 0.4971
# person: Val mIoU = 0.2532
# rider: Val mIoU = 0.0088
# car: Val mIoU = 0.4997
# truck: Val mIoU = 0.0405
# bus: Val mIoU = 0.0002
# train: Val mIoU = 0.1246
# motorcycle: Val mIoU = 0.0466
# bicycle: Val mIoU = 0.0000
# Epoch [8/50], Step [10/313], Loss: 0.7988
# Epoch [8/50], Step [20/313], Loss: 0.5446
# Epoch [8/50], Step [30/313], Loss: 0.4120
# Epoch [8/50], Step [40/313], Loss: 0.3791
# Epoch [8/50], Step [50/313], Loss: 0.3687
# Epoch [8/50], Step [60/313], Loss: 0.4192
# Epoch [8/50], Step [70/313], Loss: 0.3612
# Epoch [8/50], Step [80/313], Loss: 0.3347
# Epoch [8/50], Step [90/313], Loss: 0.4369
# Epoch [8/50], Step [100/313], Loss: 0.3169
# Epoch [8/50], Step [110/313], Loss: 0.2904
# Epoch [8/50], Step [120/313], Loss: 0.5273
# Epoch [8/50], Step [130/313], Loss: 0.4145
# Epoch [8/50], Step [140/313], Loss: 0.3283
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [8/50], Step [150/313], Loss: 0.3392
# Epoch [8/50], Step [160/313], Loss: 0.3331
# Epoch [8/50], Step [170/313], Loss: 0.4017
# Epoch [8/50], Step [180/313], Loss: 0.3831
# Epoch [8/50], Step [190/313], Loss: 0.3221
# Epoch [8/50], Step [200/313], Loss: 0.3576
# Epoch [8/50], Step [210/313], Loss: 0.4360
# Epoch [8/50], Step [220/313], Loss: 0.4104
# Epoch [8/50], Step [230/313], Loss: 0.5228
# Epoch [8/50], Step [240/313], Loss: 0.2659
# Epoch [8/50], Step [250/313], Loss: 0.3349
# Epoch [8/50], Step [260/313], Loss: 0.5611
# Epoch [8/50], Step [270/313], Loss: 0.4687
# Epoch [8/50], Step [280/313], Loss: 0.3617
# Epoch [8/50], Step [290/313], Loss: 0.6346
# Epoch [8/50], Step [300/313], Loss: 0.5417
# Epoch [8/50], Step [310/313], Loss: 0.3934
# Epoch [8/50], Aug. 2 Training Loss: 0.4062, Train Mean mIoU: 0.4550
# Epoch [8/50], Aug. 2 Validation Loss: 1.1214, Val Mean mIoU: 0.2006
# road: Val mIoU = 0.5435
# sidewalk: Val mIoU = 0.0287
# building: Val mIoU = 0.6057
# wall: Val mIoU = 0.0879
# fence: Val mIoU = 0.0569
# pole: Val mIoU = 0.1177
# traffic light: Val mIoU = 0.1239
# traffic sign: Val mIoU = 0.0340
# vegetation: Val mIoU = 0.6891
# terrain: Val mIoU = 0.0399
# sky: Val mIoU = 0.5403
# person: Val mIoU = 0.3019
# rider: Val mIoU = 0.0282
# car: Val mIoU = 0.4662
# truck: Val mIoU = 0.0821
# bus: Val mIoU = 0.0116
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0537
# bicycle: Val mIoU = 0.0000
# Epoch [9/50], Step [10/313], Loss: 0.5679
# Epoch [9/50], Step [20/313], Loss: 0.2946
# Epoch [9/50], Step [30/313], Loss: 0.4936
# Epoch [9/50], Step [40/313], Loss: 0.4705
# Epoch [9/50], Step [50/313], Loss: 0.4396
# Epoch [9/50], Step [60/313], Loss: 0.4051
# Epoch [9/50], Step [70/313], Loss: 0.3938
# Epoch [9/50], Step [80/313], Loss: 0.5631
# Epoch [9/50], Step [90/313], Loss: 0.4540
# Epoch [9/50], Step [100/313], Loss: 0.2733
# Epoch [9/50], Step [110/313], Loss: 0.4456
# Epoch [9/50], Step [120/313], Loss: 0.3501
# Epoch [9/50], Step [130/313], Loss: 0.4008
# Epoch [9/50], Step [140/313], Loss: 0.3150
# Epoch [9/50], Step [150/313], Loss: 0.3443
# Epoch [9/50], Step [160/313], Loss: 0.4644
# Epoch [9/50], Step [170/313], Loss: 0.2877
# Epoch [9/50], Step [180/313], Loss: 0.5053
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [9/50], Step [190/313], Loss: 0.3277
# Epoch [9/50], Step [200/313], Loss: 0.5015
# Epoch [9/50], Step [210/313], Loss: 0.2761
# Epoch [9/50], Step [220/313], Loss: 0.3648
# Epoch [9/50], Step [230/313], Loss: 0.3170
# Epoch [9/50], Step [240/313], Loss: 0.5401
# Epoch [9/50], Step [250/313], Loss: 0.3908
# Epoch [9/50], Step [260/313], Loss: 0.3144
# Epoch [9/50], Step [270/313], Loss: 0.4817
# Epoch [9/50], Step [280/313], Loss: 0.3136
# Epoch [9/50], Step [290/313], Loss: 0.2059
# Epoch [9/50], Step [300/313], Loss: 0.2669
# Epoch [9/50], Step [310/313], Loss: 0.4174
# Epoch [9/50], Aug. 2 Training Loss: 0.3947, Train Mean mIoU: 0.4554
# Epoch [9/50], Aug. 2 Validation Loss: 1.5177, Val Mean mIoU: 0.2021
# road: Val mIoU = 0.3557
# sidewalk: Val mIoU = 0.0803
# building: Val mIoU = 0.5707
# wall: Val mIoU = 0.0891
# fence: Val mIoU = 0.0800
# pole: Val mIoU = 0.1514
# traffic light: Val mIoU = 0.0633
# traffic sign: Val mIoU = 0.0263
# vegetation: Val mIoU = 0.7308
# terrain: Val mIoU = 0.0347
# sky: Val mIoU = 0.6433
# person: Val mIoU = 0.3711
# rider: Val mIoU = 0.0066
# car: Val mIoU = 0.5146
# truck: Val mIoU = 0.0555
# bus: Val mIoU = 0.0159
# train: Val mIoU = 0.0134
# motorcycle: Val mIoU = 0.0372
# bicycle: Val mIoU = 0.0000
# Epoch [10/50], Step [10/313], Loss: 0.2856
# Epoch [10/50], Step [20/313], Loss: 0.5512
# Epoch [10/50], Step [30/313], Loss: 0.3384
# Epoch [10/50], Step [40/313], Loss: 0.4625
# Epoch [10/50], Step [50/313], Loss: 0.4141
# Epoch [10/50], Step [60/313], Loss: 0.3817
# Epoch [10/50], Step [70/313], Loss: 0.3094
# Epoch [10/50], Step [80/313], Loss: 0.2660
# Epoch [10/50], Step [90/313], Loss: 0.3581
# Epoch [10/50], Step [100/313], Loss: 0.5054
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [10/50], Step [110/313], Loss: 0.3331
# Epoch [10/50], Step [120/313], Loss: 0.3744
# Epoch [10/50], Step [130/313], Loss: 0.3672
# Epoch [10/50], Step [140/313], Loss: 0.4510
# Epoch [10/50], Step [150/313], Loss: 0.4868
# Epoch [10/50], Step [160/313], Loss: 0.3724
# Epoch [10/50], Step [170/313], Loss: 0.5819
# Epoch [10/50], Step [180/313], Loss: 0.2858
# Epoch [10/50], Step [190/313], Loss: 0.4028
# Epoch [10/50], Step [200/313], Loss: 0.5495
# Epoch [10/50], Step [210/313], Loss: 0.4242
# Epoch [10/50], Step [220/313], Loss: 0.5125
# Epoch [10/50], Step [230/313], Loss: 0.2187
# Epoch [10/50], Step [240/313], Loss: 0.5205
# Epoch [10/50], Step [250/313], Loss: 0.4820
# Epoch [10/50], Step [260/313], Loss: 0.3697
# Epoch [10/50], Step [270/313], Loss: 0.3285
# Epoch [10/50], Step [280/313], Loss: 0.3947
# Epoch [10/50], Step [290/313], Loss: 0.4331
# Epoch [10/50], Step [300/313], Loss: 0.3004
# Epoch [10/50], Step [310/313], Loss: 0.5117
# Epoch [10/50], Aug. 2 Training Loss: 0.3832, Train Mean mIoU: 0.4635
# Epoch [10/50], Aug. 2 Validation Loss: 1.8031, Val Mean mIoU: 0.2004
# road: Val mIoU = 0.2560
# sidewalk: Val mIoU = 0.0934
# building: Val mIoU = 0.5947
# wall: Val mIoU = 0.0482
# fence: Val mIoU = 0.1484
# pole: Val mIoU = 0.1648
# traffic light: Val mIoU = 0.0517
# traffic sign: Val mIoU = 0.0795
# vegetation: Val mIoU = 0.6576
# terrain: Val mIoU = 0.0267
# sky: Val mIoU = 0.5567
# person: Val mIoU = 0.3517
# rider: Val mIoU = 0.0022
# car: Val mIoU = 0.5993
# truck: Val mIoU = 0.0839
# bus: Val mIoU = 0.0272
# train: Val mIoU = 0.0354
# motorcycle: Val mIoU = 0.0296
# bicycle: Val mIoU = 0.0000
# Epoch [11/50], Step [10/313], Loss: 0.2501
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [11/50], Step [20/313], Loss: 0.3636
# Epoch [11/50], Step [30/313], Loss: 0.4881
# Epoch [11/50], Step [40/313], Loss: 0.2948
# Epoch [11/50], Step [50/313], Loss: 0.4099
# Epoch [11/50], Step [60/313], Loss: 0.2372
# Epoch [11/50], Step [70/313], Loss: 0.2475
# Epoch [11/50], Step [80/313], Loss: 0.5226
# Epoch [11/50], Step [90/313], Loss: 0.2998
# Epoch [11/50], Step [100/313], Loss: 0.3324
# Epoch [11/50], Step [110/313], Loss: 0.3104
# Epoch [11/50], Step [120/313], Loss: 0.2041
# Epoch [11/50], Step [130/313], Loss: 0.3288
# Epoch [11/50], Step [140/313], Loss: 0.5285
# Epoch [11/50], Step [150/313], Loss: 0.3193
# Epoch [11/50], Step [160/313], Loss: 0.4928
# Epoch [11/50], Step [170/313], Loss: 0.2190
# Epoch [11/50], Step [180/313], Loss: 0.3972
# Epoch [11/50], Step [190/313], Loss: 0.4146
# Epoch [11/50], Step [200/313], Loss: 0.3412
# Epoch [11/50], Step [210/313], Loss: 0.4037
# Epoch [11/50], Step [220/313], Loss: 0.3847
# Epoch [11/50], Step [230/313], Loss: 0.4142
# Epoch [11/50], Step [240/313], Loss: 0.3827
# Epoch [11/50], Step [250/313], Loss: 0.3507
# Epoch [11/50], Step [260/313], Loss: 0.4345
# Epoch [11/50], Step [270/313], Loss: 0.4597
# Epoch [11/50], Step [280/313], Loss: 0.2407
# Epoch [11/50], Step [290/313], Loss: 0.2536
# Epoch [11/50], Step [300/313], Loss: 0.2585
# Epoch [11/50], Step [310/313], Loss: 0.4420
# Epoch [11/50], Aug. 2 Training Loss: 0.3702, Train Mean mIoU: 0.4769
# Epoch [11/50], Aug. 2 Validation Loss: 1.6777, Val Mean mIoU: 0.2135
# road: Val mIoU = 0.3048
# sidewalk: Val mIoU = 0.0387
# building: Val mIoU = 0.6830
# wall: Val mIoU = 0.0707
# fence: Val mIoU = 0.1363
# pole: Val mIoU = 0.1557
# traffic light: Val mIoU = 0.0871
# traffic sign: Val mIoU = 0.0738
# vegetation: Val mIoU = 0.7177
# terrain: Val mIoU = 0.0252
# sky: Val mIoU = 0.6146
# person: Val mIoU = 0.3589
# rider: Val mIoU = 0.0001
# car: Val mIoU = 0.6034
# truck: Val mIoU = 0.0471
# bus: Val mIoU = 0.0488
# train: Val mIoU = 0.0353
# motorcycle: Val mIoU = 0.0560
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.2135
# Epoch [12/50], Step [10/313], Loss: 0.3629
# Epoch [12/50], Step [20/313], Loss: 0.3457
# Epoch [12/50], Step [30/313], Loss: 0.2340
# Epoch [12/50], Step [40/313], Loss: 0.2431
# Epoch [12/50], Step [50/313], Loss: 0.3036
# Epoch [12/50], Step [60/313], Loss: 0.2879
# Epoch [12/50], Step [70/313], Loss: 0.5531
# Epoch [12/50], Step [80/313], Loss: 0.3512
# Epoch [12/50], Step [90/313], Loss: 0.3159
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [12/50], Step [100/313], Loss: 0.4448
# Epoch [12/50], Step [110/313], Loss: 0.3947
# Epoch [12/50], Step [120/313], Loss: 0.2828
# Epoch [12/50], Step [130/313], Loss: 0.3635
# Epoch [12/50], Step [140/313], Loss: 0.5818
# Epoch [12/50], Step [150/313], Loss: 0.4052
# Epoch [12/50], Step [160/313], Loss: 0.2551
# Epoch [12/50], Step [170/313], Loss: 0.3269
# Epoch [12/50], Step [180/313], Loss: 0.2874
# Epoch [12/50], Step [190/313], Loss: 0.3916
# Epoch [12/50], Step [200/313], Loss: 0.2710
# Epoch [12/50], Step [210/313], Loss: 0.3047
# Epoch [12/50], Step [220/313], Loss: 0.2869
# Epoch [12/50], Step [230/313], Loss: 0.3954
# Epoch [12/50], Step [240/313], Loss: 0.2818
# Epoch [12/50], Step [250/313], Loss: 0.2145
# Epoch [12/50], Step [260/313], Loss: 0.3300
# Epoch [12/50], Step [270/313], Loss: 0.2588
# Epoch [12/50], Step [280/313], Loss: 0.3110
# Epoch [12/50], Step [290/313], Loss: 0.3946
# Epoch [12/50], Step [300/313], Loss: 0.3735
# Epoch [12/50], Step [310/313], Loss: 0.4978
# Epoch [12/50], Aug. 2 Training Loss: 0.3545, Train Mean mIoU: 0.4943
# Epoch [12/50], Aug. 2 Validation Loss: 1.5671, Val Mean mIoU: 0.1707
# road: Val mIoU = 0.3650
# sidewalk: Val mIoU = 0.0989
# building: Val mIoU = 0.5041
# wall: Val mIoU = 0.0618
# fence: Val mIoU = 0.0742
# pole: Val mIoU = 0.1026
# traffic light: Val mIoU = 0.0678
# traffic sign: Val mIoU = 0.0280
# vegetation: Val mIoU = 0.5322
# terrain: Val mIoU = 0.0329
# sky: Val mIoU = 0.3818
# person: Val mIoU = 0.3420
# rider: Val mIoU = 0.0030
# car: Val mIoU = 0.5540
# truck: Val mIoU = 0.0601
# bus: Val mIoU = 0.0173
# train: Val mIoU = 0.0003
# motorcycle: Val mIoU = 0.0169
# bicycle: Val mIoU = 0.0000
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [13/50], Step [10/313], Loss: 0.5620
# Epoch [13/50], Step [20/313], Loss: 0.3854
# Epoch [13/50], Step [30/313], Loss: 0.4236
# Epoch [13/50], Step [40/313], Loss: 0.4018
# Epoch [13/50], Step [50/313], Loss: 0.3353
# Epoch [13/50], Step [60/313], Loss: 0.3277
# Epoch [13/50], Step [70/313], Loss: 0.2491
# Epoch [13/50], Step [80/313], Loss: 0.3720
# Epoch [13/50], Step [90/313], Loss: 0.2005
# Epoch [13/50], Step [100/313], Loss: 0.3224
# Epoch [13/50], Step [110/313], Loss: 0.1505
# Epoch [13/50], Step [120/313], Loss: 0.3251
# Epoch [13/50], Step [130/313], Loss: 0.3402
# Epoch [13/50], Step [140/313], Loss: 0.2174
# Epoch [13/50], Step [150/313], Loss: 0.2989
# Epoch [13/50], Step [160/313], Loss: 0.2448
# Epoch [13/50], Step [170/313], Loss: 0.2118
# Epoch [13/50], Step [180/313], Loss: 0.4068
# Epoch [13/50], Step [190/313], Loss: 0.3675
# Epoch [13/50], Step [200/313], Loss: 0.2129
# Epoch [13/50], Step [210/313], Loss: 0.3007
# Epoch [13/50], Step [220/313], Loss: 0.2777
# Epoch [13/50], Step [230/313], Loss: 0.2468
# Epoch [13/50], Step [240/313], Loss: 0.4700
# Epoch [13/50], Step [250/313], Loss: 0.3357
# Epoch [13/50], Step [260/313], Loss: 0.5109
# Epoch [13/50], Step [270/313], Loss: 0.4742
# Epoch [13/50], Step [280/313], Loss: 0.2043
# Epoch [13/50], Step [290/313], Loss: 0.5069
# Epoch [13/50], Step [300/313], Loss: 0.2874
# Epoch [13/50], Step [310/313], Loss: 0.4142
# Epoch [13/50], Aug. 2 Training Loss: 0.3592, Train Mean mIoU: 0.4891
# Epoch [13/50], Aug. 2 Validation Loss: 1.9654, Val Mean mIoU: 0.1882
# road: Val mIoU = 0.2465
# sidewalk: Val mIoU = 0.0613
# building: Val mIoU = 0.6651
# wall: Val mIoU = 0.0557
# fence: Val mIoU = 0.1245
# pole: Val mIoU = 0.1323
# traffic light: Val mIoU = 0.0886
# traffic sign: Val mIoU = 0.0487
# vegetation: Val mIoU = 0.5523
# terrain: Val mIoU = 0.0222
# sky: Val mIoU = 0.5724
# person: Val mIoU = 0.3585
# rider: Val mIoU = 0.0035
# car: Val mIoU = 0.5236
# truck: Val mIoU = 0.0629
# bus: Val mIoU = 0.0290
# train: Val mIoU = 0.0107
# motorcycle: Val mIoU = 0.0173
# bicycle: Val mIoU = 0.0000
# Epoch [14/50], Step [10/313], Loss: 0.3145
# Epoch [14/50], Step [20/313], Loss: 0.2960
# Epoch [14/50], Step [30/313], Loss: 0.3751
# Epoch [14/50], Step [40/313], Loss: 0.3987
# Epoch [14/50], Step [50/313], Loss: 0.3213
# Epoch [14/50], Step [60/313], Loss: 0.2714
# Epoch [14/50], Step [70/313], Loss: 0.3460
# Epoch [14/50], Step [80/313], Loss: 0.3062
# Epoch [14/50], Step [90/313], Loss: 0.3226
# Epoch [14/50], Step [100/313], Loss: 0.2507
# Epoch [14/50], Step [110/313], Loss: 0.2729
# Epoch [14/50], Step [120/313], Loss: 0.3614
# Epoch [14/50], Step [130/313], Loss: 0.3013
# Epoch [14/50], Step [140/313], Loss: 0.5013
# Epoch [14/50], Step [150/313], Loss: 0.2365
# Epoch [14/50], Step [160/313], Loss: 0.4546
# Epoch [14/50], Step [170/313], Loss: 0.3471
# Epoch [14/50], Step [180/313], Loss: 0.3658
# Epoch [14/50], Step [190/313], Loss: 0.2508
# Epoch [14/50], Step [200/313], Loss: 0.3742
# Epoch [14/50], Step [210/313], Loss: 0.4231
# Epoch [14/50], Step [220/313], Loss: 0.3406
# Epoch [14/50], Step [230/313], Loss: 0.3460
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [14/50], Step [240/313], Loss: 0.5045
# Epoch [14/50], Step [250/313], Loss: 0.3762
# Epoch [14/50], Step [260/313], Loss: 0.2773
# Epoch [14/50], Step [270/313], Loss: 0.3597
# Epoch [14/50], Step [280/313], Loss: 0.3017
# Epoch [14/50], Step [290/313], Loss: 0.3767
# Epoch [14/50], Step [300/313], Loss: 0.3313
# Epoch [14/50], Step [310/313], Loss: 0.2268
# Epoch [14/50], Aug. 2 Training Loss: 0.3337, Train Mean mIoU: 0.5178
# Epoch [14/50], Aug. 2 Validation Loss: 1.7040, Val Mean mIoU: 0.2189
# road: Val mIoU = 0.3157
# sidewalk: Val mIoU = 0.0749
# building: Val mIoU = 0.6972
# wall: Val mIoU = 0.0696
# fence: Val mIoU = 0.1688
# pole: Val mIoU = 0.1592
# traffic light: Val mIoU = 0.0804
# traffic sign: Val mIoU = 0.1154
# vegetation: Val mIoU = 0.7024
# terrain: Val mIoU = 0.0256
# sky: Val mIoU = 0.6594
# person: Val mIoU = 0.3693
# rider: Val mIoU = 0.0077
# car: Val mIoU = 0.5535
# truck: Val mIoU = 0.0577
# bus: Val mIoU = 0.0115
# train: Val mIoU = 0.0259
# motorcycle: Val mIoU = 0.0639
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.2189
# Epoch [15/50], Step [10/313], Loss: 0.4074
# Epoch [15/50], Step [20/313], Loss: 0.3666
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [15/50], Step [30/313], Loss: 0.3944
# Epoch [15/50], Step [40/313], Loss: 0.2093
# Epoch [15/50], Step [50/313], Loss: 0.2805
# Epoch [15/50], Step [60/313], Loss: 0.3392
# Epoch [15/50], Step [70/313], Loss: 0.2897
# Epoch [15/50], Step [80/313], Loss: 0.3977
# Epoch [15/50], Step [90/313], Loss: 0.2749
# Epoch [15/50], Step [100/313], Loss: 0.2943
# Epoch [15/50], Step [110/313], Loss: 0.3062
# Epoch [15/50], Step [120/313], Loss: 0.3275
# Epoch [15/50], Step [130/313], Loss: 0.3864
# Epoch [15/50], Step [140/313], Loss: 0.3530
# Epoch [15/50], Step [150/313], Loss: 0.2151
# Epoch [15/50], Step [160/313], Loss: 0.3282
# Epoch [15/50], Step [170/313], Loss: 0.2493
# Epoch [15/50], Step [180/313], Loss: 0.3099
# Epoch [15/50], Step [190/313], Loss: 0.3703
# Epoch [15/50], Step [200/313], Loss: 0.3497
# Epoch [15/50], Step [210/313], Loss: 0.3414
# Epoch [15/50], Step [220/313], Loss: 0.2889
# Epoch [15/50], Step [230/313], Loss: 0.2605
# Epoch [15/50], Step [240/313], Loss: 0.3676
# Epoch [15/50], Step [250/313], Loss: 0.3556
# Epoch [15/50], Step [260/313], Loss: 0.3888
# Epoch [15/50], Step [270/313], Loss: 0.3174
# Epoch [15/50], Step [280/313], Loss: 0.1939
# Epoch [15/50], Step [290/313], Loss: 0.2751
# Epoch [15/50], Step [300/313], Loss: 0.4471
# Epoch [15/50], Step [310/313], Loss: 0.2227
# Epoch [15/50], Aug. 2 Training Loss: 0.3300, Train Mean mIoU: 0.5156
# Epoch [15/50], Aug. 2 Validation Loss: 2.4256, Val Mean mIoU: 0.1848
# road: Val mIoU = 0.2333
# sidewalk: Val mIoU = 0.0350
# building: Val mIoU = 0.6628
# wall: Val mIoU = 0.0139
# fence: Val mIoU = 0.0310
# pole: Val mIoU = 0.0784
# traffic light: Val mIoU = 0.0875
# traffic sign: Val mIoU = 0.0861
# vegetation: Val mIoU = 0.6294
# terrain: Val mIoU = 0.0214
# sky: Val mIoU = 0.5471
# person: Val mIoU = 0.2928
# rider: Val mIoU = 0.0026
# car: Val mIoU = 0.6016
# truck: Val mIoU = 0.0915
# bus: Val mIoU = 0.0294
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0666
# bicycle: Val mIoU = 0.0000
# Epoch [16/50], Step [10/313], Loss: 0.3486
# Epoch [16/50], Step [20/313], Loss: 0.2836
# Epoch [16/50], Step [30/313], Loss: 0.4777
# Epoch [16/50], Step [40/313], Loss: 0.3050
# Epoch [16/50], Step [50/313], Loss: 0.3067
# Epoch [16/50], Step [60/313], Loss: 0.2762
# Epoch [16/50], Step [70/313], Loss: 0.1894
# Epoch [16/50], Step [80/313], Loss: 0.2802
# Epoch [16/50], Step [90/313], Loss: 0.4875
# Epoch [16/50], Step [100/313], Loss: 0.2664
# Epoch [16/50], Step [110/313], Loss: 0.1595
# Epoch [16/50], Step [120/313], Loss: 0.2991
# Epoch [16/50], Step [130/313], Loss: 0.2528
# Epoch [16/50], Step [140/313], Loss: 0.4083
# Epoch [16/50], Step [150/313], Loss: 0.2907
# Epoch [16/50], Step [160/313], Loss: 0.3651
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [16/50], Step [170/313], Loss: 0.3133
# Epoch [16/50], Step [180/313], Loss: 0.3274
# Epoch [16/50], Step [190/313], Loss: 0.2924
# Epoch [16/50], Step [200/313], Loss: 0.3533
# Epoch [16/50], Step [210/313], Loss: 0.2267
# Epoch [16/50], Step [220/313], Loss: 0.1855
# Epoch [16/50], Step [230/313], Loss: 0.1581
# Epoch [16/50], Step [240/313], Loss: 0.2972
# Epoch [16/50], Step [250/313], Loss: 0.3485
# Epoch [16/50], Step [260/313], Loss: 0.2200
# Epoch [16/50], Step [270/313], Loss: 0.3629
# Epoch [16/50], Step [280/313], Loss: 0.3001
# Epoch [16/50], Step [290/313], Loss: 0.2282
# Epoch [16/50], Step [300/313], Loss: 0.3558
# Epoch [16/50], Step [310/313], Loss: 0.5099
# Epoch [16/50], Aug. 2 Training Loss: 0.3229, Train Mean mIoU: 0.5232
# Epoch [16/50], Aug. 2 Validation Loss: 1.5965, Val Mean mIoU: 0.1941
# road: Val mIoU = 0.4124
# sidewalk: Val mIoU = 0.0159
# building: Val mIoU = 0.6018
# wall: Val mIoU = 0.0291
# fence: Val mIoU = 0.0636
# pole: Val mIoU = 0.0967
# traffic light: Val mIoU = 0.0388
# traffic sign: Val mIoU = 0.0556
# vegetation: Val mIoU = 0.6784
# terrain: Val mIoU = 0.0271
# sky: Val mIoU = 0.5721
# person: Val mIoU = 0.3332
# rider: Val mIoU = 0.0158
# car: Val mIoU = 0.5715
# truck: Val mIoU = 0.1019
# bus: Val mIoU = 0.0239
# train: Val mIoU = 0.0004
# motorcycle: Val mIoU = 0.0491
# bicycle: Val mIoU = 0.0000
# Epoch [17/50], Step [10/313], Loss: 0.3363
# Epoch [17/50], Step [20/313], Loss: 0.2701
# Epoch [17/50], Step [30/313], Loss: 0.3293
# Epoch [17/50], Step [40/313], Loss: 0.3134
# Epoch [17/50], Step [50/313], Loss: 0.3889
# Epoch [17/50], Step [60/313], Loss: 0.2107
# Epoch [17/50], Step [70/313], Loss: 0.2859
# Epoch [17/50], Step [80/313], Loss: 0.2559
# Epoch [17/50], Step [90/313], Loss: 0.3123
# Epoch [17/50], Step [100/313], Loss: 0.4850
# Epoch [17/50], Step [110/313], Loss: 0.3152
# Epoch [17/50], Step [120/313], Loss: 0.2933
# Epoch [17/50], Step [130/313], Loss: 0.3530
# Epoch [17/50], Step [140/313], Loss: 0.2673
# Epoch [17/50], Step [150/313], Loss: 0.2814
# Epoch [17/50], Step [160/313], Loss: 0.3202
# Epoch [17/50], Step [170/313], Loss: 0.3789
# Epoch [17/50], Step [180/313], Loss: 0.3380
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [17/50], Step [190/313], Loss: 0.1997
# Epoch [17/50], Step [200/313], Loss: 0.2570
# Epoch [17/50], Step [210/313], Loss: 0.3929
# Epoch [17/50], Step [220/313], Loss: 0.3841
# Epoch [17/50], Step [230/313], Loss: 0.2950
# Epoch [17/50], Step [240/313], Loss: 0.2006
# Epoch [17/50], Step [250/313], Loss: 0.2267
# Epoch [17/50], Step [260/313], Loss: 0.2597
# Epoch [17/50], Step [270/313], Loss: 0.2602
# Epoch [17/50], Step [280/313], Loss: 0.3957
# Epoch [17/50], Step [290/313], Loss: 0.3828
# Epoch [17/50], Step [300/313], Loss: 0.2705
# Epoch [17/50], Step [310/313], Loss: 0.3344
# Epoch [17/50], Aug. 2 Training Loss: 0.3112, Train Mean mIoU: 0.5317
# Epoch [17/50], Aug. 2 Validation Loss: 1.8362, Val Mean mIoU: 0.1874
# road: Val mIoU = 0.3263
# sidewalk: Val mIoU = 0.0584
# building: Val mIoU = 0.6617
# wall: Val mIoU = 0.0412
# fence: Val mIoU = 0.0255
# pole: Val mIoU = 0.1302
# traffic light: Val mIoU = 0.0805
# traffic sign: Val mIoU = 0.0587
# vegetation: Val mIoU = 0.6330
# terrain: Val mIoU = 0.0238
# sky: Val mIoU = 0.5327
# person: Val mIoU = 0.3575
# rider: Val mIoU = 0.0104
# car: Val mIoU = 0.4891
# truck: Val mIoU = 0.0803
# bus: Val mIoU = 0.0138
# train: Val mIoU = 0.0007
# motorcycle: Val mIoU = 0.0368
# bicycle: Val mIoU = 0.0000
# Epoch [18/50], Step [10/313], Loss: 0.2559
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [18/50], Step [20/313], Loss: 0.2616
# Epoch [18/50], Step [30/313], Loss: 0.2265
# Epoch [18/50], Step [40/313], Loss: 0.2833
# Epoch [18/50], Step [50/313], Loss: 0.2898
# Epoch [18/50], Step [60/313], Loss: 0.2505
# Epoch [18/50], Step [70/313], Loss: 0.2201
# Epoch [18/50], Step [80/313], Loss: 0.3316
# Epoch [18/50], Step [90/313], Loss: 0.2827
# Epoch [18/50], Step [100/313], Loss: 0.4241
# Epoch [18/50], Step [110/313], Loss: 0.3481
# Epoch [18/50], Step [120/313], Loss: 0.2806
# Epoch [18/50], Step [130/313], Loss: 0.1983
# Epoch [18/50], Step [140/313], Loss: 0.3468
# Epoch [18/50], Step [150/313], Loss: 0.2920
# Epoch [18/50], Step [160/313], Loss: 0.2969
# Epoch [18/50], Step [170/313], Loss: 0.2383
# Epoch [18/50], Step [180/313], Loss: 0.2650
# Epoch [18/50], Step [190/313], Loss: 0.1870
# Epoch [18/50], Step [200/313], Loss: 0.3141
# Epoch [18/50], Step [210/313], Loss: 0.3609
# Epoch [18/50], Step [220/313], Loss: 0.3895
# Epoch [18/50], Step [230/313], Loss: 0.2446
# Epoch [18/50], Step [240/313], Loss: 0.3376
# Epoch [18/50], Step [250/313], Loss: 0.3042
# Epoch [18/50], Step [260/313], Loss: 0.2925
# Epoch [18/50], Step [270/313], Loss: 0.2675
# Epoch [18/50], Step [280/313], Loss: 0.3423
# Epoch [18/50], Step [290/313], Loss: 0.2392
# Epoch [18/50], Step [300/313], Loss: 0.2546
# Epoch [18/50], Step [310/313], Loss: 0.2291
# Epoch [18/50], Aug. 2 Training Loss: 0.3006, Train Mean mIoU: 0.5456
# Epoch [18/50], Aug. 2 Validation Loss: 1.8885, Val Mean mIoU: 0.1980
# road: Val mIoU = 0.2946
# sidewalk: Val mIoU = 0.0880
# building: Val mIoU = 0.6200
# wall: Val mIoU = 0.0437
# fence: Val mIoU = 0.0374
# pole: Val mIoU = 0.1054
# traffic light: Val mIoU = 0.0679
# traffic sign: Val mIoU = 0.0785
# vegetation: Val mIoU = 0.6734
# terrain: Val mIoU = 0.0239
# sky: Val mIoU = 0.6806
# person: Val mIoU = 0.3134
# rider: Val mIoU = 0.0111
# car: Val mIoU = 0.5887
# truck: Val mIoU = 0.0757
# bus: Val mIoU = 0.0236
# train: Val mIoU = 0.0003
# motorcycle: Val mIoU = 0.0357
# bicycle: Val mIoU = 0.0000
# Epoch [19/50], Step [10/313], Loss: 0.2094
# Epoch [19/50], Step [20/313], Loss: 0.3492
# Epoch [19/50], Step [30/313], Loss: 0.2141
# Epoch [19/50], Step [40/313], Loss: 0.2511
# Epoch [19/50], Step [50/313], Loss: 0.3131
# Epoch [19/50], Step [60/313], Loss: 0.1699
# Epoch [19/50], Step [70/313], Loss: 0.3099
# Epoch [19/50], Step [80/313], Loss: 0.3031
# Epoch [19/50], Step [90/313], Loss: 0.3589
# Epoch [19/50], Step [100/313], Loss: 0.2812
# Epoch [19/50], Step [110/313], Loss: 0.2223
# Epoch [19/50], Step [120/313], Loss: 0.2913
# Epoch [19/50], Step [130/313], Loss: 0.3418
# Epoch [19/50], Step [140/313], Loss: 0.3683
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [19/50], Step [150/313], Loss: 0.2507
# Epoch [19/50], Step [160/313], Loss: 0.2398
# Epoch [19/50], Step [170/313], Loss: 0.3391
# Epoch [19/50], Step [180/313], Loss: 0.2347
# Epoch [19/50], Step [190/313], Loss: 0.2512
# Epoch [19/50], Step [200/313], Loss: 0.3067
# Epoch [19/50], Step [210/313], Loss: 0.2624
# Epoch [19/50], Step [220/313], Loss: 0.3140
# Epoch [19/50], Step [230/313], Loss: 0.2705
# Epoch [19/50], Step [240/313], Loss: 0.3588
# Epoch [19/50], Step [250/313], Loss: 0.2742
# Epoch [19/50], Step [260/313], Loss: 0.2940
# Epoch [19/50], Step [270/313], Loss: 0.2276
# Epoch [19/50], Step [280/313], Loss: 0.3342
# Epoch [19/50], Step [290/313], Loss: 0.3280
# Epoch [19/50], Step [300/313], Loss: 0.3794
# Epoch [19/50], Step [310/313], Loss: 0.3148
# Epoch [19/50], Aug. 2 Training Loss: 0.2888, Train Mean mIoU: 0.5420
# Epoch [19/50], Aug. 2 Validation Loss: 1.3753, Val Mean mIoU: 0.2103
# road: Val mIoU = 0.4518
# sidewalk: Val mIoU = 0.0395
# building: Val mIoU = 0.6578
# wall: Val mIoU = 0.0644
# fence: Val mIoU = 0.1020
# pole: Val mIoU = 0.1144
# traffic light: Val mIoU = 0.0707
# traffic sign: Val mIoU = 0.0584
# vegetation: Val mIoU = 0.7135
# terrain: Val mIoU = 0.0267
# sky: Val mIoU = 0.6104
# person: Val mIoU = 0.3220
# rider: Val mIoU = 0.0123
# car: Val mIoU = 0.5702
# truck: Val mIoU = 0.1156
# bus: Val mIoU = 0.0101
# train: Val mIoU = 0.0090
# motorcycle: Val mIoU = 0.0477
# bicycle: Val mIoU = 0.0000
# Epoch [20/50], Step [10/313], Loss: 0.3065
# Epoch [20/50], Step [20/313], Loss: 0.3370
# Epoch [20/50], Step [30/313], Loss: 0.3611
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [20/50], Step [40/313], Loss: 0.4245
# Epoch [20/50], Step [50/313], Loss: 0.2313
# Epoch [20/50], Step [60/313], Loss: 0.2894
# Epoch [20/50], Step [70/313], Loss: 0.2477
# Epoch [20/50], Step [80/313], Loss: 0.2882
# Epoch [20/50], Step [90/313], Loss: 0.2515
# Epoch [20/50], Step [100/313], Loss: 0.3299
# Epoch [20/50], Step [110/313], Loss: 0.3068
# Epoch [20/50], Step [120/313], Loss: 0.3713
# Epoch [20/50], Step [130/313], Loss: 0.2161
# Epoch [20/50], Step [140/313], Loss: 0.3491
# Epoch [20/50], Step [150/313], Loss: 0.3184
# Epoch [20/50], Step [160/313], Loss: 0.2801
# Epoch [20/50], Step [170/313], Loss: 0.2874
# Epoch [20/50], Step [180/313], Loss: 0.2590
# Epoch [20/50], Step [190/313], Loss: 0.2231
# Epoch [20/50], Step [200/313], Loss: 0.3961
# Epoch [20/50], Step [210/313], Loss: 0.2644
# Epoch [20/50], Step [220/313], Loss: 0.3256
# Epoch [20/50], Step [230/313], Loss: 0.2501
# Epoch [20/50], Step [240/313], Loss: 0.2699
# Epoch [20/50], Step [250/313], Loss: 0.3111
# Epoch [20/50], Step [260/313], Loss: 0.2426
# Epoch [20/50], Step [270/313], Loss: 0.1748
# Epoch [20/50], Step [280/313], Loss: 0.2621
# Epoch [20/50], Step [290/313], Loss: 0.3261
# Epoch [20/50], Step [300/313], Loss: 0.3620
# Epoch [20/50], Step [310/313], Loss: 0.2930
# Epoch [20/50], Aug. 2 Training Loss: 0.2817, Train Mean mIoU: 0.5648
# Epoch [20/50], Aug. 2 Validation Loss: 1.4451, Val Mean mIoU: 0.2087
# road: Val mIoU = 0.4138
# sidewalk: Val mIoU = 0.1197
# building: Val mIoU = 0.6105
# wall: Val mIoU = 0.1005
# fence: Val mIoU = 0.0942
# pole: Val mIoU = 0.0842
# traffic light: Val mIoU = 0.0818
# traffic sign: Val mIoU = 0.0388
# vegetation: Val mIoU = 0.7296
# terrain: Val mIoU = 0.0293
# sky: Val mIoU = 0.6113
# person: Val mIoU = 0.3070
# rider: Val mIoU = 0.0033
# car: Val mIoU = 0.5503
# truck: Val mIoU = 0.1225
# bus: Val mIoU = 0.0375
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0308
# bicycle: Val mIoU = 0.0000
# Epoch [21/50], Step [10/313], Loss: 0.1971
# Epoch [21/50], Step [20/313], Loss: 0.2897
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [21/50], Step [30/313], Loss: 0.2476
# Epoch [21/50], Step [40/313], Loss: 0.2238
# Epoch [21/50], Step [50/313], Loss: 0.3770
# Epoch [21/50], Step [60/313], Loss: 0.1888
# Epoch [21/50], Step [70/313], Loss: 0.2534
# Epoch [21/50], Step [80/313], Loss: 0.2843
# Epoch [21/50], Step [90/313], Loss: 0.2984
# Epoch [21/50], Step [100/313], Loss: 0.2849
# Epoch [21/50], Step [110/313], Loss: 0.2109
# Epoch [21/50], Step [120/313], Loss: 0.2393
# Epoch [21/50], Step [130/313], Loss: 0.3407
# Epoch [21/50], Step [140/313], Loss: 0.3676
# Epoch [21/50], Step [150/313], Loss: 0.3172
# Epoch [21/50], Step [160/313], Loss: 0.2392
# Epoch [21/50], Step [170/313], Loss: 0.2809
# Epoch [21/50], Step [180/313], Loss: 0.2235
# Epoch [21/50], Step [190/313], Loss: 0.2314
# Epoch [21/50], Step [200/313], Loss: 0.2437
# Epoch [21/50], Step [210/313], Loss: 0.4232
# Epoch [21/50], Step [220/313], Loss: 0.3030
# Epoch [21/50], Step [230/313], Loss: 0.3989
# Epoch [21/50], Step [240/313], Loss: 0.2865
# Epoch [21/50], Step [250/313], Loss: 0.2020
# Epoch [21/50], Step [260/313], Loss: 0.2493
# Epoch [21/50], Step [270/313], Loss: 0.2195
# Epoch [21/50], Step [280/313], Loss: 0.1723
# Epoch [21/50], Step [290/313], Loss: 0.2449
# Epoch [21/50], Step [300/313], Loss: 0.2493
# Epoch [21/50], Step [310/313], Loss: 0.1647
# Epoch [21/50], Aug. 2 Training Loss: 0.2780, Train Mean mIoU: 0.5460
# Epoch [21/50], Aug. 2 Validation Loss: 2.0894, Val Mean mIoU: 0.1791
# road: Val mIoU = 0.2101
# sidewalk: Val mIoU = 0.0948
# building: Val mIoU = 0.6095
# wall: Val mIoU = 0.0488
# fence: Val mIoU = 0.1340
# pole: Val mIoU = 0.0784
# traffic light: Val mIoU = 0.0301
# traffic sign: Val mIoU = 0.0719
# vegetation: Val mIoU = 0.6532
# terrain: Val mIoU = 0.0261
# sky: Val mIoU = 0.5906
# person: Val mIoU = 0.2903
# rider: Val mIoU = 0.0069
# car: Val mIoU = 0.4623
# truck: Val mIoU = 0.0619
# bus: Val mIoU = 0.0018
# train: Val mIoU = 0.0049
# motorcycle: Val mIoU = 0.0283
# bicycle: Val mIoU = 0.0000
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [22/50], Step [10/313], Loss: 0.1974
# Epoch [22/50], Step [20/313], Loss: 0.3396
# Epoch [22/50], Step [30/313], Loss: 0.2499
# Epoch [22/50], Step [40/313], Loss: 0.2969
# Epoch [22/50], Step [50/313], Loss: 0.2504
# Epoch [22/50], Step [60/313], Loss: 0.3159
# Epoch [22/50], Step [70/313], Loss: 0.2534
# Epoch [22/50], Step [80/313], Loss: 0.3019
# Epoch [22/50], Step [90/313], Loss: 0.2135
# Epoch [22/50], Step [100/313], Loss: 0.2113
# Epoch [22/50], Step [110/313], Loss: 0.2718
# Epoch [22/50], Step [120/313], Loss: 0.3076
# Epoch [22/50], Step [130/313], Loss: 0.3085
# Epoch [22/50], Step [140/313], Loss: 0.2650
# Epoch [22/50], Step [150/313], Loss: 0.3731
# Epoch [22/50], Step [160/313], Loss: 0.2685
# Epoch [22/50], Step [170/313], Loss: 0.3257
# Epoch [22/50], Step [180/313], Loss: 0.2832
# Epoch [22/50], Step [190/313], Loss: 0.2392
# Epoch [22/50], Step [200/313], Loss: 0.3242
# Epoch [22/50], Step [210/313], Loss: 0.2322
# Epoch [22/50], Step [220/313], Loss: 0.3198
# Epoch [22/50], Step [230/313], Loss: 0.1724
# Epoch [22/50], Step [240/313], Loss: 0.2552
# Epoch [22/50], Step [250/313], Loss: 0.2841
# Epoch [22/50], Step [260/313], Loss: 0.1987
# Epoch [22/50], Step [270/313], Loss: 0.2821
# Epoch [22/50], Step [280/313], Loss: 0.2604
# Epoch [22/50], Step [290/313], Loss: 0.2852
# Epoch [22/50], Step [300/313], Loss: 0.1870
# Epoch [22/50], Step [310/313], Loss: 0.2505
# Epoch [22/50], Aug. 2 Training Loss: 0.2707, Train Mean mIoU: 0.5610
# Epoch [22/50], Aug. 2 Validation Loss: 1.9541, Val Mean mIoU: 0.2064
# road: Val mIoU = 0.2770
# sidewalk: Val mIoU = 0.0789
# building: Val mIoU = 0.6569
# wall: Val mIoU = 0.0449
# fence: Val mIoU = 0.0844
# pole: Val mIoU = 0.1215
# traffic light: Val mIoU = 0.0974
# traffic sign: Val mIoU = 0.0688
# vegetation: Val mIoU = 0.6871
# terrain: Val mIoU = 0.0234
# sky: Val mIoU = 0.6378
# person: Val mIoU = 0.3335
# rider: Val mIoU = 0.0276
# car: Val mIoU = 0.6132
# truck: Val mIoU = 0.1154
# bus: Val mIoU = 0.0034
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0508
# bicycle: Val mIoU = 0.0000
# Epoch [23/50], Step [10/313], Loss: 0.2090
# Epoch [23/50], Step [20/313], Loss: 0.2068
# Epoch [23/50], Step [30/313], Loss: 0.2189
# Epoch [23/50], Step [40/313], Loss: 0.1517
# Epoch [23/50], Step [50/313], Loss: 0.2207
# Epoch [23/50], Step [60/313], Loss: 0.2083
# Epoch [23/50], Step [70/313], Loss: 0.2835
# Epoch [23/50], Step [80/313], Loss: 0.2371
# Epoch [23/50], Step [90/313], Loss: 0.1974
# Epoch [23/50], Step [100/313], Loss: 0.1542
# Epoch [23/50], Step [110/313], Loss: 0.2493
# Epoch [23/50], Step [120/313], Loss: 0.2320
# Epoch [23/50], Step [130/313], Loss: 0.2908
# Epoch [23/50], Step [140/313], Loss: 0.2999
# Epoch [23/50], Step [150/313], Loss: 0.3076
# Epoch [23/50], Step [160/313], Loss: 0.2812
# Epoch [23/50], Step [170/313], Loss: 0.2532
# Epoch [23/50], Step [180/313], Loss: 0.2044
# Epoch [23/50], Step [190/313], Loss: 0.2933
# Epoch [23/50], Step [200/313], Loss: 0.2466
# Epoch [23/50], Step [210/313], Loss: 0.1938
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [23/50], Step [220/313], Loss: 0.2136
# Epoch [23/50], Step [230/313], Loss: 0.2036
# Epoch [23/50], Step [240/313], Loss: 0.2495
# Epoch [23/50], Step [250/313], Loss: 0.1928
# Epoch [23/50], Step [260/313], Loss: 0.2737
# Epoch [23/50], Step [270/313], Loss: 0.2248
# Epoch [23/50], Step [280/313], Loss: 0.1925
# Epoch [23/50], Step [290/313], Loss: 0.3342
# Epoch [23/50], Step [300/313], Loss: 0.2959
# Epoch [23/50], Step [310/313], Loss: 0.2785
# Epoch [23/50], Aug. 2 Training Loss: 0.2606, Train Mean mIoU: 0.5746
# Epoch [23/50], Aug. 2 Validation Loss: 1.4626, Val Mean mIoU: 0.2036
# road: Val mIoU = 0.4030
# sidewalk: Val mIoU = 0.1386
# building: Val mIoU = 0.6662
# wall: Val mIoU = 0.0497
# fence: Val mIoU = 0.0749
# pole: Val mIoU = 0.1322
# traffic light: Val mIoU = 0.0703
# traffic sign: Val mIoU = 0.0746
# vegetation: Val mIoU = 0.6735
# terrain: Val mIoU = 0.0291
# sky: Val mIoU = 0.5964
# person: Val mIoU = 0.3519
# rider: Val mIoU = 0.0083
# car: Val mIoU = 0.4711
# truck: Val mIoU = 0.0798
# bus: Val mIoU = 0.0037
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0442
# bicycle: Val mIoU = 0.0000
# Epoch [24/50], Step [10/313], Loss: 0.2207
# Epoch [24/50], Step [20/313], Loss: 0.2154
# Epoch [24/50], Step [30/313], Loss: 0.2423
# Epoch [24/50], Step [40/313], Loss: 0.3515
# Epoch [24/50], Step [50/313], Loss: 0.1916
# Epoch [24/50], Step [60/313], Loss: 0.3409
# Epoch [24/50], Step [70/313], Loss: 0.2877
# Epoch [24/50], Step [80/313], Loss: 0.3160
# Epoch [24/50], Step [90/313], Loss: 0.2017
# Epoch [24/50], Step [100/313], Loss: 0.3212
# Epoch [24/50], Step [110/313], Loss: 0.2119
# Epoch [24/50], Step [120/313], Loss: 0.2942
# Epoch [24/50], Step [130/313], Loss: 0.1753
# Epoch [24/50], Step [140/313], Loss: 0.2603
# Epoch [24/50], Step [150/313], Loss: 0.3018
# Epoch [24/50], Step [160/313], Loss: 0.2167
# Epoch [24/50], Step [170/313], Loss: 0.2571
# Epoch [24/50], Step [180/313], Loss: 0.2381
# Epoch [24/50], Step [190/313], Loss: 0.2159
# Epoch [24/50], Step [200/313], Loss: 0.2889
# Epoch [24/50], Step [210/313], Loss: 0.2589
# Epoch [24/50], Step [220/313], Loss: 0.2318
# Epoch [24/50], Step [230/313], Loss: 0.2123
# Epoch [24/50], Step [240/313], Loss: 0.2465
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [24/50], Step [250/313], Loss: 0.2145
# Epoch [24/50], Step [260/313], Loss: 0.2118
# Epoch [24/50], Step [270/313], Loss: 0.1954
# Epoch [24/50], Step [280/313], Loss: 0.2714
# Epoch [24/50], Step [290/313], Loss: 0.1412
# Epoch [24/50], Step [300/313], Loss: 0.2331
# Epoch [24/50], Step [310/313], Loss: 0.2523
# Epoch [24/50], Aug. 2 Training Loss: 0.2513, Train Mean mIoU: 0.5929
# Epoch [24/50], Aug. 2 Validation Loss: 1.8309, Val Mean mIoU: 0.1966
# road: Val mIoU = 0.2962
# sidewalk: Val mIoU = 0.1138
# building: Val mIoU = 0.6166
# wall: Val mIoU = 0.0798
# fence: Val mIoU = 0.0144
# pole: Val mIoU = 0.1280
# traffic light: Val mIoU = 0.0562
# traffic sign: Val mIoU = 0.0575
# vegetation: Val mIoU = 0.6995
# terrain: Val mIoU = 0.0265
# sky: Val mIoU = 0.6139
# person: Val mIoU = 0.3531
# rider: Val mIoU = 0.0055
# car: Val mIoU = 0.5510
# truck: Val mIoU = 0.0639
# bus: Val mIoU = 0.0343
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0256
# bicycle: Val mIoU = 0.0000
# Epoch [25/50], Step [10/313], Loss: 0.2529
# Epoch [25/50], Step [20/313], Loss: 0.2652
# Epoch [25/50], Step [30/313], Loss: 0.2331
# Epoch [25/50], Step [40/313], Loss: 0.2574
# Epoch [25/50], Step [50/313], Loss: 0.3485
# Epoch [25/50], Step [60/313], Loss: 0.2112
# Epoch [25/50], Step [70/313], Loss: 0.2323
# Epoch [25/50], Step [80/313], Loss: 0.2332
# Epoch [25/50], Step [90/313], Loss: 0.2211
# Epoch [25/50], Step [100/313], Loss: 0.2877
# Epoch [25/50], Step [110/313], Loss: 0.2103
# Epoch [25/50], Step [120/313], Loss: 0.2259
# Epoch [25/50], Step [130/313], Loss: 0.2729
# Epoch [25/50], Step [140/313], Loss: 0.3091
# Epoch [25/50], Step [150/313], Loss: 0.2479
# Epoch [25/50], Step [160/313], Loss: 0.2490
# Epoch [25/50], Step [170/313], Loss: 0.2874
# Epoch [25/50], Step [180/313], Loss: 0.2365
# Epoch [25/50], Step [190/313], Loss: 0.2389
# Epoch [25/50], Step [200/313], Loss: 0.3170
# Epoch [25/50], Step [210/313], Loss: 0.1945
# Epoch [25/50], Step [220/313], Loss: 0.1573
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [25/50], Step [230/313], Loss: 0.3209
# Epoch [25/50], Step [240/313], Loss: 0.2185
# Epoch [25/50], Step [250/313], Loss: 0.2215
# Epoch [25/50], Step [260/313], Loss: 0.2904
# Epoch [25/50], Step [270/313], Loss: 0.2855
# Epoch [25/50], Step [280/313], Loss: 0.2412
# Epoch [25/50], Step [290/313], Loss: 0.2300
# Epoch [25/50], Step [300/313], Loss: 0.3041
# Epoch [25/50], Step [310/313], Loss: 0.1667
# Epoch [25/50], Aug. 2 Training Loss: 0.2486, Train Mean mIoU: 0.5827
# Epoch [25/50], Aug. 2 Validation Loss: 1.9086, Val Mean mIoU: 0.1997
# road: Val mIoU = 0.3000
# sidewalk: Val mIoU = 0.1036
# building: Val mIoU = 0.6413
# wall: Val mIoU = 0.0678
# fence: Val mIoU = 0.0560
# pole: Val mIoU = 0.1423
# traffic light: Val mIoU = 0.0769
# traffic sign: Val mIoU = 0.0689
# vegetation: Val mIoU = 0.7016
# terrain: Val mIoU = 0.0265
# sky: Val mIoU = 0.6107
# person: Val mIoU = 0.3352
# rider: Val mIoU = 0.0050
# car: Val mIoU = 0.5450
# truck: Val mIoU = 0.0590
# bus: Val mIoU = 0.0257
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0294
# bicycle: Val mIoU = 0.0000
# Epoch [26/50], Step [10/313], Loss: 0.2514
# Epoch [26/50], Step [20/313], Loss: 0.1938
# Epoch [26/50], Step [30/313], Loss: 0.2467
# Epoch [26/50], Step [40/313], Loss: 0.2566
# Epoch [26/50], Step [50/313], Loss: 0.1845
# Epoch [26/50], Step [60/313], Loss: 0.3138
# Epoch [26/50], Step [70/313], Loss: 0.3187
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [26/50], Step [80/313], Loss: 0.1347
# Epoch [26/50], Step [90/313], Loss: 0.2256
# Epoch [26/50], Step [100/313], Loss: 0.2196
# Epoch [26/50], Step [110/313], Loss: 0.3201
# Epoch [26/50], Step [120/313], Loss: 0.2709
# Epoch [26/50], Step [130/313], Loss: 0.2255
# Epoch [26/50], Step [140/313], Loss: 0.2424
# Epoch [26/50], Step [150/313], Loss: 0.3048
# Epoch [26/50], Step [160/313], Loss: 0.2393
# Epoch [26/50], Step [170/313], Loss: 0.2097
# Epoch [26/50], Step [180/313], Loss: 0.2291
# Epoch [26/50], Step [190/313], Loss: 0.2486
# Epoch [26/50], Step [200/313], Loss: 0.3165
# Epoch [26/50], Step [210/313], Loss: 0.3744
# Epoch [26/50], Step [220/313], Loss: 0.2319
# Epoch [26/50], Step [230/313], Loss: 0.2318
# Epoch [26/50], Step [240/313], Loss: 0.2577
# Epoch [26/50], Step [250/313], Loss: 0.2262
# Epoch [26/50], Step [260/313], Loss: 0.2612
# Epoch [26/50], Step [270/313], Loss: 0.2467
# Epoch [26/50], Step [280/313], Loss: 0.3016
# Epoch [26/50], Step [290/313], Loss: 0.2395
# Epoch [26/50], Step [300/313], Loss: 0.2653
# Epoch [26/50], Step [310/313], Loss: 0.2396
# Epoch [26/50], Aug. 2 Training Loss: 0.2427, Train Mean mIoU: 0.5907
# Epoch [26/50], Aug. 2 Validation Loss: 1.6844, Val Mean mIoU: 0.1840
# road: Val mIoU = 0.3223
# sidewalk: Val mIoU = 0.0609
# building: Val mIoU = 0.5799
# wall: Val mIoU = 0.0469
# fence: Val mIoU = 0.0915
# pole: Val mIoU = 0.1264
# traffic light: Val mIoU = 0.0591
# traffic sign: Val mIoU = 0.0597
# vegetation: Val mIoU = 0.6952
# terrain: Val mIoU = 0.0314
# sky: Val mIoU = 0.6044
# person: Val mIoU = 0.3010
# rider: Val mIoU = 0.0094
# car: Val mIoU = 0.4173
# truck: Val mIoU = 0.0586
# bus: Val mIoU = 0.0098
# train: Val mIoU = 0.0014
# motorcycle: Val mIoU = 0.0205
# bicycle: Val mIoU = 0.0000
# Epoch [27/50], Step [10/313], Loss: 0.2045
# Epoch [27/50], Step [20/313], Loss: 0.1798
# Epoch [27/50], Step [30/313], Loss: 0.2369
# Epoch [27/50], Step [40/313], Loss: 0.1736
# Epoch [27/50], Step [50/313], Loss: 0.2290
# Epoch [27/50], Step [60/313], Loss: 0.2566
# Epoch [27/50], Step [70/313], Loss: 0.2543
# Epoch [27/50], Step [80/313], Loss: 0.2821
# Epoch [27/50], Step [90/313], Loss: 0.2586
# Epoch [27/50], Step [100/313], Loss: 0.2283
# Epoch [27/50], Step [110/313], Loss: 0.2586
# Epoch [27/50], Step [120/313], Loss: 0.1786
# Epoch [27/50], Step [130/313], Loss: 0.2793
# Epoch [27/50], Step [140/313], Loss: 0.2633
# Epoch [27/50], Step [150/313], Loss: 0.3651
# Epoch [27/50], Step [160/313], Loss: 0.2604
# Epoch [27/50], Step [170/313], Loss: 0.2807
# Epoch [27/50], Step [180/313], Loss: 0.1468
# Epoch [27/50], Step [190/313], Loss: 0.3089
# Epoch [27/50], Step [200/313], Loss: 0.2461
# Epoch [27/50], Step [210/313], Loss: 0.2280
# Epoch [27/50], Step [220/313], Loss: 0.3324
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [27/50], Step [230/313], Loss: 0.3700
# Epoch [27/50], Step [240/313], Loss: 0.2116
# Epoch [27/50], Step [250/313], Loss: 0.2440
# Epoch [27/50], Step [260/313], Loss: 0.1962
# Epoch [27/50], Step [270/313], Loss: 0.1827
# Epoch [27/50], Step [280/313], Loss: 0.2173
# Epoch [27/50], Step [290/313], Loss: 0.2462
# Epoch [27/50], Step [300/313], Loss: 0.2526
# Epoch [27/50], Step [310/313], Loss: 0.2763
# Epoch [27/50], Aug. 2 Training Loss: 0.2373, Train Mean mIoU: 0.6005
# Epoch [27/50], Aug. 2 Validation Loss: 2.3159, Val Mean mIoU: 0.1860
# road: Val mIoU = 0.2220
# sidewalk: Val mIoU = 0.0552
# building: Val mIoU = 0.6102
# wall: Val mIoU = 0.0325
# fence: Val mIoU = 0.0740
# pole: Val mIoU = 0.1125
# traffic light: Val mIoU = 0.0689
# traffic sign: Val mIoU = 0.0651
# vegetation: Val mIoU = 0.6738
# terrain: Val mIoU = 0.0228
# sky: Val mIoU = 0.6319
# person: Val mIoU = 0.3036
# rider: Val mIoU = 0.0035
# car: Val mIoU = 0.5397
# truck: Val mIoU = 0.0594
# bus: Val mIoU = 0.0193
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0394
# bicycle: Val mIoU = 0.0000
# Epoch [28/50], Step [10/313], Loss: 0.2132
# Epoch [28/50], Step [20/313], Loss: 0.2365
# Epoch [28/50], Step [30/313], Loss: 0.1810
# Epoch [28/50], Step [40/313], Loss: 0.1969
# Epoch [28/50], Step [50/313], Loss: 0.1864
# Epoch [28/50], Step [60/313], Loss: 0.2302
# Epoch [28/50], Step [70/313], Loss: 0.2132
# Epoch [28/50], Step [80/313], Loss: 0.2361
# Epoch [28/50], Step [90/313], Loss: 0.2826
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [28/50], Step [100/313], Loss: 0.2932
# Epoch [28/50], Step [110/313], Loss: 0.1397
# Epoch [28/50], Step [120/313], Loss: 0.1638
# Epoch [28/50], Step [130/313], Loss: 0.2152
# Epoch [28/50], Step [140/313], Loss: 0.2163
# Epoch [28/50], Step [150/313], Loss: 0.2355
# Epoch [28/50], Step [160/313], Loss: 0.2023
# Epoch [28/50], Step [170/313], Loss: 0.2179
# Epoch [28/50], Step [180/313], Loss: 0.1721
# Epoch [28/50], Step [190/313], Loss: 0.2391
# Epoch [28/50], Step [200/313], Loss: 0.2500
# Epoch [28/50], Step [210/313], Loss: 0.2407
# Epoch [28/50], Step [220/313], Loss: 0.1854
# Epoch [28/50], Step [230/313], Loss: 0.2813
# Epoch [28/50], Step [240/313], Loss: 0.2479
# Epoch [28/50], Step [250/313], Loss: 0.2341
# Epoch [28/50], Step [260/313], Loss: 0.2277
# Epoch [28/50], Step [270/313], Loss: 0.1872
# Epoch [28/50], Step [280/313], Loss: 0.2900
# Epoch [28/50], Step [290/313], Loss: 0.1818
# Epoch [28/50], Step [300/313], Loss: 0.2960
# Epoch [28/50], Step [310/313], Loss: 0.3223
# Epoch [28/50], Aug. 2 Training Loss: 0.2292, Train Mean mIoU: 0.6090
# Epoch [28/50], Aug. 2 Validation Loss: 1.6279, Val Mean mIoU: 0.2074
# road: Val mIoU = 0.3532
# sidewalk: Val mIoU = 0.1301
# building: Val mIoU = 0.6686
# wall: Val mIoU = 0.0656
# fence: Val mIoU = 0.0730
# pole: Val mIoU = 0.1366
# traffic light: Val mIoU = 0.0800
# traffic sign: Val mIoU = 0.0649
# vegetation: Val mIoU = 0.6966
# terrain: Val mIoU = 0.0292
# sky: Val mIoU = 0.6265
# person: Val mIoU = 0.3512
# rider: Val mIoU = 0.0073
# car: Val mIoU = 0.4806
# truck: Val mIoU = 0.0931
# bus: Val mIoU = 0.0177
# train: Val mIoU = 0.0022
# motorcycle: Val mIoU = 0.0633
# bicycle: Val mIoU = 0.0000
# Epoch [29/50], Step [10/313], Loss: 0.2053
# Epoch [29/50], Step [20/313], Loss: 0.2173
# Epoch [29/50], Step [30/313], Loss: 0.3004
# Epoch [29/50], Step [40/313], Loss: 0.2803
# Epoch [29/50], Step [50/313], Loss: 0.4048
# Epoch [29/50], Step [60/313], Loss: 0.3235
# Epoch [29/50], Step [70/313], Loss: 0.2487
# Epoch [29/50], Step [80/313], Loss: 0.2358
# Epoch [29/50], Step [90/313], Loss: 0.2479
# Epoch [29/50], Step [100/313], Loss: 0.2389
# ...
# Epoch [43/50], Step [280/313], Loss: 0.0922
# Epoch [43/50], Step [290/313], Loss: 0.0883
# Epoch [43/50], Step [300/313], Loss: 0.1455
# Epoch [43/50], Step [310/313], Loss: 0.0883
# Epoch [43/50], Aug. 1 + Aug. 2 Training Loss: 0.1178, Train Mean mIoU: 0.7539
# Epoch [43/50], Aug. 1 + Aug. 2 Validation Loss: 1.5405, Val Mean mIoU: 0.2166
# road: Val mIoU = 0.4212
# sidewalk: Val mIoU = 0.1372
# building: Val mIoU = 0.6245
# wall: Val mIoU = 0.1023
# fence: Val mIoU = 0.0934
# pole: Val mIoU = 0.1602
# traffic light: Val mIoU = 0.1170
# traffic sign: Val mIoU = 0.0472
# vegetation: Val mIoU = 0.7265
# terrain: Val mIoU = 0.0339
# sky: Val mIoU = 0.6568
# person: Val mIoU = 0.3384
# rider: Val mIoU = 0.0103
# car: Val mIoU = 0.5077
# truck: Val mIoU = 0.1018
# bus: Val mIoU = 0.0325
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0030
# bicycle: Val mIoU = 0.0007
# Epoch [44/50], Step [10/313], Loss: 0.1370
# Epoch [44/50], Step [20/313], Loss: 0.1292
# Epoch [44/50], Step [30/313], Loss: 0.1650
# Epoch [44/50], Step [40/313], Loss: 0.0953
# Epoch [44/50], Step [50/313], Loss: 0.1253
# Epoch [44/50], Step [60/313], Loss: 0.1019
# Epoch [44/50], Step [70/313], Loss: 0.1467
# Epoch [44/50], Step [80/313], Loss: 0.1116
# Epoch [44/50], Step [90/313], Loss: 0.1035
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [44/50], Step [100/313], Loss: 0.1007
# Epoch [44/50], Step [110/313], Loss: 0.1058
# Epoch [44/50], Step [120/313], Loss: 0.1055
# Epoch [44/50], Step [130/313], Loss: 0.0814
# Epoch [44/50], Step [140/313], Loss: 0.0845
# Epoch [44/50], Step [150/313], Loss: 0.1350
# Epoch [44/50], Step [160/313], Loss: 0.1670
# Epoch [44/50], Step [170/313], Loss: 0.0925
# Epoch [44/50], Step [180/313], Loss: 0.1008
# Epoch [44/50], Step [190/313], Loss: 0.1188
# Epoch [44/50], Step [200/313], Loss: 0.1397
# Epoch [44/50], Step [210/313], Loss: 0.1382
# Epoch [44/50], Step [220/313], Loss: 0.0904
# Epoch [44/50], Step [230/313], Loss: 0.1267
# Epoch [44/50], Step [240/313], Loss: 0.1118
# Epoch [44/50], Step [250/313], Loss: 0.1162
# Epoch [44/50], Step [260/313], Loss: 0.1135
# Epoch [44/50], Step [270/313], Loss: 0.0821
# Epoch [44/50], Step [280/313], Loss: 0.0874
# Epoch [44/50], Step [290/313], Loss: 0.1332
# Epoch [44/50], Step [300/313], Loss: 0.1428
# Epoch [44/50], Step [310/313], Loss: 0.1238
# Epoch [44/50], Aug. 1 + Aug. 2 Training Loss: 0.1171, Train Mean mIoU: 0.7564
# Epoch [44/50], Aug. 1 + Aug. 2 Validation Loss: 1.6698, Val Mean mIoU: 0.2151
# road: Val mIoU = 0.3895
# sidewalk: Val mIoU = 0.1370
# building: Val mIoU = 0.6198
# wall: Val mIoU = 0.1110
# fence: Val mIoU = 0.0928
# pole: Val mIoU = 0.1613
# traffic light: Val mIoU = 0.1187
# traffic sign: Val mIoU = 0.0452
# vegetation: Val mIoU = 0.7274
# terrain: Val mIoU = 0.0324
# sky: Val mIoU = 0.6581
# person: Val mIoU = 0.3404
# rider: Val mIoU = 0.0085
# car: Val mIoU = 0.5104
# truck: Val mIoU = 0.0937
# bus: Val mIoU = 0.0378
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0014
# bicycle: Val mIoU = 0.0010
# Epoch [45/50], Step [10/313], Loss: 0.1043
# Epoch [45/50], Step [20/313], Loss: 0.0726
# Epoch [45/50], Step [30/313], Loss: 0.0900
# Epoch [45/50], Step [40/313], Loss: 0.0909
# Epoch [45/50], Step [50/313], Loss: 0.1213
# Epoch [45/50], Step [60/313], Loss: 0.1158
# Epoch [45/50], Step [70/313], Loss: 0.1075
# Epoch [45/50], Step [80/313], Loss: 0.1335
# Epoch [45/50], Step [90/313], Loss: 0.0925
# Epoch [45/50], Step [100/313], Loss: 0.1105
# Epoch [45/50], Step [110/313], Loss: 0.1313
# Epoch [45/50], Step [120/313], Loss: 0.1195
# Epoch [45/50], Step [130/313], Loss: 0.0992
# Epoch [45/50], Step [140/313], Loss: 0.0926
# Epoch [45/50], Step [150/313], Loss: 0.0849
# Epoch [45/50], Step [160/313], Loss: 0.1329
# Epoch [45/50], Step [170/313], Loss: 0.1286
# Epoch [45/50], Step [180/313], Loss: 0.1105
# Epoch [45/50], Step [190/313], Loss: 0.1351
# Epoch [45/50], Step [200/313], Loss: 0.1154
# Epoch [45/50], Step [210/313], Loss: 0.1187
# Epoch [45/50], Step [220/313], Loss: 0.1421
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [45/50], Step [230/313], Loss: 0.1284
# Epoch [45/50], Step [240/313], Loss: 0.1467
# Epoch [45/50], Step [250/313], Loss: 0.1344
# Epoch [45/50], Step [260/313], Loss: 0.1099
# Epoch [45/50], Step [270/313], Loss: 0.0982
# Epoch [45/50], Step [280/313], Loss: 0.1728
# Epoch [45/50], Step [290/313], Loss: 0.1169
# Epoch [45/50], Step [300/313], Loss: 0.1326
# Epoch [45/50], Step [310/313], Loss: 0.0944
# Epoch [45/50], Aug. 1 + Aug. 2 Training Loss: 0.1164, Train Mean mIoU: 0.7589
# Epoch [45/50], Aug. 1 + Aug. 2 Validation Loss: 1.5562, Val Mean mIoU: 0.2191
# road: Val mIoU = 0.4318
# sidewalk: Val mIoU = 0.1414
# building: Val mIoU = 0.6383
# wall: Val mIoU = 0.1024
# fence: Val mIoU = 0.0995
# pole: Val mIoU = 0.1599
# traffic light: Val mIoU = 0.1078
# traffic sign: Val mIoU = 0.0480
# vegetation: Val mIoU = 0.7247
# terrain: Val mIoU = 0.0324
# sky: Val mIoU = 0.6529
# person: Val mIoU = 0.3468
# rider: Val mIoU = 0.0073
# car: Val mIoU = 0.5307
# truck: Val mIoU = 0.1041
# bus: Val mIoU = 0.0314
# train: Val mIoU = 0.0005
# motorcycle: Val mIoU = 0.0026
# bicycle: Val mIoU = 0.0003
# Epoch [46/50], Step [10/313], Loss: 0.1369
# Epoch [46/50], Step [20/313], Loss: 0.1026
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [46/50], Step [30/313], Loss: 0.1084
# Epoch [46/50], Step [40/313], Loss: 0.1526
# Epoch [46/50], Step [50/313], Loss: 0.1352
# Epoch [46/50], Step [60/313], Loss: 0.0983
# Epoch [46/50], Step [70/313], Loss: 0.1201
# Epoch [46/50], Step [80/313], Loss: 0.0864
# Epoch [46/50], Step [90/313], Loss: 0.1649
# Epoch [46/50], Step [100/313], Loss: 0.1063
# Epoch [46/50], Step [110/313], Loss: 0.1100
# Epoch [46/50], Step [120/313], Loss: 0.1226
# Epoch [46/50], Step [130/313], Loss: 0.1081
# Epoch [46/50], Step [140/313], Loss: 0.1644
# Epoch [46/50], Step [150/313], Loss: 0.1315
# Epoch [46/50], Step [160/313], Loss: 0.1024
# Epoch [46/50], Step [170/313], Loss: 0.1220
# Epoch [46/50], Step [180/313], Loss: 0.1101
# Epoch [46/50], Step [190/313], Loss: 0.1329
# Epoch [46/50], Step [200/313], Loss: 0.1214
# Epoch [46/50], Step [210/313], Loss: 0.1126
# Epoch [46/50], Step [220/313], Loss: 0.1197
# Epoch [46/50], Step [230/313], Loss: 0.1176
# Epoch [46/50], Step [240/313], Loss: 0.1328
# Epoch [46/50], Step [250/313], Loss: 0.0779
# Epoch [46/50], Step [260/313], Loss: 0.0995
# Epoch [46/50], Step [270/313], Loss: 0.1289
# Epoch [46/50], Step [280/313], Loss: 0.0905
# Epoch [46/50], Step [290/313], Loss: 0.1087
# Epoch [46/50], Step [300/313], Loss: 0.1165
# Epoch [46/50], Step [310/313], Loss: 0.1026
# Epoch [46/50], Aug. 1 + Aug. 2 Training Loss: 0.1182, Train Mean mIoU: 0.7552
# Epoch [46/50], Aug. 1 + Aug. 2 Validation Loss: 1.6488, Val Mean mIoU: 0.2107
# road: Val mIoU = 0.3866
# sidewalk: Val mIoU = 0.1316
# building: Val mIoU = 0.6127
# wall: Val mIoU = 0.0954
# fence: Val mIoU = 0.0977
# pole: Val mIoU = 0.1573
# traffic light: Val mIoU = 0.1133
# traffic sign: Val mIoU = 0.0521
# vegetation: Val mIoU = 0.7179
# terrain: Val mIoU = 0.0312
# sky: Val mIoU = 0.6353
# person: Val mIoU = 0.3275
# rider: Val mIoU = 0.0090
# car: Val mIoU = 0.5068
# truck: Val mIoU = 0.0968
# bus: Val mIoU = 0.0304
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0008
# bicycle: Val mIoU = 0.0013
# Epoch [47/50], Step [10/313], Loss: 0.0993
# Epoch [47/50], Step [20/313], Loss: 0.0950
# Epoch [47/50], Step [30/313], Loss: 0.1364
# Epoch [47/50], Step [40/313], Loss: 0.1000
# Epoch [47/50], Step [50/313], Loss: 0.0830
# Epoch [47/50], Step [60/313], Loss: 0.0958
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [47/50], Step [70/313], Loss: 0.0968
# Epoch [47/50], Step [80/313], Loss: 0.1158
# Epoch [47/50], Step [90/313], Loss: 0.1041
# Epoch [47/50], Step [100/313], Loss: 0.1145
# Epoch [47/50], Step [110/313], Loss: 0.0991
# Epoch [47/50], Step [120/313], Loss: 0.1287
# Epoch [47/50], Step [130/313], Loss: 0.0987
# Epoch [47/50], Step [140/313], Loss: 0.1847
# Epoch [47/50], Step [150/313], Loss: 0.1464
# Epoch [47/50], Step [160/313], Loss: 0.0878
# Epoch [47/50], Step [170/313], Loss: 0.0911
# Epoch [47/50], Step [180/313], Loss: 0.1207
# Epoch [47/50], Step [190/313], Loss: 0.1801
# Epoch [47/50], Step [200/313], Loss: 0.1639
# Epoch [47/50], Step [210/313], Loss: 0.0884
# Epoch [47/50], Step [220/313], Loss: 0.1270
# Epoch [47/50], Step [230/313], Loss: 0.0800
# Epoch [47/50], Step [240/313], Loss: 0.0882
# Epoch [47/50], Step [250/313], Loss: 0.1361
# Epoch [47/50], Step [260/313], Loss: 0.1181
# Epoch [47/50], Step [270/313], Loss: 0.1230
# Epoch [47/50], Step [280/313], Loss: 0.1209
# Epoch [47/50], Step [290/313], Loss: 0.1165
# Epoch [47/50], Step [300/313], Loss: 0.1069
# Epoch [47/50], Step [310/313], Loss: 0.1626
# Epoch [47/50], Aug. 1 + Aug. 2 Training Loss: 0.1138, Train Mean mIoU: 0.7569
# Epoch [47/50], Aug. 1 + Aug. 2 Validation Loss: 1.6090, Val Mean mIoU: 0.2137
# road: Val mIoU = 0.4066
# sidewalk: Val mIoU = 0.1418
# building: Val mIoU = 0.6298
# wall: Val mIoU = 0.1009
# fence: Val mIoU = 0.0928
# pole: Val mIoU = 0.1606
# traffic light: Val mIoU = 0.1142
# traffic sign: Val mIoU = 0.0492
# vegetation: Val mIoU = 0.7247
# terrain: Val mIoU = 0.0326
# sky: Val mIoU = 0.6475
# person: Val mIoU = 0.3314
# rider: Val mIoU = 0.0068
# car: Val mIoU = 0.4983
# truck: Val mIoU = 0.0932
# bus: Val mIoU = 0.0287
# train: Val mIoU = 0.0001
# motorcycle: Val mIoU = 0.0015
# bicycle: Val mIoU = 0.0005
# Epoch [48/50], Step [10/313], Loss: 0.1152
# Epoch [48/50], Step [20/313], Loss: 0.0813
# Epoch [48/50], Step [30/313], Loss: 0.0894
# Epoch [48/50], Step [40/313], Loss: 0.1237
# Epoch [48/50], Step [50/313], Loss: 0.1203
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [48/50], Step [60/313], Loss: 0.1176
# Epoch [48/50], Step [70/313], Loss: 0.1253
# Epoch [48/50], Step [80/313], Loss: 0.1272
# Epoch [48/50], Step [90/313], Loss: 0.0883
# Epoch [48/50], Step [100/313], Loss: 0.0931
# Epoch [48/50], Step [110/313], Loss: 0.1400
# Epoch [48/50], Step [120/313], Loss: 0.1038
# Epoch [48/50], Step [130/313], Loss: 0.1119
# Epoch [48/50], Step [140/313], Loss: 0.1124
# Epoch [48/50], Step [150/313], Loss: 0.1400
# Epoch [48/50], Step [160/313], Loss: 0.0883
# Epoch [48/50], Step [170/313], Loss: 0.0770
# Epoch [48/50], Step [180/313], Loss: 0.1541
# Epoch [48/50], Step [190/313], Loss: 0.1463
# Epoch [48/50], Step [200/313], Loss: 0.0964
# Epoch [48/50], Step [210/313], Loss: 0.1301
# Epoch [48/50], Step [220/313], Loss: 0.1126
# Epoch [48/50], Step [230/313], Loss: 0.1005
# Epoch [48/50], Step [240/313], Loss: 0.1048
# Epoch [48/50], Step [250/313], Loss: 0.1202
# Epoch [48/50], Step [260/313], Loss: 0.0877
# Epoch [48/50], Step [270/313], Loss: 0.1013
# Epoch [48/50], Step [280/313], Loss: 0.1029
# Epoch [48/50], Step [290/313], Loss: 0.1416
# Epoch [48/50], Step [300/313], Loss: 0.1407
# Epoch [48/50], Step [310/313], Loss: 0.1299
# Epoch [48/50], Aug. 1 + Aug. 2 Training Loss: 0.1145, Train Mean mIoU: 0.7560
# Epoch [48/50], Aug. 1 + Aug. 2 Validation Loss: 1.6791, Val Mean mIoU: 0.2079
# road: Val mIoU = 0.3725
# sidewalk: Val mIoU = 0.1354
# building: Val mIoU = 0.6162
# wall: Val mIoU = 0.0950
# fence: Val mIoU = 0.0997
# pole: Val mIoU = 0.1622
# traffic light: Val mIoU = 0.1174
# traffic sign: Val mIoU = 0.0478
# vegetation: Val mIoU = 0.7118
# terrain: Val mIoU = 0.0309
# sky: Val mIoU = 0.6188
# person: Val mIoU = 0.3140
# rider: Val mIoU = 0.0076
# car: Val mIoU = 0.4838
# truck: Val mIoU = 0.1003
# bus: Val mIoU = 0.0358
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0008
# Epoch [49/50], Step [10/313], Loss: 0.1679
# Epoch [49/50], Step [20/313], Loss: 0.0989
# Epoch [49/50], Step [30/313], Loss: 0.1092
# Epoch [49/50], Step [40/313], Loss: 0.1283
# Epoch [49/50], Step [50/313], Loss: 0.0860
# Epoch [49/50], Step [60/313], Loss: 0.0798
# Epoch [49/50], Step [70/313], Loss: 0.1137
# Epoch [49/50], Step [80/313], Loss: 0.1102
# Epoch [49/50], Step [90/313], Loss: 0.1151
# Epoch [49/50], Step [100/313], Loss: 0.1382
# Epoch [49/50], Step [110/313], Loss: 0.0999
# Epoch [49/50], Step [120/313], Loss: 0.1194
# Epoch [49/50], Step [130/313], Loss: 0.0967
# Epoch [49/50], Step [140/313], Loss: 0.1239
# Epoch [49/50], Step [150/313], Loss: 0.0974
# Epoch [49/50], Step [160/313], Loss: 0.1409
# Epoch [49/50], Step [170/313], Loss: 0.1074
# Epoch [49/50], Step [180/313], Loss: 0.0810
# Epoch [49/50], Step [190/313], Loss: 0.1239
# Epoch [49/50], Step [200/313], Loss: 0.1134
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [49/50], Step [210/313], Loss: 0.1088
# Epoch [49/50], Step [220/313], Loss: 0.0884
# Epoch [49/50], Step [230/313], Loss: 0.0938
# Epoch [49/50], Step [240/313], Loss: 0.0872
# Epoch [49/50], Step [250/313], Loss: 0.1032
# Epoch [49/50], Step [260/313], Loss: 0.0869
# Epoch [49/50], Step [270/313], Loss: 0.1262
# Epoch [49/50], Step [280/313], Loss: 0.1171
# Epoch [49/50], Step [290/313], Loss: 0.0913
# Epoch [49/50], Step [300/313], Loss: 0.1078
# Epoch [49/50], Step [310/313], Loss: 0.1085
# Epoch [49/50], Aug. 1 + Aug. 2 Training Loss: 0.1135, Train Mean mIoU: 0.7563
# Epoch [49/50], Aug. 1 + Aug. 2 Validation Loss: 1.6581, Val Mean mIoU: 0.2125
# road: Val mIoU = 0.3889
# sidewalk: Val mIoU = 0.1402
# building: Val mIoU = 0.6318
# wall: Val mIoU = 0.0966
# fence: Val mIoU = 0.0933
# pole: Val mIoU = 0.1592
# traffic light: Val mIoU = 0.1177
# traffic sign: Val mIoU = 0.0513
# vegetation: Val mIoU = 0.7202
# terrain: Val mIoU = 0.0313
# sky: Val mIoU = 0.6412
# person: Val mIoU = 0.3312
# rider: Val mIoU = 0.0083
# car: Val mIoU = 0.4949
# truck: Val mIoU = 0.0954
# bus: Val mIoU = 0.0333
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0026
# bicycle: Val mIoU = 0.0006
# Epoch [50/50], Step [10/313], Loss: 0.1300
# Epoch [50/50], Step [20/313], Loss: 0.1064
# Epoch [50/50], Step [30/313], Loss: 0.0928
# Epoch [50/50], Step [40/313], Loss: 0.1054
# Epoch [50/50], Step [50/313], Loss: 0.1379
# Epoch [50/50], Step [60/313], Loss: 0.1019
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [50/50], Step [70/313], Loss: 0.0980
# Epoch [50/50], Step [80/313], Loss: 0.1279
# Epoch [50/50], Step [90/313], Loss: 0.1214
# Epoch [50/50], Step [100/313], Loss: 0.0859
# Epoch [50/50], Step [110/313], Loss: 0.1147
# Epoch [50/50], Step [120/313], Loss: 0.0970
# Epoch [50/50], Step [130/313], Loss: 0.0976
# Epoch [50/50], Step [140/313], Loss: 0.1255
# Epoch [50/50], Step [150/313], Loss: 0.1315
# Epoch [50/50], Step [160/313], Loss: 0.1822
# Epoch [50/50], Step [170/313], Loss: 0.1313
# Epoch [50/50], Step [180/313], Loss: 0.1313
# Epoch [50/50], Step [190/313], Loss: 0.0730
# Epoch [50/50], Step [200/313], Loss: 0.0960
# Epoch [50/50], Step [210/313], Loss: 0.1129
# Epoch [50/50], Step [220/313], Loss: 0.1600
# Epoch [50/50], Step [230/313], Loss: 0.1289
# Epoch [50/50], Step [240/313], Loss: 0.1482
# Epoch [50/50], Step [250/313], Loss: 0.0945
# Epoch [50/50], Step [260/313], Loss: 0.1366
# Epoch [50/50], Step [270/313], Loss: 0.1231
# Epoch [50/50], Step [280/313], Loss: 0.1228
# Epoch [50/50], Step [290/313], Loss: 0.1176
# Epoch [50/50], Step [300/313], Loss: 0.1037
# Epoch [50/50], Step [310/313], Loss: 0.0809
# Epoch [50/50], Aug. 1 + Aug. 2 Training Loss: 0.1153, Train Mean mIoU: 0.7590
# Epoch [50/50], Aug. 1 + Aug. 2 Validation Loss: 1.6914, Val Mean mIoU: 0.2092
# road: Val mIoU = 0.3774
# sidewalk: Val mIoU = 0.1337
# building: Val mIoU = 0.6174
# wall: Val mIoU = 0.0972
# fence: Val mIoU = 0.1002
# pole: Val mIoU = 0.1549
# traffic light: Val mIoU = 0.1118
# traffic sign: Val mIoU = 0.0434
# vegetation: Val mIoU = 0.7156
# terrain: Val mIoU = 0.0314
# sky: Val mIoU = 0.6332
# person: Val mIoU = 0.3170
# rider: Val mIoU = 0.0078
# car: Val mIoU = 0.4914
# truck: Val mIoU = 0.1009
# bus: Val mIoU = 0.0370
# train: Val mIoU = 0.0001
# motorcycle: Val mIoU = 0.0033
# bicycle: Val mIoU = 0.0007

# %%
import matplotlib.pyplot as plt

augmentation_types = ['Aug. 1', 'Aug. 2', 'Aug. 1 + Aug. 2']
epochs = range(1, num_epochs + 1)

for aug_type in augmentation_types:
    # Plot for Training and Validation Loss
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_losses_all[aug_type], 'b-', label='Training Loss')
    plt.plot(epochs, val_losses_all[aug_type], 'g-', label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training and Validation Loss - {aug_type}')
    plt.legend()
    plt.show()

    # Plot for Training and Validation mIoU
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_mIoUs_all[aug_type], 'b-', label='Training mIoU')
    plt.plot(epochs, val_mIoUs_all[aug_type], 'r-', label='Validation mIoU')
    plt.xlabel('Epoch')
    plt.ylabel('mIoU')
    plt.title(f'Training and Validation mIoU - {aug_type}')
    plt.legend()
    plt.show()
