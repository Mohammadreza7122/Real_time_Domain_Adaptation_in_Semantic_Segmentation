# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np


def poly_lr_scheduler(optimizer, init_lr, iter, lr_decay_iter=1,
                      max_iter=300, power=0.9):
    """Polynomial decay of learning rate
            :param init_lr is base learning rate
            :param iter is a current iteration
            :param lr_decay_iter how frequently decay occurs, default is 1
            :param max_iter is number of maximum iterations
            :param power is a polymomial power

    """
    # if iter % lr_decay_iter or iter > max_iter:
    # 	return optimizer

    lr = init_lr*(1 - iter/max_iter)**power
    optimizer.param_groups[0]['lr'] = lr
    return lr
    # return lr


def fast_hist(a, b, n):
    '''
    a and b are label and prediction respectively
    n is the number of classes
    '''
    k = (a >= 0) & (a < n)
    return np.bincount(n * a[k].astype(int) + b[k], minlength=n ** 2).reshape(n, n)


def per_class_iou(hist):
    epsilon = 1e-5
    return (np.diag(hist)) / (hist.sum(1) + hist.sum(0) - np.diag(hist) + epsilon)

# %%
import torch
from torchvision import models


class resnet18(torch.nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.features = models.resnet18(pretrained=pretrained)
        self.conv1 = self.features.conv1
        self.bn1 = self.features.bn1
        self.relu = self.features.relu
        self.maxpool1 = self.features.maxpool
        self.layer1 = self.features.layer1
        self.layer2 = self.features.layer2
        self.layer3 = self.features.layer3
        self.layer4 = self.features.layer4

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu(self.bn1(x))
        x = self.maxpool1(x)
        feature1 = self.layer1(x)  # 1 / 4
        feature2 = self.layer2(feature1)  # 1 / 8
        feature3 = self.layer3(feature2)  # 1 / 16
        feature4 = self.layer4(feature3)  # 1 / 32
        # global average pooling to build tail
        tail = torch.mean(feature4, 3, keepdim=True)
        tail = torch.mean(tail, 2, keepdim=True)
        return feature3, feature4, tail


class resnet101(torch.nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.features = models.resnet101(pretrained=pretrained)
        self.conv1 = self.features.conv1
        self.bn1 = self.features.bn1
        self.relu = self.features.relu
        self.maxpool1 = self.features.maxpool
        self.layer1 = self.features.layer1
        self.layer2 = self.features.layer2
        self.layer3 = self.features.layer3
        self.layer4 = self.features.layer4

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu(self.bn1(x))
        x = self.maxpool1(x)
        feature1 = self.layer1(x)  # 1 / 4
        feature2 = self.layer2(feature1)  # 1 / 8
        feature3 = self.layer3(feature2)  # 1 / 16
        feature4 = self.layer4(feature3)  # 1 / 32
        # global average pooling to build tail
        tail = torch.mean(feature4, 3, keepdim=True)
        tail = torch.mean(tail, 2, keepdim=True)
        return feature3, feature4, tail


def build_contextpath(name):
    model = {
        'resnet18': resnet18(pretrained=True),
        'resnet101': resnet101(pretrained=True)
    }
    return model[name]

# %%
import torch
from torch import nn
import warnings
warnings.filterwarnings(action='ignore')


class ConvBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size,
                               stride=stride, padding=padding, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, input):
        x = self.conv1(input)
        return self.relu(self.bn(x))


class Spatial_path(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.convblock1 = ConvBlock(in_channels=3, out_channels=64)
        self.convblock2 = ConvBlock(in_channels=64, out_channels=128)
        self.convblock3 = ConvBlock(in_channels=128, out_channels=256)

    def forward(self, input):
        x = self.convblock1(input)
        x = self.convblock2(x)
        x = self.convblock3(x)
        return x


class AttentionRefinementModule(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.sigmoid = nn.Sigmoid()
        self.in_channels = in_channels
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

    def forward(self, input):
        # global average pooling
        x = self.avgpool(input)
        assert self.in_channels == x.size(1), 'in_channels and out_channels should all be {}'.format(x.size(1))
        x = self.conv(x)
        x = self.sigmoid(self.bn(x))
        # x = self.sigmoid(x)
        # channels of input and x should be same
        x = torch.mul(input, x)
        return x


class FeatureFusionModule(torch.nn.Module):
    def __init__(self, num_classes, in_channels):
        super().__init__()
        # self.in_channels = input_1.channels + input_2.channels
        # resnet101 3328 = 256(from spatial path) + 1024(from context path) + 2048(from context path)
        # resnet18  1024 = 256(from spatial path) + 256(from context path) + 512(from context path)
        self.in_channels = in_channels

        self.convblock = ConvBlock(in_channels=self.in_channels, out_channels=num_classes, stride=1)
        self.conv1 = nn.Conv2d(num_classes, num_classes, kernel_size=1)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(num_classes, num_classes, kernel_size=1)
        self.sigmoid = nn.Sigmoid()
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

    def forward(self, input_1, input_2):
        x = torch.cat((input_1, input_2), dim=1)
        assert self.in_channels == x.size(1), 'in_channels of ConvBlock should be {}'.format(x.size(1))
        feature = self.convblock(x)
        x = self.avgpool(feature)

        x = self.relu(self.conv1(x))
        x = self.sigmoid(self.conv2(x))
        x = torch.mul(feature, x)
        x = torch.add(x, feature)
        return x


class BiSeNet(torch.nn.Module):
    def __init__(self, num_classes, context_path):
        super().__init__()
        # build spatial path
        self.saptial_path = Spatial_path()

        # build context path
        self.context_path = build_contextpath(name=context_path)

        # build attention refinement module  for resnet 101
        if context_path == 'resnet101':
            self.attention_refinement_module1 = AttentionRefinementModule(1024, 1024)
            self.attention_refinement_module2 = AttentionRefinementModule(2048, 2048)
            # supervision block
            self.supervision1 = nn.Conv2d(in_channels=1024, out_channels=num_classes, kernel_size=1)
            self.supervision2 = nn.Conv2d(in_channels=2048, out_channels=num_classes, kernel_size=1)
            # build feature fusion module
            self.feature_fusion_module = FeatureFusionModule(num_classes, 3328)

        elif context_path == 'resnet18':
            # build attention refinement module  for resnet 18
            self.attention_refinement_module1 = AttentionRefinementModule(256, 256)
            self.attention_refinement_module2 = AttentionRefinementModule(512, 512)
            # supervision block
            self.supervision1 = nn.Conv2d(in_channels=256, out_channels=num_classes, kernel_size=1)
            self.supervision2 = nn.Conv2d(in_channels=512, out_channels=num_classes, kernel_size=1)
            # build feature fusion module
            self.feature_fusion_module = FeatureFusionModule(num_classes, 1024)
        else:
            print('Error: unspport context_path network \n')

        # build final convolution
        self.conv = nn.Conv2d(in_channels=num_classes, out_channels=num_classes, kernel_size=1)

        self.init_weight()

        self.mul_lr = []
        self.mul_lr.append(self.saptial_path)
        self.mul_lr.append(self.attention_refinement_module1)
        self.mul_lr.append(self.attention_refinement_module2)
        self.mul_lr.append(self.supervision1)
        self.mul_lr.append(self.supervision2)
        self.mul_lr.append(self.feature_fusion_module)
        self.mul_lr.append(self.conv)

    def init_weight(self):
        for name, m in self.named_modules():
            if 'context_path' not in name:
                if isinstance(m, nn.Conv2d):
                    nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                elif isinstance(m, nn.BatchNorm2d):
                    m.eps = 1e-5
                    m.momentum = 0.1
                    nn.init.constant_(m.weight, 1)
                    nn.init.constant_(m.bias, 0)

    def forward(self, input):
        # output of spatial path
        sx = self.saptial_path(input)

        # output of context path
        cx1, cx2, tail = self.context_path(input)
        cx1 = self.attention_refinement_module1(cx1)
        cx2 = self.attention_refinement_module2(cx2)
        cx2 = torch.mul(cx2, tail)
        # upsampling
        cx1 = torch.nn.functional.interpolate(cx1, size=sx.size()[-2:], mode='bilinear')
        cx2 = torch.nn.functional.interpolate(cx2, size=sx.size()[-2:], mode='bilinear')
        cx = torch.cat((cx1, cx2), dim=1)

        if self.training == True:
            cx1_sup = self.supervision1(cx1)
            cx2_sup = self.supervision2(cx2)
            cx1_sup = torch.nn.functional.interpolate(cx1_sup, size=input.size()[-2:], mode='bilinear')
            cx2_sup = torch.nn.functional.interpolate(cx2_sup, size=input.size()[-2:], mode='bilinear')

        # output of feature fusion module
        result = self.feature_fusion_module(sx, cx)

        # upsampling
        result = torch.nn.functional.interpolate(result, scale_factor=8, mode='bilinear')
        result = self.conv(result)

        if self.training == True:
            return result, cx1_sup, cx2_sup

        return result

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from typing import Tuple


class CityScapes(Dataset):
    def __init__(self, root_dir, split='train', transform=None, target_transform=None):
        super(CityScapes, self).__init__()
        self.root_dir = root_dir
        self.split = split
        self.transform = transform
        self.target_transform = target_transform

        self.images_dir = os.path.join(root_dir, 'leftImg8bit', split)
        self.labels_dir = os.path.join(root_dir, 'gtFine', split)

        self.images = []
        self.labels = []

        for city in os.listdir(self.images_dir):
            img_dir = os.path.join(self.images_dir, city)
            lbl_dir = os.path.join(self.labels_dir, city)

            for file_name in os.listdir(img_dir):
                if file_name.endswith('_leftImg8bit.png'):
                    img_path = os.path.join(img_dir, file_name)
                    lbl_path = os.path.join(lbl_dir, file_name.replace('_leftImg8bit.png', '_gtFine_labelTrainIds.png'))

                    if not os.path.exists(img_path):
                        print(f"Image file does not exist: {img_path}")
                    if not os.path.exists(lbl_path):
                        print(f"Label file does not exist: {lbl_path}")

                    self.images.append(img_path)
                    self.labels.append(lbl_path)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        lbl_path = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        label = Image.open(lbl_path)

        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)

        return image, label

    def get_class_names(self):
        return ['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light', 'traffic sign',
                'vegetation', 'terrain', 'sky', 'person', 'rider', 'car', 'truck', 'bus', 'train',
                'motorcycle', 'bicycle']

# %%
import os
from PIL import Image, UnidentifiedImageError
import torch
from torch.utils.data import Dataset
import numpy as np
from torchvision import transforms

class GTA5(Dataset):
    def __init__(self, root_dir, transform=None, target_transform=None):
        super(GTA5, self).__init__()
        self.root_dir = root_dir
        self.transform = transform
        self.target_transform = target_transform

        self.images_dir = os.path.join(self.root_dir, 'images')
        self.labels_dir = os.path.join(self.root_dir, 'labels')

        self.images = []
        self.labels = []

        for image in os.listdir(self.images_dir):
            image_path = os.path.join(self.images_dir, image)
            label_path = os.path.join(self.labels_dir, image)
            if os.path.exists(label_path):
                self.images.append(image_path)
                self.labels.append(label_path)

        # Map from color to corresponding class of Cityscapes
        self.color_to_id = {
            (128, 64, 128): 0,   # road
            (244, 35, 232): 1,   # sidewalk
            (70, 70, 70): 2,     # building
            (102, 102, 156): 3,  # wall
            (190, 153, 153): 4,  # fence
            (153, 153, 153): 5,  # pole
            (250, 170, 30): 6,   # light
            (220, 220, 0): 7,    # sign
            (107, 142, 35): 8,   # vegetation
            (152, 251, 152): 9,  # terrain
            (70, 130, 180): 10,  # sky
            (220, 20, 60): 11,   # person
            (255, 0, 0): 12,     # rider
            (0, 0, 142): 13,     # car
            (0, 0, 70): 14,      # truck
            (0, 60, 100): 15,    # bus
            (0, 80, 100): 16,    # train
            (0, 0, 230): 17,     # motorcycle
            (119, 11, 32): 18    # bicycle
        }

    def __getitem__(self, idx):
        try:
            image = Image.open(self.images[idx]).convert('RGB')
            label = Image.open(self.labels[idx]).convert('RGB')
        except (UnidentifiedImageError, FileNotFoundError) as e:
            print(f"Error loading image {self.images[idx]} or label {self.labels[idx]}, skipping...")
            return self.__getitem__((idx + 1) % len(self.images))

        if self.transform is not None:
            image = self.transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)
            label = self.map_color_to_class(label)

        return image, label

    def __len__(self):
        return len(self.images)

    def map_color_to_class(self, label):
        # Convert the RGB image to a single integer value
        label_int = label[:, :, 0] * 256 * 256 + label[:, :, 1] * 256 + label[:, :, 2]

        # Create a tensor of the same shape as the input image, filled with 255 (the class for 'unlabeled')
        class_id_image = torch.full_like(label_int, 255)

        # Replace each unique color value with the corresponding class
        for color, class_id in self.color_to_id.items():
            color_int = color[0] * 256 * 256 + color[1] * 256 + color[2]
            class_id_image = torch.where(label_int == color_int, class_id, class_id_image)

        return class_id_image

# %%
from torchvision import transforms
from torch.utils.data import DataLoader

gta5_transform = transforms.Compose([
    transforms.Resize((720,1280)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

gta5_target_transform = transforms.Compose([
    transforms.Resize((720,1280), interpolation=Image.NEAREST),
    transforms.Lambda(lambda lbl: torch.tensor(np.array(lbl), dtype=torch.long)),
])

cityscapes_transform = transforms.Compose([
    transforms.Resize((512,1024)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

cityscapes_target_transform = transforms.Compose([
    transforms.Resize((512,1024), interpolation=Image.NEAREST),
    transforms.Lambda(lambda lbl: torch.tensor(np.array(lbl), dtype=torch.long)),
])


#Create Dataloaders for Cityscapes and GTA5
gta5_root ='/content/drive/MyDrive/MLDLMLDL/GTA5'

gta5_dataset = GTA5(gta5_root, transform=gta5_transform, target_transform=gta5_target_transform)

gta5_loader = DataLoader(gta5_dataset, batch_size=8, shuffle=True, num_workers=12)

# Cityscapes Dataset and DataLoader
cityscapes_root = '/content/drive/MyDrive/MLDLMLDL/Cityscapes/Cityscapes/Cityspaces'
cityscapes_dataset = CityScapes(root_dir=cityscapes_root, split='val', transform=cityscapes_transform, target_transform=cityscapes_target_transform)
cityscapes_loader = DataLoader(cityscapes_dataset, batch_size=8, shuffle=False, num_workers=12)

# %%
print(len(gta5_dataset))
print(len(cityscapes_dataset))
# Out:
# 2500
# 500

# %%
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BiSeNet(num_classes=19, context_path='resnet18').to(device)

# Hyperparameters
num_epochs = 50
learning_rate = 2e-2
batch_size = 4
num_classes = 19
# Loss and Optimizer
criterion = nn.CrossEntropyLoss(ignore_index=255)
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

class_names = cityscapes_dataset.get_class_names()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 197MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [00:00<00:00, 227MB/s]

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np

best_mIoU = 0.0
train_losses = []
val_losses = []
train_mIoUs = []
val_mIoUs = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    hist_train = np.zeros((num_classes, num_classes))
    for iter, (images, labels) in enumerate(gta5_loader):
        images = images.to(device)
        labels = labels.to(device).long()

        # Forward pass
        optimizer.zero_grad()
        outputs, _, _ = model(images)  # Extract the first element of the tuple
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Update learning rate
        current_iter = epoch * len(gta5_loader) + iter
        poly_lr_scheduler(optimizer, learning_rate, current_iter, max_iter=num_epochs * len(gta5_loader))

        running_loss += loss.item()

        # Calculate training mIoU
        preds_train = torch.argmax(outputs, dim=1)
        hist_train += fast_hist(labels.cpu().numpy().flatten(), preds_train.cpu().numpy().flatten(), num_classes)

        if (iter + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{iter+1}/{len(gta5_loader)}], Loss: {loss.item():.4f}')

    avg_train_loss = running_loss / len(gta5_loader)
    train_losses.append(avg_train_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_train_loss:.4f}')

    train_mIoUs_epoch = per_class_iou(hist_train)
    avg_train_mIoU = np.mean(train_mIoUs_epoch)
    train_mIoUs.append(avg_train_mIoU)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Mean mIoU: {avg_train_mIoU:.4f}')

    # Validation
    model.eval()
    hist_val = np.zeros((num_classes, num_classes))
    running_val_loss = 0.0
    with torch.no_grad():
        for images, labels in cityscapes_loader:
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)
            preds_val = torch.argmax(outputs, dim=1)
            val_loss = criterion(outputs, labels)
            running_val_loss += val_loss.item()

            hist_val += fast_hist(labels.cpu().numpy().flatten(), preds_val.cpu().numpy().flatten(), num_classes)

    avg_val_loss = running_val_loss / len(cityscapes_loader)
    val_losses.append(avg_val_loss)

    val_mIoUs_epoch = per_class_iou(hist_val)
    avg_val_mIoU = np.mean(val_mIoUs_epoch)
    val_mIoUs.append(avg_val_mIoU)
    print(f'Epoch [{epoch+1}/{num_epochs}], Val Mean mIoU: {avg_val_mIoU:.4f}')
    for i, iou in enumerate(val_mIoUs_epoch):
        print(f'{class_names[i]}: Val mIoU = {iou:.4f}')

    # Save the model if it has the best mIoU so far
    if avg_val_mIoU > best_mIoU:
        best_mIoU = avg_val_mIoU
        torch.save(model.state_dict(), '/content/drive/MyDrive/MLDLMLDL/best_model_3a_Final.pth')
        print(f'Model saved with Mean mIoU: {avg_val_mIoU:.4f}')

    # Clear cache to free up memory
    torch.cuda.empty_cache()
# Out:
# Epoch [1/50], Step [10/313], Loss: 1.2692
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [1/50], Step [20/313], Loss: 0.6533
# Epoch [1/50], Step [30/313], Loss: 0.6227
# Epoch [1/50], Step [40/313], Loss: 0.6193
# Epoch [1/50], Step [50/313], Loss: 0.6459
# Epoch [1/50], Step [60/313], Loss: 0.4914
# Epoch [1/50], Step [70/313], Loss: 0.5211
# Epoch [1/50], Step [80/313], Loss: 0.3969
# Epoch [1/50], Step [90/313], Loss: 0.4861
# Epoch [1/50], Step [100/313], Loss: 0.8638
# Epoch [1/50], Step [110/313], Loss: 0.3672
# Epoch [1/50], Step [120/313], Loss: 0.4382
# Epoch [1/50], Step [130/313], Loss: 0.3635
# Epoch [1/50], Step [140/313], Loss: 0.3960
# Epoch [1/50], Step [150/313], Loss: 0.4314
# Epoch [1/50], Step [160/313], Loss: 0.3300
# Epoch [1/50], Step [170/313], Loss: 0.2971
# Epoch [1/50], Step [180/313], Loss: 0.3451
# Epoch [1/50], Step [190/313], Loss: 0.3715
# Epoch [1/50], Step [200/313], Loss: 0.3172
# Epoch [1/50], Step [210/313], Loss: 0.3769
# Epoch [1/50], Step [220/313], Loss: 0.2836
# Epoch [1/50], Step [230/313], Loss: 0.7795
# Epoch [1/50], Step [240/313], Loss: 0.2677
# Epoch [1/50], Step [250/313], Loss: 0.3305
# Epoch [1/50], Step [260/313], Loss: 0.2833
# Epoch [1/50], Step [270/313], Loss: 0.2902
# Epoch [1/50], Step [280/313], Loss: 0.3514
# Epoch [1/50], Step [290/313], Loss: 0.4009
# Epoch [1/50], Step [300/313], Loss: 0.2702
# Epoch [1/50], Step [310/313], Loss: 0.2893
# Epoch [1/50], Loss: 0.4664
# Epoch [1/50], Train Mean mIoU: 0.3010
# Epoch [1/50], Val Mean mIoU: 0.1833
# road: Val mIoU = 0.6602
# sidewalk: Val mIoU = 0.0653
# building: Val mIoU = 0.6812
# wall: Val mIoU = 0.0709
# fence: Val mIoU = 0.1359
# pole: Val mIoU = 0.0963
# traffic light: Val mIoU = 0.0001
# traffic sign: Val mIoU = 0.0000
# vegetation: Val mIoU = 0.5787
# terrain: Val mIoU = 0.1018
# sky: Val mIoU = 0.6067
# person: Val mIoU = 0.0000
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.4490
# truck: Val mIoU = 0.0359
# bus: Val mIoU = 0.0000
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.1833
# Epoch [2/50], Step [10/313], Loss: 0.3118
# Epoch [2/50], Step [20/313], Loss: 0.2922
# Epoch [2/50], Step [30/313], Loss: 0.3750
# Epoch [2/50], Step [40/313], Loss: 0.1945
# Epoch [2/50], Step [50/313], Loss: 0.2248
# Epoch [2/50], Step [60/313], Loss: 0.2693
# Epoch [2/50], Step [70/313], Loss: 0.2955
# Epoch [2/50], Step [80/313], Loss: 0.2826
# Epoch [2/50], Step [90/313], Loss: 0.2645
# Epoch [2/50], Step [100/313], Loss: 0.2472
# Epoch [2/50], Step [110/313], Loss: 0.2693
# Epoch [2/50], Step [120/313], Loss: 0.2941
# Epoch [2/50], Step [130/313], Loss: 0.2853
# Epoch [2/50], Step [140/313], Loss: 0.2541
# Epoch [2/50], Step [150/313], Loss: 0.3165
# Epoch [2/50], Step [160/313], Loss: 0.2662
# Epoch [2/50], Step [170/313], Loss: 0.2464
# Epoch [2/50], Step [180/313], Loss: 0.2443
# Epoch [2/50], Step [190/313], Loss: 0.3003
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [2/50], Step [200/313], Loss: 0.2481
# Epoch [2/50], Step [210/313], Loss: 0.2879
# Epoch [2/50], Step [220/313], Loss: 0.2531
# Epoch [2/50], Step [230/313], Loss: 0.2413
# Epoch [2/50], Step [240/313], Loss: 0.2347
# Epoch [2/50], Step [250/313], Loss: 0.1967
# Epoch [2/50], Step [260/313], Loss: 0.3250
# Epoch [2/50], Step [270/313], Loss: 0.2402
# Epoch [2/50], Step [280/313], Loss: 0.2072
# Epoch [2/50], Step [290/313], Loss: 0.2170
# Epoch [2/50], Step [300/313], Loss: 0.2203
# Epoch [2/50], Step [310/313], Loss: 0.2460
# Epoch [2/50], Loss: 0.2677
# Epoch [2/50], Train Mean mIoU: 0.4368
# Epoch [2/50], Val Mean mIoU: 0.1767
# road: Val mIoU = 0.2636
# sidewalk: Val mIoU = 0.1434
# building: Val mIoU = 0.6784
# wall: Val mIoU = 0.0368
# fence: Val mIoU = 0.1104
# pole: Val mIoU = 0.1290
# traffic light: Val mIoU = 0.0787
# traffic sign: Val mIoU = 0.0000
# vegetation: Val mIoU = 0.6961
# terrain: Val mIoU = 0.1351
# sky: Val mIoU = 0.5777
# person: Val mIoU = 0.2102
# rider: Val mIoU = 0.0003
# car: Val mIoU = 0.2732
# truck: Val mIoU = 0.0129
# bus: Val mIoU = 0.0102
# train: Val mIoU = 0.0010
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [3/50], Step [10/313], Loss: 0.2162
# Epoch [3/50], Step [20/313], Loss: 0.2151
# Epoch [3/50], Step [30/313], Loss: 0.1985
# Epoch [3/50], Step [40/313], Loss: 0.2312
# Epoch [3/50], Step [50/313], Loss: 0.2535
# Epoch [3/50], Step [60/313], Loss: 0.2616
# Epoch [3/50], Step [70/313], Loss: 0.2230
# Epoch [3/50], Step [80/313], Loss: 0.2125
# Epoch [3/50], Step [90/313], Loss: 0.2142
# Epoch [3/50], Step [100/313], Loss: 0.2521
# Epoch [3/50], Step [110/313], Loss: 0.1964
# Epoch [3/50], Step [120/313], Loss: 0.2126
# Epoch [3/50], Step [130/313], Loss: 0.2845
# Epoch [3/50], Step [140/313], Loss: 0.2508
# Epoch [3/50], Step [150/313], Loss: 0.2612
# Epoch [3/50], Step [160/313], Loss: 0.2290
# Epoch [3/50], Step [170/313], Loss: 0.2105
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [3/50], Step [180/313], Loss: 0.2903
# Epoch [3/50], Step [190/313], Loss: 0.2432
# Epoch [3/50], Step [200/313], Loss: 0.1956
# Epoch [3/50], Step [210/313], Loss: 0.1837
# Epoch [3/50], Step [220/313], Loss: 0.2321
# Epoch [3/50], Step [230/313], Loss: 0.2172
# Epoch [3/50], Step [240/313], Loss: 0.2168
# Epoch [3/50], Step [250/313], Loss: 0.2593
# Epoch [3/50], Step [260/313], Loss: 0.2187
# Epoch [3/50], Step [270/313], Loss: 0.1968
# Epoch [3/50], Step [280/313], Loss: 0.2291
# Epoch [3/50], Step [290/313], Loss: 0.2257
# Epoch [3/50], Step [300/313], Loss: 0.2366
# Epoch [3/50], Step [310/313], Loss: 0.2061
# Epoch [3/50], Loss: 0.2236
# Epoch [3/50], Train Mean mIoU: 0.5101
# Epoch [3/50], Val Mean mIoU: 0.1906
# road: Val mIoU = 0.3116
# sidewalk: Val mIoU = 0.2333
# building: Val mIoU = 0.6958
# wall: Val mIoU = 0.1758
# fence: Val mIoU = 0.0223
# pole: Val mIoU = 0.1098
# traffic light: Val mIoU = 0.0917
# traffic sign: Val mIoU = 0.0208
# vegetation: Val mIoU = 0.7044
# terrain: Val mIoU = 0.1528
# sky: Val mIoU = 0.5648
# person: Val mIoU = 0.1356
# rider: Val mIoU = 0.0216
# car: Val mIoU = 0.3035
# truck: Val mIoU = 0.0110
# bus: Val mIoU = 0.0598
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0059
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.1906
# Epoch [4/50], Step [10/313], Loss: 0.2073
# Epoch [4/50], Step [20/313], Loss: 0.2300
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [4/50], Step [30/313], Loss: 0.1676
# Epoch [4/50], Step [40/313], Loss: 0.1889
# Epoch [4/50], Step [50/313], Loss: 0.1707
# Epoch [4/50], Step [60/313], Loss: 0.1909
# Epoch [4/50], Step [70/313], Loss: 0.1981
# Epoch [4/50], Step [80/313], Loss: 0.1949
# Epoch [4/50], Step [90/313], Loss: 0.2270
# Epoch [4/50], Step [100/313], Loss: 0.2211
# Epoch [4/50], Step [110/313], Loss: 0.1671
# Epoch [4/50], Step [120/313], Loss: 0.2041
# Epoch [4/50], Step [130/313], Loss: 0.1669
# Epoch [4/50], Step [140/313], Loss: 0.2200
# Epoch [4/50], Step [150/313], Loss: 0.2215
# Epoch [4/50], Step [160/313], Loss: 0.1953
# Epoch [4/50], Step [170/313], Loss: 0.1934
# Epoch [4/50], Step [180/313], Loss: 0.1937
# Epoch [4/50], Step [190/313], Loss: 0.2089
# Epoch [4/50], Step [200/313], Loss: 0.1706
# Epoch [4/50], Step [210/313], Loss: 0.1776
# Epoch [4/50], Step [220/313], Loss: 0.1776
# Epoch [4/50], Step [230/313], Loss: 0.2006
# Epoch [4/50], Step [240/313], Loss: 0.1982
# Epoch [4/50], Step [250/313], Loss: 0.1919
# Epoch [4/50], Step [260/313], Loss: 0.1806
# Epoch [4/50], Step [270/313], Loss: 0.1935
# Epoch [4/50], Step [280/313], Loss: 0.1956
# Epoch [4/50], Step [290/313], Loss: 0.1661
# Epoch [4/50], Step [300/313], Loss: 0.1467
# Epoch [4/50], Step [310/313], Loss: 0.1888
# Epoch [4/50], Loss: 0.1966
# Epoch [4/50], Train Mean mIoU: 0.5760
# Epoch [4/50], Val Mean mIoU: 0.1626
# road: Val mIoU = 0.1745
# sidewalk: Val mIoU = 0.0975
# building: Val mIoU = 0.6403
# wall: Val mIoU = 0.1356
# fence: Val mIoU = 0.0562
# pole: Val mIoU = 0.1251
# traffic light: Val mIoU = 0.1022
# traffic sign: Val mIoU = 0.0656
# vegetation: Val mIoU = 0.5497
# terrain: Val mIoU = 0.0715
# sky: Val mIoU = 0.5869
# person: Val mIoU = 0.1856
# rider: Val mIoU = 0.0220
# car: Val mIoU = 0.2671
# truck: Val mIoU = 0.0088
# bus: Val mIoU = 0.0008
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [5/50], Step [10/313], Loss: 0.1892
# Epoch [5/50], Step [20/313], Loss: 0.1809
# Epoch [5/50], Step [30/313], Loss: 0.1515
# Epoch [5/50], Step [40/313], Loss: 0.2338
# Epoch [5/50], Step [50/313], Loss: 0.1575
# Epoch [5/50], Step [60/313], Loss: 0.1799
# Epoch [5/50], Step [70/313], Loss: 0.1451
# Epoch [5/50], Step [80/313], Loss: 0.2278
# Epoch [5/50], Step [90/313], Loss: 0.1564
# Epoch [5/50], Step [100/313], Loss: 0.2176
# Epoch [5/50], Step [110/313], Loss: 0.1914
# Epoch [5/50], Step [120/313], Loss: 0.1791
# Epoch [5/50], Step [130/313], Loss: 0.2016
# Epoch [5/50], Step [140/313], Loss: 0.1630
# Epoch [5/50], Step [150/313], Loss: 0.1625
# Epoch [5/50], Step [160/313], Loss: 0.1748
# Epoch [5/50], Step [170/313], Loss: 0.1866
# Epoch [5/50], Step [180/313], Loss: 0.1637
# Epoch [5/50], Step [190/313], Loss: 0.1853
# Epoch [5/50], Step [200/313], Loss: 0.1657
# Epoch [5/50], Step [210/313], Loss: 0.1792
# Epoch [5/50], Step [220/313], Loss: 0.1808
# Epoch [5/50], Step [230/313], Loss: 0.1856
# Epoch [5/50], Step [240/313], Loss: 0.1683
# Epoch [5/50], Step [250/313], Loss: 0.1636
# Epoch [5/50], Step [260/313], Loss: 0.1910
# Epoch [5/50], Step [270/313], Loss: 0.1553
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [5/50], Step [280/313], Loss: 0.1702
# Epoch [5/50], Step [290/313], Loss: 0.1780
# Epoch [5/50], Step [300/313], Loss: 0.1708
# Epoch [5/50], Step [310/313], Loss: 0.1533
# Epoch [5/50], Loss: 0.1767
# Epoch [5/50], Train Mean mIoU: 0.6160
# Epoch [5/50], Val Mean mIoU: 0.1812
# road: Val mIoU = 0.3030
# sidewalk: Val mIoU = 0.1642
# building: Val mIoU = 0.6193
# wall: Val mIoU = 0.0717
# fence: Val mIoU = 0.0164
# pole: Val mIoU = 0.1309
# traffic light: Val mIoU = 0.1380
# traffic sign: Val mIoU = 0.0361
# vegetation: Val mIoU = 0.6402
# terrain: Val mIoU = 0.1016
# sky: Val mIoU = 0.6389
# person: Val mIoU = 0.2002
# rider: Val mIoU = 0.0533
# car: Val mIoU = 0.3054
# truck: Val mIoU = 0.0147
# bus: Val mIoU = 0.0015
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0082
# bicycle: Val mIoU = 0.0000
# Epoch [6/50], Step [10/313], Loss: 0.1744
# Epoch [6/50], Step [20/313], Loss: 0.1920
# Epoch [6/50], Step [30/313], Loss: 0.1283
# Epoch [6/50], Step [40/313], Loss: 0.1640
# Epoch [6/50], Step [50/313], Loss: 0.1633
# Epoch [6/50], Step [60/313], Loss: 0.1401
# Epoch [6/50], Step [70/313], Loss: 0.1431
# Epoch [6/50], Step [80/313], Loss: 0.1360
# Epoch [6/50], Step [90/313], Loss: 0.1714
# Epoch [6/50], Step [100/313], Loss: 0.1679
# Epoch [6/50], Step [110/313], Loss: 0.1392
# Epoch [6/50], Step [120/313], Loss: 0.1916
# Epoch [6/50], Step [130/313], Loss: 0.1763
# Epoch [6/50], Step [140/313], Loss: 0.1686
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [6/50], Step [150/313], Loss: 0.1535
# Epoch [6/50], Step [160/313], Loss: 0.1933
# Epoch [6/50], Step [170/313], Loss: 0.1478
# Epoch [6/50], Step [180/313], Loss: 0.1703
# Epoch [6/50], Step [190/313], Loss: 0.1995
# Epoch [6/50], Step [200/313], Loss: 0.1636
# Epoch [6/50], Step [210/313], Loss: 0.1543
# Epoch [6/50], Step [220/313], Loss: 0.1630
# Epoch [6/50], Step [230/313], Loss: 0.1533
# Epoch [6/50], Step [240/313], Loss: 0.1481
# Epoch [6/50], Step [250/313], Loss: 0.1464
# Epoch [6/50], Step [260/313], Loss: 0.1419
# Epoch [6/50], Step [270/313], Loss: 0.1365
# Epoch [6/50], Step [280/313], Loss: 0.1506
# Epoch [6/50], Step [290/313], Loss: 0.1718
# Epoch [6/50], Step [300/313], Loss: 0.1893
# Epoch [6/50], Step [310/313], Loss: 0.1597
# Epoch [6/50], Loss: 0.1654
# Epoch [6/50], Train Mean mIoU: 0.6397
# Epoch [6/50], Val Mean mIoU: 0.1907
# road: Val mIoU = 0.4352
# sidewalk: Val mIoU = 0.0938
# building: Val mIoU = 0.6702
# wall: Val mIoU = 0.0553
# fence: Val mIoU = 0.0396
# pole: Val mIoU = 0.1293
# traffic light: Val mIoU = 0.1286
# traffic sign: Val mIoU = 0.0554
# vegetation: Val mIoU = 0.6450
# terrain: Val mIoU = 0.0714
# sky: Val mIoU = 0.5975
# person: Val mIoU = 0.2199
# rider: Val mIoU = 0.0738
# car: Val mIoU = 0.3467
# truck: Val mIoU = 0.0274
# bus: Val mIoU = 0.0191
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0149
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.1907
# Epoch [7/50], Step [10/313], Loss: 0.1657
# Epoch [7/50], Step [20/313], Loss: 0.1888
# Epoch [7/50], Step [30/313], Loss: 0.1289
# Epoch [7/50], Step [40/313], Loss: 0.1575
# Epoch [7/50], Step [50/313], Loss: 0.1420
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...Epoch [7/50], Step [60/313], Loss: 0.1805
#
# Epoch [7/50], Step [70/313], Loss: 0.1661
# Epoch [7/50], Step [80/313], Loss: 0.1562
# Epoch [7/50], Step [90/313], Loss: 0.1496
# Epoch [7/50], Step [100/313], Loss: 0.1915
# Epoch [7/50], Step [110/313], Loss: 0.2012
# Epoch [7/50], Step [120/313], Loss: 0.1707
# Epoch [7/50], Step [130/313], Loss: 0.1627
# Epoch [7/50], Step [140/313], Loss: 0.1334
# Epoch [7/50], Step [150/313], Loss: 0.1544
# Epoch [7/50], Step [160/313], Loss: 0.1555
# Epoch [7/50], Step [170/313], Loss: 0.1544
# Epoch [7/50], Step [180/313], Loss: 0.1490
# Epoch [7/50], Step [190/313], Loss: 0.1690
# Epoch [7/50], Step [200/313], Loss: 0.1721
# Epoch [7/50], Step [210/313], Loss: 0.1338
# Epoch [7/50], Step [220/313], Loss: 0.1333
# Epoch [7/50], Step [230/313], Loss: 0.1626
# Epoch [7/50], Step [240/313], Loss: 0.1878
# Epoch [7/50], Step [250/313], Loss: 0.1157
# Epoch [7/50], Step [260/313], Loss: 0.1792
# Epoch [7/50], Step [270/313], Loss: 0.1717
# Epoch [7/50], Step [280/313], Loss: 0.1532
# Epoch [7/50], Step [290/313], Loss: 0.1269
# Epoch [7/50], Step [300/313], Loss: 0.1284
# Epoch [7/50], Step [310/313], Loss: 0.1340
# Epoch [7/50], Loss: 0.1561
# Epoch [7/50], Train Mean mIoU: 0.6642
# Epoch [7/50], Val Mean mIoU: 0.1928
# road: Val mIoU = 0.3393
# sidewalk: Val mIoU = 0.1022
# building: Val mIoU = 0.6878
# wall: Val mIoU = 0.1006
# fence: Val mIoU = 0.0576
# pole: Val mIoU = 0.1637
# traffic light: Val mIoU = 0.1249
# traffic sign: Val mIoU = 0.0769
# vegetation: Val mIoU = 0.6829
# terrain: Val mIoU = 0.0755
# sky: Val mIoU = 0.6039
# person: Val mIoU = 0.2220
# rider: Val mIoU = 0.0498
# car: Val mIoU = 0.3297
# truck: Val mIoU = 0.0134
# bus: Val mIoU = 0.0267
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0065
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.1928
# Epoch [8/50], Step [10/313], Loss: 0.1472
# Epoch [8/50], Step [20/313], Loss: 0.1223
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [8/50], Step [30/313], Loss: 0.1486
# Epoch [8/50], Step [40/313], Loss: 0.1711
# Epoch [8/50], Step [50/313], Loss: 0.1505
# Epoch [8/50], Step [60/313], Loss: 0.1507
# Epoch [8/50], Step [70/313], Loss: 0.1240
# Epoch [8/50], Step [80/313], Loss: 0.1328
# Epoch [8/50], Step [90/313], Loss: 0.1320
# Epoch [8/50], Step [100/313], Loss: 0.1376
# Epoch [8/50], Step [110/313], Loss: 0.1468
# Epoch [8/50], Step [120/313], Loss: 0.1552
# Epoch [8/50], Step [130/313], Loss: 0.1855
# Epoch [8/50], Step [140/313], Loss: 0.1313
# Epoch [8/50], Step [150/313], Loss: 0.1555
# Epoch [8/50], Step [160/313], Loss: 0.1508
# Epoch [8/50], Step [170/313], Loss: 0.1395
# Epoch [8/50], Step [180/313], Loss: 0.1377
# Epoch [8/50], Step [190/313], Loss: 0.1241
# Epoch [8/50], Step [200/313], Loss: 0.1440
# Epoch [8/50], Step [210/313], Loss: 0.1399
# Epoch [8/50], Step [220/313], Loss: 0.1346
# Epoch [8/50], Step [230/313], Loss: 0.1580
# Epoch [8/50], Step [240/313], Loss: 0.1247
# Epoch [8/50], Step [250/313], Loss: 0.1629
# Epoch [8/50], Step [260/313], Loss: 0.1597
# Epoch [8/50], Step [270/313], Loss: 0.1487
# Epoch [8/50], Step [280/313], Loss: 0.1404
# Epoch [8/50], Step [290/313], Loss: 0.1263
# Epoch [8/50], Step [300/313], Loss: 0.1034
# Epoch [8/50], Step [310/313], Loss: 0.1587
# Epoch [8/50], Loss: 0.1476
# Epoch [8/50], Train Mean mIoU: 0.6816
# Epoch [8/50], Val Mean mIoU: 0.1915
# road: Val mIoU = 0.3825
# sidewalk: Val mIoU = 0.1212
# building: Val mIoU = 0.6008
# wall: Val mIoU = 0.1335
# fence: Val mIoU = 0.0869
# pole: Val mIoU = 0.1446
# traffic light: Val mIoU = 0.1138
# traffic sign: Val mIoU = 0.0437
# vegetation: Val mIoU = 0.6529
# terrain: Val mIoU = 0.0980
# sky: Val mIoU = 0.6179
# person: Val mIoU = 0.2350
# rider: Val mIoU = 0.0058
# car: Val mIoU = 0.3647
# truck: Val mIoU = 0.0143
# bus: Val mIoU = 0.0221
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [9/50], Step [10/313], Loss: 0.1455
# Epoch [9/50], Step [20/313], Loss: 0.1145
# Epoch [9/50], Step [30/313], Loss: 0.1447
# Epoch [9/50], Step [40/313], Loss: 0.1414
# Epoch [9/50], Step [50/313], Loss: 0.1247
# Epoch [9/50], Step [60/313], Loss: 0.1316
# Epoch [9/50], Step [70/313], Loss: 0.1367
# Epoch [9/50], Step [80/313], Loss: 0.1425
# Epoch [9/50], Step [90/313], Loss: 0.1547
# Epoch [9/50], Step [100/313], Loss: 0.1383
# Epoch [9/50], Step [110/313], Loss: 0.1255
# Epoch [9/50], Step [120/313], Loss: 0.1630
# Epoch [9/50], Step [130/313], Loss: 0.1526
# Epoch [9/50], Step [140/313], Loss: 0.1565
# Epoch [9/50], Step [150/313], Loss: 0.1365
# Epoch [9/50], Step [160/313], Loss: 0.1498
# Epoch [9/50], Step [170/313], Loss: 0.1386
# Epoch [9/50], Step [180/313], Loss: 0.1489
# Epoch [9/50], Step [190/313], Loss: 0.1285
# Epoch [9/50], Step [200/313], Loss: 0.1486
# Epoch [9/50], Step [210/313], Loss: 0.1853
# Epoch [9/50], Step [220/313], Loss: 0.1675
# Epoch [9/50], Step [230/313], Loss: 0.1323
# Epoch [9/50], Step [240/313], Loss: 0.1498
# Epoch [9/50], Step [250/313], Loss: 0.1193
# Epoch [9/50], Step [260/313], Loss: 0.1319
# Epoch [9/50], Step [270/313], Loss: 0.1354
# Epoch [9/50], Step [280/313], Loss: 0.1698
# Epoch [9/50], Step [290/313], Loss: 0.1300
# Epoch [9/50], Step [300/313], Loss: 0.1380
# Epoch [9/50], Step [310/313], Loss: 0.1465
# Epoch [9/50], Loss: 0.1419
# Epoch [9/50], Train Mean mIoU: 0.6959
# Epoch [9/50], Val Mean mIoU: 0.1834
# road: Val mIoU = 0.3458
# sidewalk: Val mIoU = 0.0516
# building: Val mIoU = 0.6661
# wall: Val mIoU = 0.0947
# fence: Val mIoU = 0.0620
# pole: Val mIoU = 0.1323
# traffic light: Val mIoU = 0.1281
# traffic sign: Val mIoU = 0.0677
# vegetation: Val mIoU = 0.6335
# terrain: Val mIoU = 0.0526
# sky: Val mIoU = 0.6363
# person: Val mIoU = 0.1665
# rider: Val mIoU = 0.0255
# car: Val mIoU = 0.3838
# truck: Val mIoU = 0.0139
# bus: Val mIoU = 0.0245
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [10/50], Step [10/313], Loss: 0.1300
# Epoch [10/50], Step [20/313], Loss: 0.1364
# Epoch [10/50], Step [30/313], Loss: 0.1406
# Epoch [10/50], Step [40/313], Loss: 0.1543
# Epoch [10/50], Step [50/313], Loss: 0.1205
# Epoch [10/50], Step [60/313], Loss: 0.1364
# Epoch [10/50], Step [70/313], Loss: 0.1532
# Epoch [10/50], Step [80/313], Loss: 0.1158
# Epoch [10/50], Step [90/313], Loss: 0.1502
# Epoch [10/50], Step [100/313], Loss: 0.1449
# Epoch [10/50], Step [110/313], Loss: 0.1188
# Epoch [10/50], Step [120/313], Loss: 0.1337
# Epoch [10/50], Step [130/313], Loss: 0.1176
# Epoch [10/50], Step [140/313], Loss: 0.1466
# Epoch [10/50], Step [150/313], Loss: 0.1353
# Epoch [10/50], Step [160/313], Loss: 0.1436
# Epoch [10/50], Step [170/313], Loss: 0.1413
# Epoch [10/50], Step [180/313], Loss: 0.1346
# Epoch [10/50], Step [190/313], Loss: 0.1407
# Epoch [10/50], Step [200/313], Loss: 0.1685
# Epoch [10/50], Step [210/313], Loss: 0.1469
# Epoch [10/50], Step [220/313], Loss: 0.1443
# Epoch [10/50], Step [230/313], Loss: 0.1213
# Epoch [10/50], Step [240/313], Loss: 0.1457
# Epoch [10/50], Step [250/313], Loss: 0.1394
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [10/50], Step [260/313], Loss: 0.1151
# Epoch [10/50], Step [270/313], Loss: 0.1314
# Epoch [10/50], Step [280/313], Loss: 0.1386
# Epoch [10/50], Step [290/313], Loss: 0.1454
# Epoch [10/50], Step [300/313], Loss: 0.1155
# Epoch [10/50], Step [310/313], Loss: 0.1623
# Epoch [10/50], Loss: 0.1364
# Epoch [10/50], Train Mean mIoU: 0.7024
# Epoch [10/50], Val Mean mIoU: 0.1918
# road: Val mIoU = 0.4559
# sidewalk: Val mIoU = 0.0828
# building: Val mIoU = 0.6408
# wall: Val mIoU = 0.0852
# fence: Val mIoU = 0.0587
# pole: Val mIoU = 0.1194
# traffic light: Val mIoU = 0.1335
# traffic sign: Val mIoU = 0.0850
# vegetation: Val mIoU = 0.6368
# terrain: Val mIoU = 0.0712
# sky: Val mIoU = 0.6207
# person: Val mIoU = 0.2253
# rider: Val mIoU = 0.0451
# car: Val mIoU = 0.3377
# truck: Val mIoU = 0.0179
# bus: Val mIoU = 0.0220
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0066
# bicycle: Val mIoU = 0.0003
# Epoch [11/50], Step [10/313], Loss: 0.1490
# Epoch [11/50], Step [20/313], Loss: 0.1051
# Epoch [11/50], Step [30/313], Loss: 0.1431
# Epoch [11/50], Step [40/313], Loss: 0.1401
# Epoch [11/50], Step [50/313], Loss: 0.1277
# Epoch [11/50], Step [60/313], Loss: 0.1227
# Epoch [11/50], Step [70/313], Loss: 0.0989
# Epoch [11/50], Step [80/313], Loss: 0.1267
# Epoch [11/50], Step [90/313], Loss: 0.1281
# Epoch [11/50], Step [100/313], Loss: 0.1555
# Epoch [11/50], Step [110/313], Loss: 0.1282
# Epoch [11/50], Step [120/313], Loss: 0.1249
# Epoch [11/50], Step [130/313], Loss: 0.1279
# Epoch [11/50], Step [140/313], Loss: 0.1229
# Epoch [11/50], Step [150/313], Loss: 0.1393
# Epoch [11/50], Step [160/313], Loss: 0.1177
# Epoch [11/50], Step [170/313], Loss: 0.1224
# Epoch [11/50], Step [180/313], Loss: 0.1338
# Epoch [11/50], Step [190/313], Loss: 0.1434
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [11/50], Step [200/313], Loss: 0.1294
# Epoch [11/50], Step [210/313], Loss: 0.1551
# Epoch [11/50], Step [220/313], Loss: 0.1062
# Epoch [11/50], Step [230/313], Loss: 0.1361
# Epoch [11/50], Step [240/313], Loss: 0.1485
# Epoch [11/50], Step [250/313], Loss: 0.1316
# Epoch [11/50], Step [260/313], Loss: 0.1294
# Epoch [11/50], Step [270/313], Loss: 0.1367
# Epoch [11/50], Step [280/313], Loss: 0.1503
# Epoch [11/50], Step [290/313], Loss: 0.1339
# Epoch [11/50], Step [300/313], Loss: 0.1265
# Epoch [11/50], Step [310/313], Loss: 0.1158
# Epoch [11/50], Loss: 0.1321
# Epoch [11/50], Train Mean mIoU: 0.7110
# Epoch [11/50], Val Mean mIoU: 0.1855
# road: Val mIoU = 0.3747
# sidewalk: Val mIoU = 0.0865
# building: Val mIoU = 0.6104
# wall: Val mIoU = 0.1189
# fence: Val mIoU = 0.0522
# pole: Val mIoU = 0.1329
# traffic light: Val mIoU = 0.1351
# traffic sign: Val mIoU = 0.0566
# vegetation: Val mIoU = 0.6553
# terrain: Val mIoU = 0.0670
# sky: Val mIoU = 0.6307
# person: Val mIoU = 0.1855
# rider: Val mIoU = 0.0049
# car: Val mIoU = 0.3692
# truck: Val mIoU = 0.0127
# bus: Val mIoU = 0.0304
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0024
# bicycle: Val mIoU = 0.0000
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [12/50], Step [10/313], Loss: 0.1159
# Epoch [12/50], Step [20/313], Loss: 0.1252
# Epoch [12/50], Step [30/313], Loss: 0.1330
# Epoch [12/50], Step [40/313], Loss: 0.0970
# Epoch [12/50], Step [50/313], Loss: 0.1218
# Epoch [12/50], Step [60/313], Loss: 0.1303
# Epoch [12/50], Step [70/313], Loss: 0.1260
# Epoch [12/50], Step [80/313], Loss: 0.1244
# Epoch [12/50], Step [90/313], Loss: 0.1260
# Epoch [12/50], Step [100/313], Loss: 0.1119
# Epoch [12/50], Step [110/313], Loss: 0.1256
# Epoch [12/50], Step [120/313], Loss: 0.1164
# Epoch [12/50], Step [130/313], Loss: 0.1304
# Epoch [12/50], Step [140/313], Loss: 0.1348
# Epoch [12/50], Step [150/313], Loss: 0.1175
# Epoch [12/50], Step [160/313], Loss: 0.1220
# Epoch [12/50], Step [170/313], Loss: 0.1292
# Epoch [12/50], Step [180/313], Loss: 0.1209
# Epoch [12/50], Step [190/313], Loss: 0.1357
# Epoch [12/50], Step [200/313], Loss: 0.1160
# Epoch [12/50], Step [210/313], Loss: 0.1195
# Epoch [12/50], Step [220/313], Loss: 0.1154
# Epoch [12/50], Step [230/313], Loss: 0.1207
# Epoch [12/50], Step [240/313], Loss: 0.1178
# Epoch [12/50], Step [250/313], Loss: 0.1440
# Epoch [12/50], Step [260/313], Loss: 0.1356
# Epoch [12/50], Step [270/313], Loss: 0.1341
# Epoch [12/50], Step [280/313], Loss: 0.1258
# Epoch [12/50], Step [290/313], Loss: 0.1446
# Epoch [12/50], Step [300/313], Loss: 0.1361
# Epoch [12/50], Step [310/313], Loss: 0.1339
# Epoch [12/50], Loss: 0.1285
# Epoch [12/50], Train Mean mIoU: 0.7184
# Epoch [12/50], Val Mean mIoU: 0.1832
# road: Val mIoU = 0.3318
# sidewalk: Val mIoU = 0.1115
# building: Val mIoU = 0.5785
# wall: Val mIoU = 0.1029
# fence: Val mIoU = 0.0502
# pole: Val mIoU = 0.1405
# traffic light: Val mIoU = 0.1244
# traffic sign: Val mIoU = 0.0465
# vegetation: Val mIoU = 0.6652
# terrain: Val mIoU = 0.0702
# sky: Val mIoU = 0.6124
# person: Val mIoU = 0.2058
# rider: Val mIoU = 0.0045
# car: Val mIoU = 0.4026
# truck: Val mIoU = 0.0116
# bus: Val mIoU = 0.0222
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [13/50], Step [10/313], Loss: 0.1106
# Epoch [13/50], Step [20/313], Loss: 0.1495
# Epoch [13/50], Step [30/313], Loss: 0.1317
# Epoch [13/50], Step [40/313], Loss: 0.1186
# Epoch [13/50], Step [50/313], Loss: 0.1189
# Epoch [13/50], Step [60/313], Loss: 0.1324
# Epoch [13/50], Step [70/313], Loss: 0.1145
# Epoch [13/50], Step [80/313], Loss: 0.1152
# Epoch [13/50], Step [90/313], Loss: 0.1372
# Epoch [13/50], Step [100/313], Loss: 0.1314
# Epoch [13/50], Step [110/313], Loss: 0.1222
# Epoch [13/50], Step [120/313], Loss: 0.1640
# Epoch [13/50], Step [130/313], Loss: 0.1178
# Epoch [13/50], Step [140/313], Loss: 0.1346
# Epoch [13/50], Step [150/313], Loss: 0.1252
# Epoch [13/50], Step [160/313], Loss: 0.1477
# Epoch [13/50], Step [170/313], Loss: 0.1204
# Epoch [13/50], Step [180/313], Loss: 0.1252
# Epoch [13/50], Step [190/313], Loss: 0.1004
# Epoch [13/50], Step [200/313], Loss: 0.1413
# Epoch [13/50], Step [210/313], Loss: 0.1329
# Epoch [13/50], Step [220/313], Loss: 0.1277
# Epoch [13/50], Step [230/313], Loss: 0.1187
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [13/50], Step [240/313], Loss: 0.1300
# Epoch [13/50], Step [250/313], Loss: 0.1205
# Epoch [13/50], Step [260/313], Loss: 0.1045
# Epoch [13/50], Step [270/313], Loss: 0.1346
# Epoch [13/50], Step [280/313], Loss: 0.1375
# Epoch [13/50], Step [290/313], Loss: 0.1238
# Epoch [13/50], Step [300/313], Loss: 0.1271
# Epoch [13/50], Step [310/313], Loss: 0.1182
# Epoch [13/50], Loss: 0.1249
# Epoch [13/50], Train Mean mIoU: 0.7250
# Epoch [13/50], Val Mean mIoU: 0.1917
# road: Val mIoU = 0.4472
# sidewalk: Val mIoU = 0.0917
# building: Val mIoU = 0.6289
# wall: Val mIoU = 0.1119
# fence: Val mIoU = 0.0641
# pole: Val mIoU = 0.1533
# traffic light: Val mIoU = 0.1249
# traffic sign: Val mIoU = 0.0588
# vegetation: Val mIoU = 0.6897
# terrain: Val mIoU = 0.0803
# sky: Val mIoU = 0.6457
# person: Val mIoU = 0.1699
# rider: Val mIoU = 0.0075
# car: Val mIoU = 0.3390
# truck: Val mIoU = 0.0122
# bus: Val mIoU = 0.0160
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0003
# bicycle: Val mIoU = 0.0000
# Epoch [14/50], Step [10/313], Loss: 0.1111
# Epoch [14/50], Step [20/313], Loss: 0.1160
# Epoch [14/50], Step [30/313], Loss: 0.1160
# Epoch [14/50], Step [40/313], Loss: 0.1135
# Epoch [14/50], Step [50/313], Loss: 0.1287
# Epoch [14/50], Step [60/313], Loss: 0.1195
# Epoch [14/50], Step [70/313], Loss: 0.1416
# Epoch [14/50], Step [80/313], Loss: 0.1234
# Epoch [14/50], Step [90/313], Loss: 0.1140
# Epoch [14/50], Step [100/313], Loss: 0.1318
# Epoch [14/50], Step [110/313], Loss: 0.1392
# Epoch [14/50], Step [120/313], Loss: 0.1357
# Epoch [14/50], Step [130/313], Loss: 0.1146
# Epoch [14/50], Step [140/313], Loss: 0.1199
# Epoch [14/50], Step [150/313], Loss: 0.1011
# Epoch [14/50], Step [160/313], Loss: 0.1306
# Epoch [14/50], Step [170/313], Loss: 0.1167
# Epoch [14/50], Step [180/313], Loss: 0.1200
# Epoch [14/50], Step [190/313], Loss: 0.0987
# Epoch [14/50], Step [200/313], Loss: 0.1083
# Epoch [14/50], Step [210/313], Loss: 0.1214
# Epoch [14/50], Step [220/313], Loss: 0.1066
# Epoch [14/50], Step [230/313], Loss: 0.1215
# Epoch [14/50], Step [240/313], Loss: 0.1112
# Epoch [14/50], Step [250/313], Loss: 0.1153
# Epoch [14/50], Step [260/313], Loss: 0.1168
# Epoch [14/50], Step [270/313], Loss: 0.1348
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [14/50], Step [280/313], Loss: 0.1574
# Epoch [14/50], Step [290/313], Loss: 0.1037
# Epoch [14/50], Step [300/313], Loss: 0.1183
# Epoch [14/50], Step [310/313], Loss: 0.1282
# Epoch [14/50], Loss: 0.1219
# Epoch [14/50], Train Mean mIoU: 0.7296
# Epoch [14/50], Val Mean mIoU: 0.1852
# road: Val mIoU = 0.3818
# sidewalk: Val mIoU = 0.0730
# building: Val mIoU = 0.5906
# wall: Val mIoU = 0.1010
# fence: Val mIoU = 0.0599
# pole: Val mIoU = 0.1354
# traffic light: Val mIoU = 0.1308
# traffic sign: Val mIoU = 0.0595
# vegetation: Val mIoU = 0.6752
# terrain: Val mIoU = 0.0708
# sky: Val mIoU = 0.6353
# person: Val mIoU = 0.2027
# rider: Val mIoU = 0.0029
# car: Val mIoU = 0.3674
# truck: Val mIoU = 0.0100
# bus: Val mIoU = 0.0230
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [15/50], Step [10/313], Loss: 0.1311
# Epoch [15/50], Step [20/313], Loss: 0.1293
# Epoch [15/50], Step [30/313], Loss: 0.1227
# Epoch [15/50], Step [40/313], Loss: 0.1502
# Epoch [15/50], Step [50/313], Loss: 0.1158
# Epoch [15/50], Step [60/313], Loss: 0.1148
# Epoch [15/50], Step [70/313], Loss: 0.1333
# Epoch [15/50], Step [80/313], Loss: 0.1468
# Epoch [15/50], Step [90/313], Loss: 0.1079
# Epoch [15/50], Step [100/313], Loss: 0.1223
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [15/50], Step [110/313], Loss: 0.1592
# Epoch [15/50], Step [120/313], Loss: 0.1121
# Epoch [15/50], Step [130/313], Loss: 0.1115
# Epoch [15/50], Step [140/313], Loss: 0.1249
# Epoch [15/50], Step [150/313], Loss: 0.1352
# Epoch [15/50], Step [160/313], Loss: 0.1020
# Epoch [15/50], Step [170/313], Loss: 0.1435
# Epoch [15/50], Step [180/313], Loss: 0.1287
# Epoch [15/50], Step [190/313], Loss: 0.1198
# Epoch [15/50], Step [200/313], Loss: 0.1167
# Epoch [15/50], Step [210/313], Loss: 0.1142
# Epoch [15/50], Step [220/313], Loss: 0.1397
# Epoch [15/50], Step [230/313], Loss: 0.1123
# Epoch [15/50], Step [240/313], Loss: 0.1323
# Epoch [15/50], Step [250/313], Loss: 0.1242
# Epoch [15/50], Step [260/313], Loss: 0.1147
# Epoch [15/50], Step [270/313], Loss: 0.1289
# Epoch [15/50], Step [280/313], Loss: 0.1225
# Epoch [15/50], Step [290/313], Loss: 0.1472
# Epoch [15/50], Step [300/313], Loss: 0.1269
# Epoch [15/50], Step [310/313], Loss: 0.1207
# Epoch [15/50], Loss: 0.1201
# Epoch [15/50], Train Mean mIoU: 0.7339
# Epoch [15/50], Val Mean mIoU: 0.1967
# road: Val mIoU = 0.4379
# sidewalk: Val mIoU = 0.0919
# building: Val mIoU = 0.6800
# wall: Val mIoU = 0.0910
# fence: Val mIoU = 0.0715
# pole: Val mIoU = 0.1531
# traffic light: Val mIoU = 0.1430
# traffic sign: Val mIoU = 0.0456
# vegetation: Val mIoU = 0.6708
# terrain: Val mIoU = 0.0560
# sky: Val mIoU = 0.6489
# person: Val mIoU = 0.1637
# rider: Val mIoU = 0.0077
# car: Val mIoU = 0.4377
# truck: Val mIoU = 0.0151
# bus: Val mIoU = 0.0230
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0001
# Model saved with Mean mIoU: 0.1967
# Epoch [16/50], Step [10/313], Loss: 0.1239
# Epoch [16/50], Step [20/313], Loss: 0.1218
# Epoch [16/50], Step [30/313], Loss: 0.1083
# Epoch [16/50], Step [40/313], Loss: 0.1149
# Epoch [16/50], Step [50/313], Loss: 0.0996
# Epoch [16/50], Step [60/313], Loss: 0.1443
# Epoch [16/50], Step [70/313], Loss: 0.1200
# Epoch [16/50], Step [80/313], Loss: 0.1022
# Epoch [16/50], Step [90/313], Loss: 0.1186
# Epoch [16/50], Step [100/313], Loss: 0.1164
# Epoch [16/50], Step [110/313], Loss: 0.1152
# Epoch [16/50], Step [120/313], Loss: 0.1211
# Epoch [16/50], Step [130/313], Loss: 0.1214
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [16/50], Step [140/313], Loss: 0.1310
# Epoch [16/50], Step [150/313], Loss: 0.1264
# Epoch [16/50], Step [160/313], Loss: 0.1258
# Epoch [16/50], Step [170/313], Loss: 0.1154
# Epoch [16/50], Step [180/313], Loss: 0.1244
# Epoch [16/50], Step [190/313], Loss: 0.1089
# Epoch [16/50], Step [200/313], Loss: 0.1081
# Epoch [16/50], Step [210/313], Loss: 0.1130
# Epoch [16/50], Step [220/313], Loss: 0.1080
# Epoch [16/50], Step [230/313], Loss: 0.1142
# Epoch [16/50], Step [240/313], Loss: 0.1198
# Epoch [16/50], Step [250/313], Loss: 0.1290
# Epoch [16/50], Step [260/313], Loss: 0.0925
# Epoch [16/50], Step [270/313], Loss: 0.0894
# Epoch [16/50], Step [280/313], Loss: 0.1443
# Epoch [16/50], Step [290/313], Loss: 0.1380
# Epoch [16/50], Step [300/313], Loss: 0.1148
# Epoch [16/50], Step [310/313], Loss: 0.1230
# Epoch [16/50], Loss: 0.1170
# Epoch [16/50], Train Mean mIoU: 0.7339
# Epoch [16/50], Val Mean mIoU: 0.1866
# road: Val mIoU = 0.4056
# sidewalk: Val mIoU = 0.0839
# building: Val mIoU = 0.6199
# wall: Val mIoU = 0.0937
# fence: Val mIoU = 0.0774
# pole: Val mIoU = 0.1182
# traffic light: Val mIoU = 0.1475
# traffic sign: Val mIoU = 0.0364
# vegetation: Val mIoU = 0.6607
# terrain: Val mIoU = 0.0579
# sky: Val mIoU = 0.6170
# person: Val mIoU = 0.1494
# rider: Val mIoU = 0.0022
# car: Val mIoU = 0.4431
# truck: Val mIoU = 0.0103
# bus: Val mIoU = 0.0221
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [17/50], Step [10/313], Loss: 0.1190
# Epoch [17/50], Step [20/313], Loss: 0.1244
# Epoch [17/50], Step [30/313], Loss: 0.1095
# Epoch [17/50], Step [40/313], Loss: 0.1228
# Epoch [17/50], Step [50/313], Loss: 0.1150
# Epoch [17/50], Step [60/313], Loss: 0.1182
# Epoch [17/50], Step [70/313], Loss: 0.1007
# Epoch [17/50], Step [80/313], Loss: 0.1136
# Epoch [17/50], Step [90/313], Loss: 0.1250
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [17/50], Step [100/313], Loss: 0.1120
# Epoch [17/50], Step [110/313], Loss: 0.1092
# Epoch [17/50], Step [120/313], Loss: 0.1093
# Epoch [17/50], Step [130/313], Loss: 0.1381
# Epoch [17/50], Step [140/313], Loss: 0.1185
# Epoch [17/50], Step [150/313], Loss: 0.1163
# Epoch [17/50], Step [160/313], Loss: 0.1366
# Epoch [17/50], Step [170/313], Loss: 0.1108
# Epoch [17/50], Step [180/313], Loss: 0.1203
# Epoch [17/50], Step [190/313], Loss: 0.1352
# Epoch [17/50], Step [200/313], Loss: 0.1331
# Epoch [17/50], Step [210/313], Loss: 0.1162
# Epoch [17/50], Step [220/313], Loss: 0.1141
# Epoch [17/50], Step [230/313], Loss: 0.0994
# Epoch [17/50], Step [240/313], Loss: 0.1205
# Epoch [17/50], Step [250/313], Loss: 0.1112
# Epoch [17/50], Step [260/313], Loss: 0.1095
# Epoch [17/50], Step [270/313], Loss: 0.1233
# Epoch [17/50], Step [280/313], Loss: 0.1336
# Epoch [17/50], Step [290/313], Loss: 0.1065
# Epoch [17/50], Step [300/313], Loss: 0.1162
# Epoch [17/50], Step [310/313], Loss: 0.1199
# Epoch [17/50], Loss: 0.1150
# Epoch [17/50], Train Mean mIoU: 0.7422
# Epoch [17/50], Val Mean mIoU: 0.1984
# road: Val mIoU = 0.4995
# sidewalk: Val mIoU = 0.0785
# building: Val mIoU = 0.6390
# wall: Val mIoU = 0.1007
# fence: Val mIoU = 0.0902
# pole: Val mIoU = 0.1350
# traffic light: Val mIoU = 0.1448
# traffic sign: Val mIoU = 0.0635
# vegetation: Val mIoU = 0.6872
# terrain: Val mIoU = 0.0734
# sky: Val mIoU = 0.6109
# person: Val mIoU = 0.1923
# rider: Val mIoU = 0.0038
# car: Val mIoU = 0.4104
# truck: Val mIoU = 0.0142
# bus: Val mIoU = 0.0268
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Model saved with Mean mIoU: 0.1984
# Epoch [18/50], Step [10/313], Loss: 0.1120
# Epoch [18/50], Step [20/313], Loss: 0.1094
# Epoch [18/50], Step [30/313], Loss: 0.0929
# Epoch [18/50], Step [40/313], Loss: 0.1065
# Epoch [18/50], Step [50/313], Loss: 0.1191
# Epoch [18/50], Step [60/313], Loss: 0.1190
# Epoch [18/50], Step [70/313], Loss: 0.1060
# Epoch [18/50], Step [80/313], Loss: 0.1239
# Epoch [18/50], Step [90/313], Loss: 0.1297
# Epoch [18/50], Step [100/313], Loss: 0.1039
# Epoch [18/50], Step [110/313], Loss: 0.1081
# Epoch [18/50], Step [120/313], Loss: 0.0965
# Epoch [18/50], Step [130/313], Loss: 0.1129
# Epoch [18/50], Step [140/313], Loss: 0.1120
# Epoch [18/50], Step [150/313], Loss: 0.0992
# Epoch [18/50], Step [160/313], Loss: 0.1269
# Epoch [18/50], Step [170/313], Loss: 0.0998
# Epoch [18/50], Step [180/313], Loss: 0.0946
# Epoch [18/50], Step [190/313], Loss: 0.1183
# Epoch [18/50], Step [200/313], Loss: 0.1218
# Epoch [18/50], Step [210/313], Loss: 0.1106
# Epoch [18/50], Step [220/313], Loss: 0.1065
# Epoch [18/50], Step [230/313], Loss: 0.0994
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [18/50], Step [240/313], Loss: 0.1043
# Epoch [18/50], Step [250/313], Loss: 0.1212
# Epoch [18/50], Step [260/313], Loss: 0.0988
# Epoch [18/50], Step [270/313], Loss: 0.1047
# Epoch [18/50], Step [280/313], Loss: 0.1199
# Epoch [18/50], Step [290/313], Loss: 0.1239
# Epoch [18/50], Step [300/313], Loss: 0.1107
# Epoch [18/50], Step [310/313], Loss: 0.1107
# Epoch [18/50], Loss: 0.1128
# Epoch [18/50], Train Mean mIoU: 0.7461
# Epoch [18/50], Val Mean mIoU: 0.1823
# road: Val mIoU = 0.4043
# sidewalk: Val mIoU = 0.0926
# building: Val mIoU = 0.6389
# wall: Val mIoU = 0.0793
# fence: Val mIoU = 0.0531
# pole: Val mIoU = 0.1310
# traffic light: Val mIoU = 0.1541
# traffic sign: Val mIoU = 0.0445
# vegetation: Val mIoU = 0.6410
# terrain: Val mIoU = 0.0481
# sky: Val mIoU = 0.5522
# person: Val mIoU = 0.1735
# rider: Val mIoU = 0.0007
# car: Val mIoU = 0.4210
# truck: Val mIoU = 0.0144
# bus: Val mIoU = 0.0152
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [19/50], Step [10/313], Loss: 0.1227
# Epoch [19/50], Step [20/313], Loss: 0.1038
# Epoch [19/50], Step [30/313], Loss: 0.1013
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [19/50], Step [40/313], Loss: 0.1137
# Epoch [19/50], Step [50/313], Loss: 0.1115
# Epoch [19/50], Step [60/313], Loss: 0.1133
# Epoch [19/50], Step [70/313], Loss: 0.1127
# Epoch [19/50], Step [80/313], Loss: 0.1225
# Epoch [19/50], Step [90/313], Loss: 0.1059
# Epoch [19/50], Step [100/313], Loss: 0.1293
# Epoch [19/50], Step [110/313], Loss: 0.1047
# Epoch [19/50], Step [120/313], Loss: 0.1086
# Epoch [19/50], Step [130/313], Loss: 0.0973
# Epoch [19/50], Step [140/313], Loss: 0.1118
# Epoch [19/50], Step [150/313], Loss: 0.1255
# Epoch [19/50], Step [160/313], Loss: 0.1106
# Epoch [19/50], Step [170/313], Loss: 0.1005
# Epoch [19/50], Step [180/313], Loss: 0.1117
# Epoch [19/50], Step [190/313], Loss: 0.1128
# Epoch [19/50], Step [200/313], Loss: 0.1050
# Epoch [19/50], Step [210/313], Loss: 0.1077
# Epoch [19/50], Step [220/313], Loss: 0.1147
# Epoch [19/50], Step [230/313], Loss: 0.1089
# Epoch [19/50], Step [240/313], Loss: 0.1308
# Epoch [19/50], Step [250/313], Loss: 0.1209
# Epoch [19/50], Step [260/313], Loss: 0.1205
# Epoch [19/50], Step [270/313], Loss: 0.1086
# Epoch [19/50], Step [280/313], Loss: 0.0983
# Epoch [19/50], Step [290/313], Loss: 0.1251
# Epoch [19/50], Step [300/313], Loss: 0.1135
# Epoch [19/50], Step [310/313], Loss: 0.0978
# Epoch [19/50], Loss: 0.1115
# Epoch [19/50], Train Mean mIoU: 0.7493
# Epoch [19/50], Val Mean mIoU: 0.1957
# road: Val mIoU = 0.3981
# sidewalk: Val mIoU = 0.1322
# building: Val mIoU = 0.6425
# wall: Val mIoU = 0.0923
# fence: Val mIoU = 0.0898
# pole: Val mIoU = 0.1499
# traffic light: Val mIoU = 0.1551
# traffic sign: Val mIoU = 0.0422
# vegetation: Val mIoU = 0.6719
# terrain: Val mIoU = 0.0546
# sky: Val mIoU = 0.6296
# person: Val mIoU = 0.1730
# rider: Val mIoU = 0.0007
# car: Val mIoU = 0.4491
# truck: Val mIoU = 0.0118
# bus: Val mIoU = 0.0255
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0000
# Epoch [20/50], Step [10/313], Loss: 0.1066
# Epoch [20/50], Step [20/313], Loss: 0.0962
# Epoch [20/50], Step [30/313], Loss: 0.1056
# Epoch [20/50], Step [40/313], Loss: 0.1054
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [20/50], Step [50/313], Loss: 0.1033
# Epoch [20/50], Step [60/313], Loss: 0.1164
# Epoch [20/50], Step [70/313], Loss: 0.1146
# Epoch [20/50], Step [80/313], Loss: 0.1106
# Epoch [20/50], Step [90/313], Loss: 0.1152
# Epoch [20/50], Step [100/313], Loss: 0.1099
# Epoch [20/50], Step [110/313], Loss: 0.1129
# Epoch [20/50], Step [120/313], Loss: 0.1234
# Epoch [20/50], Step [130/313], Loss: 0.1030
# Epoch [20/50], Step [140/313], Loss: 0.1053
# Epoch [20/50], Step [150/313], Loss: 0.1049
# Epoch [20/50], Step [160/313], Loss: 0.1238
# Epoch [20/50], Step [170/313], Loss: 0.0888
# Epoch [20/50], Step [180/313], Loss: 0.1233
# Epoch [20/50], Step [190/313], Loss: 0.1243
# Epoch [20/50], Step [200/313], Loss: 0.1183
# Epoch [20/50], Step [210/313], Loss: 0.0978
# Epoch [20/50], Step [220/313], Loss: 0.1112
# Epoch [20/50], Step [230/313], Loss: 0.1080
# Epoch [20/50], Step [240/313], Loss: 0.1260
# Epoch [20/50], Step [250/313], Loss: 0.1144
# Epoch [20/50], Step [260/313], Loss: 0.1282
# Epoch [20/50], Step [270/313], Loss: 0.1095
# Epoch [20/50], Step [280/313], Loss: 0.1114
# Epoch [20/50], Step [290/313], Loss: 0.0960
# Epoch [20/50], Step [300/313], Loss: 0.1160
# Epoch [20/50], Step [310/313], Loss: 0.1022
# Epoch [20/50], Loss: 0.1096
# Epoch [20/50], Train Mean mIoU: 0.7511
# Epoch [20/50], Val Mean mIoU: 0.1873
# road: Val mIoU = 0.3569
# sidewalk: Val mIoU = 0.1348
# building: Val mIoU = 0.6493
# wall: Val mIoU = 0.0738
# fence: Val mIoU = 0.0512
# pole: Val mIoU = 0.1275
# traffic light: Val mIoU = 0.1578
# traffic sign: Val mIoU = 0.0511
# vegetation: Val mIoU = 0.6352
# terrain: Val mIoU = 0.0538
# sky: Val mIoU = 0.6272
# person: Val mIoU = 0.1827
# rider: Val mIoU = 0.0018
# car: Val mIoU = 0.4213
# truck: Val mIoU = 0.0124
# bus: Val mIoU = 0.0206
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0002
# Epoch [21/50], Step [10/313], Loss: 0.1322
# Epoch [21/50], Step [20/313], Loss: 0.1033
# Epoch [21/50], Step [30/313], Loss: 0.1130
# Epoch [21/50], Step [40/313], Loss: 0.0917
# Epoch [21/50], Step [50/313], Loss: 0.0898
# Epoch [21/50], Step [60/313], Loss: 0.1091
# Epoch [21/50], Step [70/313], Loss: 0.1050
# Epoch [21/50], Step [80/313], Loss: 0.1166
# Epoch [21/50], Step [90/313], Loss: 0.1115
# Epoch [21/50], Step [100/313], Loss: 0.1118
# Epoch [21/50], Step [110/313], Loss: 0.0977
# Epoch [21/50], Step [120/313], Loss: 0.1117
# Epoch [21/50], Step [130/313], Loss: 0.0896
# Epoch [21/50], Step [140/313], Loss: 0.0982
# Epoch [21/50], Step [150/313], Loss: 0.1012
# Epoch [21/50], Step [160/313], Loss: 0.0991
# Epoch [21/50], Step [170/313], Loss: 0.0918
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [21/50], Step [180/313], Loss: 0.1166
# Epoch [21/50], Step [190/313], Loss: 0.1098
# Epoch [21/50], Step [200/313], Loss: 0.1212
# Epoch [21/50], Step [210/313], Loss: 0.1164
# Epoch [21/50], Step [220/313], Loss: 0.1064
# Epoch [21/50], Step [230/313], Loss: 0.1096
# Epoch [21/50], Step [240/313], Loss: 0.1184
# Epoch [21/50], Step [250/313], Loss: 0.1071
# Epoch [21/50], Step [260/313], Loss: 0.1053
# Epoch [21/50], Step [270/313], Loss: 0.1106
# Epoch [21/50], Step [280/313], Loss: 0.1151
# Epoch [21/50], Step [290/313], Loss: 0.0972
# Epoch [21/50], Step [300/313], Loss: 0.1242
# Epoch [21/50], Step [310/313], Loss: 0.1283
# Epoch [21/50], Loss: 0.1080
# Epoch [21/50], Train Mean mIoU: 0.7551
# Epoch [21/50], Val Mean mIoU: 0.2016
# road: Val mIoU = 0.3863
# sidewalk: Val mIoU = 0.1374
# building: Val mIoU = 0.6840
# wall: Val mIoU = 0.0893
# fence: Val mIoU = 0.1078
# pole: Val mIoU = 0.1536
# traffic light: Val mIoU = 0.1505
# traffic sign: Val mIoU = 0.0475
# vegetation: Val mIoU = 0.6660
# terrain: Val mIoU = 0.0440
# sky: Val mIoU = 0.6485
# person: Val mIoU = 0.2387
# rider: Val mIoU = 0.0027
# car: Val mIoU = 0.4144
# truck: Val mIoU = 0.0161
# bus: Val mIoU = 0.0420
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0015
# bicycle: Val mIoU = 0.0002
# Model saved with Mean mIoU: 0.2016
# Epoch [22/50], Step [10/313], Loss: 0.1184
# Epoch [22/50], Step [20/313], Loss: 0.1065
# Epoch [22/50], Step [30/313], Loss: 0.1314
# Epoch [22/50], Step [40/313], Loss: 0.0990
# Epoch [22/50], Step [50/313], Loss: 0.1097
# Epoch [22/50], Step [60/313], Loss: 0.1084
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [22/50], Step [70/313], Loss: 0.1294
# Epoch [22/50], Step [80/313], Loss: 0.1172
# Epoch [22/50], Step [90/313], Loss: 0.0965
# Epoch [22/50], Step [100/313], Loss: 0.1081
# Epoch [22/50], Step [110/313], Loss: 0.1077
# Epoch [22/50], Step [120/313], Loss: 0.0973
# Epoch [22/50], Step [130/313], Loss: 0.1019
# Epoch [22/50], Step [140/313], Loss: 0.0995
# Epoch [22/50], Step [150/313], Loss: 0.0980
# Epoch [22/50], Step [160/313], Loss: 0.1062
# Epoch [22/50], Step [170/313], Loss: 0.1302
# Epoch [22/50], Step [180/313], Loss: 0.1106
# Epoch [22/50], Step [190/313], Loss: 0.0821
# Epoch [22/50], Step [200/313], Loss: 0.1116
# Epoch [22/50], Step [210/313], Loss: 0.1137
# Epoch [22/50], Step [220/313], Loss: 0.1218
# Epoch [22/50], Step [230/313], Loss: 0.1078
# Epoch [22/50], Step [240/313], Loss: 0.0907
# Epoch [22/50], Step [250/313], Loss: 0.0959
# Epoch [22/50], Step [260/313], Loss: 0.1047
# Epoch [22/50], Step [270/313], Loss: 0.1088
# Epoch [22/50], Step [280/313], Loss: 0.1029
# Epoch [22/50], Step [290/313], Loss: 0.1152
# Epoch [22/50], Step [300/313], Loss: 0.1173
# Epoch [22/50], Step [310/313], Loss: 0.1042
# Epoch [22/50], Loss: 0.1062
# Epoch [22/50], Train Mean mIoU: 0.7592
# Epoch [22/50], Val Mean mIoU: 0.1920
# road: Val mIoU = 0.4363
# sidewalk: Val mIoU = 0.0973
# building: Val mIoU = 0.6684
# wall: Val mIoU = 0.0977
# fence: Val mIoU = 0.0673
# pole: Val mIoU = 0.1134
# traffic light: Val mIoU = 0.1576
# traffic sign: Val mIoU = 0.0451
# vegetation: Val mIoU = 0.6655
# terrain: Val mIoU = 0.0516
# sky: Val mIoU = 0.6509
# person: Val mIoU = 0.1761
# rider: Val mIoU = 0.0029
# car: Val mIoU = 0.3811
# truck: Val mIoU = 0.0169
# bus: Val mIoU = 0.0203
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0003
# Epoch [23/50], Step [10/313], Loss: 0.1151
# Epoch [23/50], Step [20/313], Loss: 0.0970
# Epoch [23/50], Step [30/313], Loss: 0.0993
# Epoch [23/50], Step [40/313], Loss: 0.1126
# Epoch [23/50], Step [50/313], Loss: 0.1073
# Epoch [23/50], Step [60/313], Loss: 0.0985
# Epoch [23/50], Step [70/313], Loss: 0.0949
# Epoch [23/50], Step [80/313], Loss: 0.1027
# Epoch [23/50], Step [90/313], Loss: 0.1080
# Epoch [23/50], Step [100/313], Loss: 0.1023
# Epoch [23/50], Step [110/313], Loss: 0.1059
# Epoch [23/50], Step [120/313], Loss: 0.0932
# Epoch [23/50], Step [130/313], Loss: 0.1082
# Epoch [23/50], Step [140/313], Loss: 0.0869
# Epoch [23/50], Step [150/313], Loss: 0.1056
# Epoch [23/50], Step [160/313], Loss: 0.1014
# Epoch [23/50], Step [170/313], Loss: 0.1055
# Epoch [23/50], Step [180/313], Loss: 0.1257
# Epoch [23/50], Step [190/313], Loss: 0.1113
# Epoch [23/50], Step [200/313], Loss: 0.0944
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [23/50], Step [210/313], Loss: 0.1108
# Epoch [23/50], Step [220/313], Loss: 0.0972
# Epoch [23/50], Step [230/313], Loss: 0.0980
# Epoch [23/50], Step [240/313], Loss: 0.0951
# Epoch [23/50], Step [250/313], Loss: 0.1069
# Epoch [23/50], Step [260/313], Loss: 0.1032
# Epoch [23/50], Step [270/313], Loss: 0.0985
# Epoch [23/50], Step [280/313], Loss: 0.1082
# Epoch [23/50], Step [290/313], Loss: 0.1077
# Epoch [23/50], Step [300/313], Loss: 0.1083
# Epoch [23/50], Step [310/313], Loss: 0.1088
# Epoch [23/50], Loss: 0.1048
# Epoch [23/50], Train Mean mIoU: 0.7612
# Epoch [23/50], Val Mean mIoU: 0.2098
# ...
# Epoch [43/50], Step [200/313], Loss: 0.0938
# Epoch [43/50], Step [210/313], Loss: 0.0931
# Epoch [43/50], Step [220/313], Loss: 0.0982
# Epoch [43/50], Step [230/313], Loss: 0.0892
# Epoch [43/50], Step [240/313], Loss: 0.0985
# Epoch [43/50], Step [250/313], Loss: 0.0962
# Epoch [43/50], Step [260/313], Loss: 0.0836
# Epoch [43/50], Step [270/313], Loss: 0.0953
# Epoch [43/50], Step [280/313], Loss: 0.0812
# Epoch [43/50], Step [290/313], Loss: 0.1002
# Epoch [43/50], Step [300/313], Loss: 0.0861
# Epoch [43/50], Step [310/313], Loss: 0.0840
# Epoch [43/50], Loss: 0.0904
# Epoch [43/50], Train Mean mIoU: 0.7879
# Epoch [43/50], Val Mean mIoU: 0.2117
# road: Val mIoU = 0.5260
# sidewalk: Val mIoU = 0.1512
# building: Val mIoU = 0.6670
# wall: Val mIoU = 0.1173
# fence: Val mIoU = 0.0711
# pole: Val mIoU = 0.1602
# traffic light: Val mIoU = 0.1644
# traffic sign: Val mIoU = 0.0527
# vegetation: Val mIoU = 0.6751
# terrain: Val mIoU = 0.0606
# sky: Val mIoU = 0.6461
# person: Val mIoU = 0.2176
# rider: Val mIoU = 0.0079
# car: Val mIoU = 0.4582
# truck: Val mIoU = 0.0188
# bus: Val mIoU = 0.0275
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0008
# Epoch [44/50], Step [10/313], Loss: 0.1001
# Epoch [44/50], Step [20/313], Loss: 0.0865
# Epoch [44/50], Step [30/313], Loss: 0.0798
# Epoch [44/50], Step [40/313], Loss: 0.0757
# Epoch [44/50], Step [50/313], Loss: 0.0930
# Epoch [44/50], Step [60/313], Loss: 0.0963
# Epoch [44/50], Step [70/313], Loss: 0.0965
# Epoch [44/50], Step [80/313], Loss: 0.0795
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [44/50], Step [90/313], Loss: 0.0900
# Epoch [44/50], Step [100/313], Loss: 0.1033
# Epoch [44/50], Step [110/313], Loss: 0.0794
# Epoch [44/50], Step [120/313], Loss: 0.0800
# Epoch [44/50], Step [130/313], Loss: 0.0963
# Epoch [44/50], Step [140/313], Loss: 0.0920
# Epoch [44/50], Step [150/313], Loss: 0.0794
# Epoch [44/50], Step [160/313], Loss: 0.1114
# Epoch [44/50], Step [170/313], Loss: 0.0828
# Epoch [44/50], Step [180/313], Loss: 0.0887
# Epoch [44/50], Step [190/313], Loss: 0.0971
# Epoch [44/50], Step [200/313], Loss: 0.0946
# Epoch [44/50], Step [210/313], Loss: 0.0878
# Epoch [44/50], Step [220/313], Loss: 0.1019
# Epoch [44/50], Step [230/313], Loss: 0.1005
# Epoch [44/50], Step [240/313], Loss: 0.0882
# Epoch [44/50], Step [250/313], Loss: 0.0935
# Epoch [44/50], Step [260/313], Loss: 0.0895
# Epoch [44/50], Step [270/313], Loss: 0.0734
# Epoch [44/50], Step [280/313], Loss: 0.0883
# Epoch [44/50], Step [290/313], Loss: 0.0748
# Epoch [44/50], Step [300/313], Loss: 0.0893
# Epoch [44/50], Step [310/313], Loss: 0.1091
# Epoch [44/50], Loss: 0.0901
# Epoch [44/50], Train Mean mIoU: 0.7887
# Epoch [44/50], Val Mean mIoU: 0.2092
# road: Val mIoU = 0.5197
# sidewalk: Val mIoU = 0.1341
# building: Val mIoU = 0.6632
# wall: Val mIoU = 0.1139
# fence: Val mIoU = 0.0727
# pole: Val mIoU = 0.1573
# traffic light: Val mIoU = 0.1637
# traffic sign: Val mIoU = 0.0516
# vegetation: Val mIoU = 0.6809
# terrain: Val mIoU = 0.0615
# sky: Val mIoU = 0.6380
# person: Val mIoU = 0.2006
# rider: Val mIoU = 0.0045
# car: Val mIoU = 0.4687
# truck: Val mIoU = 0.0182
# bus: Val mIoU = 0.0260
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0009
# Epoch [45/50], Step [10/313], Loss: 0.0910
# Epoch [45/50], Step [20/313], Loss: 0.0760
# Epoch [45/50], Step [30/313], Loss: 0.0845
# Epoch [45/50], Step [40/313], Loss: 0.0982
# Epoch [45/50], Step [50/313], Loss: 0.0956
# Epoch [45/50], Step [60/313], Loss: 0.0986
# Epoch [45/50], Step [70/313], Loss: 0.0884
# Epoch [45/50], Step [80/313], Loss: 0.0951
# Epoch [45/50], Step [90/313], Loss: 0.0933
# Epoch [45/50], Step [100/313], Loss: 0.0837
# Epoch [45/50], Step [110/313], Loss: 0.0841
# Epoch [45/50], Step [120/313], Loss: 0.0863
# Epoch [45/50], Step [130/313], Loss: 0.0957
# Epoch [45/50], Step [140/313], Loss: 0.0974
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [45/50], Step [150/313], Loss: 0.1065
# Epoch [45/50], Step [160/313], Loss: 0.0836
# Epoch [45/50], Step [170/313], Loss: 0.1039
# Epoch [45/50], Step [180/313], Loss: 0.1060
# Epoch [45/50], Step [190/313], Loss: 0.0737
# Epoch [45/50], Step [200/313], Loss: 0.1018
# Epoch [45/50], Step [210/313], Loss: 0.1051
# Epoch [45/50], Step [220/313], Loss: 0.0998
# Epoch [45/50], Step [230/313], Loss: 0.0609
# Epoch [45/50], Step [240/313], Loss: 0.0819
# Epoch [45/50], Step [250/313], Loss: 0.1076
# Epoch [45/50], Step [260/313], Loss: 0.0872
# Epoch [45/50], Step [270/313], Loss: 0.0877
# Epoch [45/50], Step [280/313], Loss: 0.0895
# Epoch [45/50], Step [290/313], Loss: 0.0971
# Epoch [45/50], Step [300/313], Loss: 0.0953
# Epoch [45/50], Step [310/313], Loss: 0.1069
# Epoch [45/50], Loss: 0.0899
# Epoch [45/50], Train Mean mIoU: 0.7905
# Epoch [45/50], Val Mean mIoU: 0.2120
# road: Val mIoU = 0.5415
# sidewalk: Val mIoU = 0.1446
# building: Val mIoU = 0.6608
# wall: Val mIoU = 0.1230
# fence: Val mIoU = 0.0691
# pole: Val mIoU = 0.1553
# traffic light: Val mIoU = 0.1675
# traffic sign: Val mIoU = 0.0543
# vegetation: Val mIoU = 0.6750
# terrain: Val mIoU = 0.0691
# sky: Val mIoU = 0.6270
# person: Val mIoU = 0.2180
# rider: Val mIoU = 0.0064
# car: Val mIoU = 0.4729
# truck: Val mIoU = 0.0170
# bus: Val mIoU = 0.0259
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0007
# Epoch [46/50], Step [10/313], Loss: 0.0726
# Epoch [46/50], Step [20/313], Loss: 0.0958
# Epoch [46/50], Step [30/313], Loss: 0.0860
# Epoch [46/50], Step [40/313], Loss: 0.0984
# Epoch [46/50], Step [50/313], Loss: 0.0948
# Epoch [46/50], Step [60/313], Loss: 0.0951
# Epoch [46/50], Step [70/313], Loss: 0.0850
# Epoch [46/50], Step [80/313], Loss: 0.0722
# Epoch [46/50], Step [90/313], Loss: 0.0799
# Epoch [46/50], Step [100/313], Loss: 0.0770
# Epoch [46/50], Step [110/313], Loss: 0.0942
# Epoch [46/50], Step [120/313], Loss: 0.0803
# Epoch [46/50], Step [130/313], Loss: 0.0908
# Epoch [46/50], Step [140/313], Loss: 0.0883
# Epoch [46/50], Step [150/313], Loss: 0.0919
# Epoch [46/50], Step [160/313], Loss: 0.1012
# Epoch [46/50], Step [170/313], Loss: 0.0947
# Epoch [46/50], Step [180/313], Loss: 0.0998
# Epoch [46/50], Step [190/313], Loss: 0.1002
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [46/50], Step [200/313], Loss: 0.0893
# Epoch [46/50], Step [210/313], Loss: 0.0725
# Epoch [46/50], Step [220/313], Loss: 0.0777
# Epoch [46/50], Step [230/313], Loss: 0.0838
# Epoch [46/50], Step [240/313], Loss: 0.0847
# Epoch [46/50], Step [250/313], Loss: 0.0804
# Epoch [46/50], Step [260/313], Loss: 0.0889
# Epoch [46/50], Step [270/313], Loss: 0.0835
# Epoch [46/50], Step [280/313], Loss: 0.0919
# Epoch [46/50], Step [290/313], Loss: 0.0941
# Epoch [46/50], Step [300/313], Loss: 0.0941
# Epoch [46/50], Step [310/313], Loss: 0.0876
# Epoch [46/50], Loss: 0.0897
# Epoch [46/50], Train Mean mIoU: 0.7906
# Epoch [46/50], Val Mean mIoU: 0.2142
# road: Val mIoU = 0.5505
# sidewalk: Val mIoU = 0.1355
# building: Val mIoU = 0.6678
# wall: Val mIoU = 0.1174
# fence: Val mIoU = 0.0735
# pole: Val mIoU = 0.1568
# traffic light: Val mIoU = 0.1641
# traffic sign: Val mIoU = 0.0517
# vegetation: Val mIoU = 0.6802
# terrain: Val mIoU = 0.0667
# sky: Val mIoU = 0.6504
# person: Val mIoU = 0.2095
# rider: Val mIoU = 0.0049
# car: Val mIoU = 0.4860
# truck: Val mIoU = 0.0160
# bus: Val mIoU = 0.0378
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0007
# Epoch [47/50], Step [10/313], Loss: 0.0810
# Epoch [47/50], Step [20/313], Loss: 0.0841
# Epoch [47/50], Step [30/313], Loss: 0.0801
# Epoch [47/50], Step [40/313], Loss: 0.0804
# Epoch [47/50], Step [50/313], Loss: 0.1205
# Epoch [47/50], Step [60/313], Loss: 0.0900
# Epoch [47/50], Step [70/313], Loss: 0.0880
# Epoch [47/50], Step [80/313], Loss: 0.0955
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [47/50], Step [90/313], Loss: 0.0937
# Epoch [47/50], Step [100/313], Loss: 0.0892
# Epoch [47/50], Step [110/313], Loss: 0.0929
# Epoch [47/50], Step [120/313], Loss: 0.0914
# Epoch [47/50], Step [130/313], Loss: 0.0869
# Epoch [47/50], Step [140/313], Loss: 0.1022
# Epoch [47/50], Step [150/313], Loss: 0.0944
# Epoch [47/50], Step [160/313], Loss: 0.0884
# Epoch [47/50], Step [170/313], Loss: 0.0893
# Epoch [47/50], Step [180/313], Loss: 0.0954
# Epoch [47/50], Step [190/313], Loss: 0.0918
# Epoch [47/50], Step [200/313], Loss: 0.0916
# Epoch [47/50], Step [210/313], Loss: 0.0934
# Epoch [47/50], Step [220/313], Loss: 0.0917
# Epoch [47/50], Step [230/313], Loss: 0.0715
# Epoch [47/50], Step [240/313], Loss: 0.0931
# Epoch [47/50], Step [250/313], Loss: 0.0936
# Epoch [47/50], Step [260/313], Loss: 0.0967
# Epoch [47/50], Step [270/313], Loss: 0.0804
# Epoch [47/50], Step [280/313], Loss: 0.0828
# Epoch [47/50], Step [290/313], Loss: 0.0836
# Epoch [47/50], Step [300/313], Loss: 0.0937
# Epoch [47/50], Step [310/313], Loss: 0.1023
# Epoch [47/50], Loss: 0.0894
# Epoch [47/50], Train Mean mIoU: 0.7904
# Epoch [47/50], Val Mean mIoU: 0.2141
# road: Val mIoU = 0.5479
# sidewalk: Val mIoU = 0.1377
# building: Val mIoU = 0.6698
# wall: Val mIoU = 0.1250
# fence: Val mIoU = 0.0693
# pole: Val mIoU = 0.1576
# traffic light: Val mIoU = 0.1658
# traffic sign: Val mIoU = 0.0550
# vegetation: Val mIoU = 0.6803
# terrain: Val mIoU = 0.0641
# sky: Val mIoU = 0.6539
# person: Val mIoU = 0.2087
# rider: Val mIoU = 0.0062
# car: Val mIoU = 0.4797
# truck: Val mIoU = 0.0187
# bus: Val mIoU = 0.0264
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0010
# Epoch [48/50], Step [10/313], Loss: 0.0905
# Epoch [48/50], Step [20/313], Loss: 0.0727
# Epoch [48/50], Step [30/313], Loss: 0.0764
# Epoch [48/50], Step [40/313], Loss: 0.1073
# Epoch [48/50], Step [50/313], Loss: 0.0861
# Epoch [48/50], Step [60/313], Loss: 0.0956
# Epoch [48/50], Step [70/313], Loss: 0.0919
# Epoch [48/50], Step [80/313], Loss: 0.0927
# Epoch [48/50], Step [90/313], Loss: 0.0953
# Epoch [48/50], Step [100/313], Loss: 0.0845
# Epoch [48/50], Step [110/313], Loss: 0.0864
# Epoch [48/50], Step [120/313], Loss: 0.0869
# Epoch [48/50], Step [130/313], Loss: 0.0922
# Epoch [48/50], Step [140/313], Loss: 0.1032
# Epoch [48/50], Step [150/313], Loss: 0.1039
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [48/50], Step [160/313], Loss: 0.0780
# Epoch [48/50], Step [170/313], Loss: 0.0999
# Epoch [48/50], Step [180/313], Loss: 0.0920
# Epoch [48/50], Step [190/313], Loss: 0.0889
# Epoch [48/50], Step [200/313], Loss: 0.0879
# Epoch [48/50], Step [210/313], Loss: 0.0844
# Epoch [48/50], Step [220/313], Loss: 0.0768
# Epoch [48/50], Step [230/313], Loss: 0.1045
# Epoch [48/50], Step [240/313], Loss: 0.1067
# Epoch [48/50], Step [250/313], Loss: 0.0932
# Epoch [48/50], Step [260/313], Loss: 0.0784
# Epoch [48/50], Step [270/313], Loss: 0.0855
# Epoch [48/50], Step [280/313], Loss: 0.0829
# Epoch [48/50], Step [290/313], Loss: 0.0867
# Epoch [48/50], Step [300/313], Loss: 0.0827
# Epoch [48/50], Step [310/313], Loss: 0.0957
# Epoch [48/50], Loss: 0.0893
# Epoch [48/50], Train Mean mIoU: 0.7906
# Epoch [48/50], Val Mean mIoU: 0.2125
# road: Val mIoU = 0.5462
# sidewalk: Val mIoU = 0.1366
# building: Val mIoU = 0.6702
# wall: Val mIoU = 0.1160
# fence: Val mIoU = 0.0688
# pole: Val mIoU = 0.1559
# traffic light: Val mIoU = 0.1660
# traffic sign: Val mIoU = 0.0499
# vegetation: Val mIoU = 0.6786
# terrain: Val mIoU = 0.0620
# sky: Val mIoU = 0.6546
# person: Val mIoU = 0.2047
# rider: Val mIoU = 0.0048
# car: Val mIoU = 0.4803
# truck: Val mIoU = 0.0191
# bus: Val mIoU = 0.0240
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0007
# Epoch [49/50], Step [10/313], Loss: 0.0999
# Epoch [49/50], Step [20/313], Loss: 0.0796
# Epoch [49/50], Step [30/313], Loss: 0.0698
# Epoch [49/50], Step [40/313], Loss: 0.0982
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [49/50], Step [50/313], Loss: 0.0986
# Epoch [49/50], Step [60/313], Loss: 0.0804
# Epoch [49/50], Step [70/313], Loss: 0.0925
# Epoch [49/50], Step [80/313], Loss: 0.0970
# Epoch [49/50], Step [90/313], Loss: 0.1055
# Epoch [49/50], Step [100/313], Loss: 0.0888
# Epoch [49/50], Step [110/313], Loss: 0.0955
# Epoch [49/50], Step [120/313], Loss: 0.1034
# Epoch [49/50], Step [130/313], Loss: 0.0930
# Epoch [49/50], Step [140/313], Loss: 0.0851
# Epoch [49/50], Step [150/313], Loss: 0.0814
# Epoch [49/50], Step [160/313], Loss: 0.0925
# Epoch [49/50], Step [170/313], Loss: 0.0829
# Epoch [49/50], Step [180/313], Loss: 0.0788
# Epoch [49/50], Step [190/313], Loss: 0.0777
# Epoch [49/50], Step [200/313], Loss: 0.0988
# Epoch [49/50], Step [210/313], Loss: 0.0808
# Epoch [49/50], Step [220/313], Loss: 0.0844
# Epoch [49/50], Step [230/313], Loss: 0.0903
# Epoch [49/50], Step [240/313], Loss: 0.0776
# Epoch [49/50], Step [250/313], Loss: 0.0960
# Epoch [49/50], Step [260/313], Loss: 0.0800
# Epoch [49/50], Step [270/313], Loss: 0.0946
# Epoch [49/50], Step [280/313], Loss: 0.0741
# Epoch [49/50], Step [290/313], Loss: 0.0849
# Epoch [49/50], Step [300/313], Loss: 0.0872
# Epoch [49/50], Step [310/313], Loss: 0.0932
# Epoch [49/50], Loss: 0.0892
# Epoch [49/50], Train Mean mIoU: 0.7918
# Epoch [49/50], Val Mean mIoU: 0.2132
# road: Val mIoU = 0.5592
# sidewalk: Val mIoU = 0.1319
# building: Val mIoU = 0.6698
# wall: Val mIoU = 0.1141
# fence: Val mIoU = 0.0635
# pole: Val mIoU = 0.1524
# traffic light: Val mIoU = 0.1627
# traffic sign: Val mIoU = 0.0551
# vegetation: Val mIoU = 0.6740
# terrain: Val mIoU = 0.0647
# sky: Val mIoU = 0.6553
# person: Val mIoU = 0.2129
# rider: Val mIoU = 0.0078
# car: Val mIoU = 0.4795
# truck: Val mIoU = 0.0179
# bus: Val mIoU = 0.0285
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0010
# Epoch [50/50], Step [10/313], Loss: 0.0907
# Epoch [50/50], Step [20/313], Loss: 0.0945
# Epoch [50/50], Step [30/313], Loss: 0.0925
# Epoch [50/50], Step [40/313], Loss: 0.0889
# Epoch [50/50], Step [50/313], Loss: 0.1034
# Epoch [50/50], Step [60/313], Loss: 0.1051
# Epoch [50/50], Step [70/313], Loss: 0.0773
# Epoch [50/50], Step [80/313], Loss: 0.0904
# Epoch [50/50], Step [90/313], Loss: 0.0896
# Epoch [50/50], Step [100/313], Loss: 0.0926
# Epoch [50/50], Step [110/313], Loss: 0.0947
# Epoch [50/50], Step [120/313], Loss: 0.1006
# Epoch [50/50], Step [130/313], Loss: 0.0904
# Epoch [50/50], Step [140/313], Loss: 0.0706
# Epoch [50/50], Step [150/313], Loss: 0.0971
# Epoch [50/50], Step [160/313], Loss: 0.0793
# Epoch [50/50], Step [170/313], Loss: 0.0805
# Error loading image /content/drive/MyDrive/MLDLMLDL/GTA5/images/00417.png or label /content/drive/MyDrive/MLDLMLDL/GTA5/labels/00417.png, skipping...
# Epoch [50/50], Step [180/313], Loss: 0.0618
# Epoch [50/50], Step [190/313], Loss: 0.0841
# Epoch [50/50], Step [200/313], Loss: 0.0861
# Epoch [50/50], Step [210/313], Loss: 0.0777
# Epoch [50/50], Step [220/313], Loss: 0.0950
# Epoch [50/50], Step [230/313], Loss: 0.0908
# Epoch [50/50], Step [240/313], Loss: 0.0792
# Epoch [50/50], Step [250/313], Loss: 0.0829
# Epoch [50/50], Step [260/313], Loss: 0.0877
# Epoch [50/50], Step [270/313], Loss: 0.0827
# Epoch [50/50], Step [280/313], Loss: 0.0965
# Epoch [50/50], Step [290/313], Loss: 0.0744
# Epoch [50/50], Step [300/313], Loss: 0.0909
# Epoch [50/50], Step [310/313], Loss: 0.0841
# Epoch [50/50], Loss: 0.0889
# Epoch [50/50], Train Mean mIoU: 0.7909
# Epoch [50/50], Val Mean mIoU: 0.2179
# road: Val mIoU = 0.5487
# sidewalk: Val mIoU = 0.1480
# building: Val mIoU = 0.6752
# wall: Val mIoU = 0.1291
# fence: Val mIoU = 0.0734
# pole: Val mIoU = 0.1613
# traffic light: Val mIoU = 0.1644
# traffic sign: Val mIoU = 0.0549
# vegetation: Val mIoU = 0.6857
# terrain: Val mIoU = 0.0673
# sky: Val mIoU = 0.6702
# person: Val mIoU = 0.2220
# rider: Val mIoU = 0.0080
# car: Val mIoU = 0.4769
# truck: Val mIoU = 0.0191
# bus: Val mIoU = 0.0346
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0000
# bicycle: Val mIoU = 0.0012
# Model saved with Mean mIoU: 0.2179

# %%
epochs = range(1, num_epochs + 1)
# Plot for Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, 'b-', label='Training Loss')
plt.plot(epochs, val_losses, 'g-', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot for Training and Validation mIoU
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_mIoUs, 'b-', label='Training mIoU')
plt.plot(epochs, val_mIoUs, 'r-', label='Validation mIoU')
plt.xlabel('Epoch')
plt.ylabel('mIoU')
plt.title('Training and Validation mIoU')
plt.legend()
plt.show()
