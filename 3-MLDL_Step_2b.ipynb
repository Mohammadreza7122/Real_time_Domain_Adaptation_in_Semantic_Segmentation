# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np


def poly_lr_scheduler(optimizer, init_lr, iter, lr_decay_iter=1,
                      max_iter=300, power=0.9):
    """Polynomial decay of learning rate
            :param init_lr is base learning rate
            :param iter is a current iteration
            :param lr_decay_iter how frequently decay occurs, default is 1
            :param max_iter is number of maximum iterations
            :param power is a polymomial power

    """
    # if iter % lr_decay_iter or iter > max_iter:
    # 	return optimizer

    lr = init_lr*(1 - iter/max_iter)**power
    optimizer.param_groups[0]['lr'] = lr
    return lr
    # return lr


def fast_hist(a, b, n):
    '''
    a and b are label and prediction respectively
    n is the number of classes
    '''
    k = (a >= 0) & (a < n)
    return np.bincount(n * a[k].astype(int) + b[k], minlength=n ** 2).reshape(n, n)


def per_class_iou(hist):
    epsilon = 1e-5
    return (np.diag(hist)) / (hist.sum(1) + hist.sum(0) - np.diag(hist) + epsilon)

# %%
import torch
from torchvision import models


class resnet18(torch.nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.features = models.resnet18(pretrained=pretrained)
        self.conv1 = self.features.conv1
        self.bn1 = self.features.bn1
        self.relu = self.features.relu
        self.maxpool1 = self.features.maxpool
        self.layer1 = self.features.layer1
        self.layer2 = self.features.layer2
        self.layer3 = self.features.layer3
        self.layer4 = self.features.layer4

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu(self.bn1(x))
        x = self.maxpool1(x)
        feature1 = self.layer1(x)  # 1 / 4
        feature2 = self.layer2(feature1)  # 1 / 8
        feature3 = self.layer3(feature2)  # 1 / 16
        feature4 = self.layer4(feature3)  # 1 / 32
        # global average pooling to build tail
        tail = torch.mean(feature4, 3, keepdim=True)
        tail = torch.mean(tail, 2, keepdim=True)
        return feature3, feature4, tail


class resnet101(torch.nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.features = models.resnet101(pretrained=pretrained)
        self.conv1 = self.features.conv1
        self.bn1 = self.features.bn1
        self.relu = self.features.relu
        self.maxpool1 = self.features.maxpool
        self.layer1 = self.features.layer1
        self.layer2 = self.features.layer2
        self.layer3 = self.features.layer3
        self.layer4 = self.features.layer4

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu(self.bn1(x))
        x = self.maxpool1(x)
        feature1 = self.layer1(x)  # 1 / 4
        feature2 = self.layer2(feature1)  # 1 / 8
        feature3 = self.layer3(feature2)  # 1 / 16
        feature4 = self.layer4(feature3)  # 1 / 32
        # global average pooling to build tail
        tail = torch.mean(feature4, 3, keepdim=True)
        tail = torch.mean(tail, 2, keepdim=True)
        return feature3, feature4, tail


def build_contextpath(name):
    model = {
        'resnet18': resnet18(pretrained=True),
        'resnet101': resnet101(pretrained=True)
    }
    return model[name]

# %%
import torch
from torch import nn
import warnings
warnings.filterwarnings(action='ignore')


class ConvBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size,
                               stride=stride, padding=padding, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, input):
        x = self.conv1(input)
        return self.relu(self.bn(x))


class Spatial_path(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.convblock1 = ConvBlock(in_channels=3, out_channels=64)
        self.convblock2 = ConvBlock(in_channels=64, out_channels=128)
        self.convblock3 = ConvBlock(in_channels=128, out_channels=256)

    def forward(self, input):
        x = self.convblock1(input)
        x = self.convblock2(x)
        x = self.convblock3(x)
        return x


class AttentionRefinementModule(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.sigmoid = nn.Sigmoid()
        self.in_channels = in_channels
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

    def forward(self, input):
        # global average pooling
        x = self.avgpool(input)
        assert self.in_channels == x.size(1), 'in_channels and out_channels should all be {}'.format(x.size(1))
        x = self.conv(x)
        x = self.sigmoid(self.bn(x))
        # x = self.sigmoid(x)
        # channels of input and x should be same
        x = torch.mul(input, x)
        return x


class FeatureFusionModule(torch.nn.Module):
    def __init__(self, num_classes, in_channels):
        super().__init__()
        # self.in_channels = input_1.channels + input_2.channels
        # resnet101 3328 = 256(from spatial path) + 1024(from context path) + 2048(from context path)
        # resnet18  1024 = 256(from spatial path) + 256(from context path) + 512(from context path)
        self.in_channels = in_channels

        self.convblock = ConvBlock(in_channels=self.in_channels, out_channels=num_classes, stride=1)
        self.conv1 = nn.Conv2d(num_classes, num_classes, kernel_size=1)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(num_classes, num_classes, kernel_size=1)
        self.sigmoid = nn.Sigmoid()
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

    def forward(self, input_1, input_2):
        x = torch.cat((input_1, input_2), dim=1)
        assert self.in_channels == x.size(1), 'in_channels of ConvBlock should be {}'.format(x.size(1))
        feature = self.convblock(x)
        x = self.avgpool(feature)

        x = self.relu(self.conv1(x))
        x = self.sigmoid(self.conv2(x))
        x = torch.mul(feature, x)
        x = torch.add(x, feature)
        return x


class BiSeNet(torch.nn.Module):
    def __init__(self, num_classes, context_path):
        super().__init__()
        # build spatial path
        self.saptial_path = Spatial_path()

        # build context path
        self.context_path = build_contextpath(name=context_path)

        # build attention refinement module  for resnet 101
        if context_path == 'resnet101':
            self.attention_refinement_module1 = AttentionRefinementModule(1024, 1024)
            self.attention_refinement_module2 = AttentionRefinementModule(2048, 2048)
            # supervision block
            self.supervision1 = nn.Conv2d(in_channels=1024, out_channels=num_classes, kernel_size=1)
            self.supervision2 = nn.Conv2d(in_channels=2048, out_channels=num_classes, kernel_size=1)
            # build feature fusion module
            self.feature_fusion_module = FeatureFusionModule(num_classes, 3328)

        elif context_path == 'resnet18':
            # build attention refinement module  for resnet 18
            self.attention_refinement_module1 = AttentionRefinementModule(256, 256)
            self.attention_refinement_module2 = AttentionRefinementModule(512, 512)
            # supervision block
            self.supervision1 = nn.Conv2d(in_channels=256, out_channels=num_classes, kernel_size=1)
            self.supervision2 = nn.Conv2d(in_channels=512, out_channels=num_classes, kernel_size=1)
            # build feature fusion module
            self.feature_fusion_module = FeatureFusionModule(num_classes, 1024)
        else:
            print('Error: unspport context_path network \n')

        # build final convolution
        self.conv = nn.Conv2d(in_channels=num_classes, out_channels=num_classes, kernel_size=1)

        self.init_weight()

        self.mul_lr = []
        self.mul_lr.append(self.saptial_path)
        self.mul_lr.append(self.attention_refinement_module1)
        self.mul_lr.append(self.attention_refinement_module2)
        self.mul_lr.append(self.supervision1)
        self.mul_lr.append(self.supervision2)
        self.mul_lr.append(self.feature_fusion_module)
        self.mul_lr.append(self.conv)

    def init_weight(self):
        for name, m in self.named_modules():
            if 'context_path' not in name:
                if isinstance(m, nn.Conv2d):
                    nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                elif isinstance(m, nn.BatchNorm2d):
                    m.eps = 1e-5
                    m.momentum = 0.1
                    nn.init.constant_(m.weight, 1)
                    nn.init.constant_(m.bias, 0)

    def forward(self, input):
        # output of spatial path
        sx = self.saptial_path(input)

        # output of context path
        cx1, cx2, tail = self.context_path(input)
        cx1 = self.attention_refinement_module1(cx1)
        cx2 = self.attention_refinement_module2(cx2)
        cx2 = torch.mul(cx2, tail)
        # upsampling
        cx1 = torch.nn.functional.interpolate(cx1, size=sx.size()[-2:], mode='bilinear')
        cx2 = torch.nn.functional.interpolate(cx2, size=sx.size()[-2:], mode='bilinear')
        cx = torch.cat((cx1, cx2), dim=1)

        if self.training == True:
            cx1_sup = self.supervision1(cx1)
            cx2_sup = self.supervision2(cx2)
            cx1_sup = torch.nn.functional.interpolate(cx1_sup, size=input.size()[-2:], mode='bilinear')
            cx2_sup = torch.nn.functional.interpolate(cx2_sup, size=input.size()[-2:], mode='bilinear')

        # output of feature fusion module
        result = self.feature_fusion_module(sx, cx)

        # upsampling
        result = torch.nn.functional.interpolate(result, scale_factor=8, mode='bilinear')
        result = self.conv(result)

        if self.training == True:
            return result, cx1_sup, cx2_sup

        return result

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
from torchvision import transforms

class CityScapes(Dataset):
    def __init__(self, root_dir, split='train', transform=None, target_transform=None):
        super(CityScapes, self).__init__()
        self.root_dir = root_dir
        self.split = split
        self.transform = transform
        self.target_transform = target_transform

        self.images_dir = os.path.join(root_dir, 'images', split)
        self.labels_dir = os.path.join(root_dir, 'gtFine', split)

        self.images = []
        self.labels = []

        for city in os.listdir(self.images_dir):
            img_dir = os.path.join(self.images_dir, city)
            lbl_dir = os.path.join(self.labels_dir, city)

            for file_name in os.listdir(img_dir):
                if file_name.endswith('_leftImg8bit.png'):
                    img_path = os.path.join(img_dir, file_name)
                    lbl_path = os.path.join(lbl_dir, file_name.replace('_leftImg8bit.png', '_gtFine_labelTrainIds.png'))

                    if not os.path.exists(img_path):
                        print(f"Image file does not exist: {img_path}")
                    if not os.path.exists(lbl_path):
                        print(f"Label file does not exist: {lbl_path}")

                    self.images.append(img_path)
                    self.labels.append(lbl_path)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        lbl_path = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        label = Image.open(lbl_path)

        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)

        return image, label

    def get_class_names(self):
        return ['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light', 'traffic sign',
                'vegetation', 'terrain', 'sky', 'person', 'rider', 'car', 'truck', 'bus', 'train',
                'motorcycle', 'bicycle']

# %%
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# Hyperparameters
num_epochs = 50
learning_rate = 1e-4
batch_size = 4
num_classes = 19
root_dir = '/content/drive/MyDrive/Colab Notebooks/MlDl/Cityscapes/Cityscapes/Cityspaces'

# Transforms
transform = transforms.Compose([
    transforms.Resize((512, 1024)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

target_transform = transforms.Compose([
    transforms.Resize((512, 1024), interpolation=Image.NEAREST),
    transforms.Lambda(lambda lbl: torch.tensor(np.array(lbl), dtype=torch.long)),
])

# Dataset and Dataloader
train_dataset = CityScapes(root_dir=root_dir, split='train', transform=transform, target_transform=target_transform)
val_dataset = CityScapes(root_dir=root_dir, split='val', transform=transform, target_transform=target_transform)

print(f"Dataset size: {len(train_dataset)}")
print(f"Val_Dataset size: {len(val_dataset)}")

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Model
model = BiSeNet(num_classes=num_classes, context_path='resnet18').to(device)
# Loss and Optimizer
criterion = nn.CrossEntropyLoss(ignore_index=255)
# Optimizer - change from Adam to SGD
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

class_names = train_dataset.get_class_names()
# Out:
# cuda
# Dataset size: 1572
# Val_Dataset size: 500
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 180MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [00:00<00:00, 214MB/s]

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np

best_mIoU = 0.0
train_losses = []
val_losses = []
train_mIoUs = []
val_mIoUs = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    hist_train = np.zeros((num_classes, num_classes))
    for iter, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device).long()

        # Forward pass
        optimizer.zero_grad()
        outputs, _, _ = model(images)  # Extract the first element of the tuple
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Update learning rate
        current_iter = epoch * len(train_loader) + iter
        poly_lr_scheduler(optimizer, learning_rate, current_iter, max_iter=num_epochs * len(train_loader))

        running_loss += loss.item()

        # Calculate training mIoU
        preds_train = torch.argmax(outputs, dim=1)
        hist_train += fast_hist(labels.cpu().numpy().flatten(), preds_train.cpu().numpy().flatten(), num_classes)

        if (iter + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{iter+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

    avg_train_loss = running_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_train_loss:.4f}')

    train_mIoUs_epoch = per_class_iou(hist_train)
    avg_train_mIoU = np.mean(train_mIoUs_epoch)
    train_mIoUs.append(avg_train_mIoU)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Mean mIoU: {avg_train_mIoU:.4f}')

    # Validation
    model.eval()
    hist_val = np.zeros((num_classes, num_classes))
    running_val_loss = 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)
            preds_val = torch.argmax(outputs, dim=1)
            val_loss = criterion(outputs, labels)
            running_val_loss += val_loss.item()

            hist_val += fast_hist(labels.cpu().numpy().flatten(), preds_val.cpu().numpy().flatten(), num_classes)

    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)

    val_mIoUs_epoch = per_class_iou(hist_val)
    avg_val_mIoU = np.mean(val_mIoUs_epoch)
    val_mIoUs.append(avg_val_mIoU)
    print(f'Epoch [{epoch+1}/{num_epochs}], Val Mean mIoU: {avg_val_mIoU:.4f}')
    for i, iou in enumerate(val_mIoUs_epoch):
        print(f'{class_names[i]}: Val mIoU = {iou:.4f}')

    # Save the model if it has the best mIoU so far
    if avg_val_mIoU > best_mIoU:
        best_mIoU = avg_val_mIoU
        torch.save(model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/MlDl/best_model_2b.pth')
        print(f'Model saved with Mean mIoU: {avg_val_mIoU:.4f}')

    # Clear cache to free up memory
    torch.cuda.empty_cache()
# Out:
# Epoch [1/50], Step [10/393], Loss: 1.1008
# Epoch [1/50], Step [20/393], Loss: 1.2165
# Epoch [1/50], Step [30/393], Loss: 1.2871
# Epoch [1/50], Step [40/393], Loss: 1.2550
# Epoch [1/50], Step [50/393], Loss: 1.6539
# Epoch [1/50], Step [60/393], Loss: 1.0510
# Epoch [1/50], Step [70/393], Loss: 1.2151
# Epoch [1/50], Step [80/393], Loss: 1.1125
# Epoch [1/50], Step [90/393], Loss: 1.3180
# Epoch [1/50], Step [100/393], Loss: 1.1209
# Epoch [1/50], Step [110/393], Loss: 1.2297
# Epoch [1/50], Step [120/393], Loss: 1.2195
# Epoch [1/50], Step [130/393], Loss: 1.0361
# Epoch [1/50], Step [140/393], Loss: 1.1328
# Epoch [1/50], Step [150/393], Loss: 1.0702
# Epoch [1/50], Step [160/393], Loss: 1.1850
# Epoch [1/50], Step [170/393], Loss: 1.2232
# Epoch [1/50], Step [180/393], Loss: 1.0514
# Epoch [1/50], Step [190/393], Loss: 1.0657
# Epoch [1/50], Step [200/393], Loss: 1.0473
# Epoch [1/50], Step [210/393], Loss: 0.9509
# Epoch [1/50], Step [220/393], Loss: 0.9269
# Epoch [1/50], Step [230/393], Loss: 0.9927
# Epoch [1/50], Step [240/393], Loss: 0.8095
# Epoch [1/50], Step [250/393], Loss: 0.9061
# Epoch [1/50], Step [260/393], Loss: 0.9464
# Epoch [1/50], Step [270/393], Loss: 0.9862
# Epoch [1/50], Step [280/393], Loss: 0.9077
# Epoch [1/50], Step [290/393], Loss: 0.8562
# Epoch [1/50], Step [300/393], Loss: 1.0070
# Epoch [1/50], Step [310/393], Loss: 0.8388
# Epoch [1/50], Step [320/393], Loss: 0.8402
# Epoch [1/50], Step [330/393], Loss: 0.9415
# Epoch [1/50], Step [340/393], Loss: 1.2042
# Epoch [1/50], Step [350/393], Loss: 0.9645
# Epoch [1/50], Step [360/393], Loss: 0.9737
# Epoch [1/50], Step [370/393], Loss: 0.9353
# Epoch [1/50], Step [380/393], Loss: 0.9456
# Epoch [1/50], Step [390/393], Loss: 1.1791
# Epoch [1/50], Loss: 1.0879
# Epoch [1/50], Train Mean mIoU: 0.1960
# Epoch [1/50], Val Mean mIoU: 0.2086
# road: Val mIoU = 0.8579
# sidewalk: Val mIoU = 0.1868
# building: Val mIoU = 0.6797
# wall: Val mIoU = 0.0000
# fence: Val mIoU = 0.0039
# pole: Val mIoU = 0.0334
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0100
# vegetation: Val mIoU = 0.6965
# terrain: Val mIoU = 0.0085
# sky: Val mIoU = 0.6722
# person: Val mIoU = 0.1569
# rider: Val mIoU = 0.0002
# car: Val mIoU = 0.6118
# truck: Val mIoU = 0.0008
# bus: Val mIoU = 0.0019
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0039
# bicycle: Val mIoU = 0.0399
# Model saved with Mean mIoU: 0.2086
# Epoch [2/50], Step [10/393], Loss: 0.9476
# Epoch [2/50], Step [20/393], Loss: 0.8163
# Epoch [2/50], Step [30/393], Loss: 1.0554
# Epoch [2/50], Step [40/393], Loss: 1.2019
# Epoch [2/50], Step [50/393], Loss: 1.0629
# Epoch [2/50], Step [60/393], Loss: 1.0707
# Epoch [2/50], Step [70/393], Loss: 1.2685
# Epoch [2/50], Step [80/393], Loss: 0.9405
# Epoch [2/50], Step [90/393], Loss: 1.0073
# Epoch [2/50], Step [100/393], Loss: 0.9741
# Epoch [2/50], Step [110/393], Loss: 1.0099
# Epoch [2/50], Step [120/393], Loss: 1.0744
# Epoch [2/50], Step [130/393], Loss: 0.7619
# Epoch [2/50], Step [140/393], Loss: 0.7646
# Epoch [2/50], Step [150/393], Loss: 0.7473
# Epoch [2/50], Step [160/393], Loss: 0.7808
# Epoch [2/50], Step [170/393], Loss: 0.9092
# Epoch [2/50], Step [180/393], Loss: 0.8110
# Epoch [2/50], Step [190/393], Loss: 0.6997
# Epoch [2/50], Step [200/393], Loss: 1.0025
# Epoch [2/50], Step [210/393], Loss: 0.7561
# Epoch [2/50], Step [220/393], Loss: 0.9100
# Epoch [2/50], Step [230/393], Loss: 0.6624
# Epoch [2/50], Step [240/393], Loss: 0.8164
# Epoch [2/50], Step [250/393], Loss: 0.8840
# Epoch [2/50], Step [260/393], Loss: 0.8520
# Epoch [2/50], Step [270/393], Loss: 0.8054
# Epoch [2/50], Step [280/393], Loss: 0.7399
# Epoch [2/50], Step [290/393], Loss: 0.8537
# Epoch [2/50], Step [300/393], Loss: 0.7749
# Epoch [2/50], Step [310/393], Loss: 0.8348
# Epoch [2/50], Step [320/393], Loss: 0.7123
# Epoch [2/50], Step [330/393], Loss: 0.9311
# Epoch [2/50], Step [340/393], Loss: 0.8371
# Epoch [2/50], Step [350/393], Loss: 0.6608
# Epoch [2/50], Step [360/393], Loss: 0.9254
# Epoch [2/50], Step [370/393], Loss: 1.0215
# Epoch [2/50], Step [380/393], Loss: 0.7989
# Epoch [2/50], Step [390/393], Loss: 0.7007
# Epoch [2/50], Loss: 0.8554
# Epoch [2/50], Train Mean mIoU: 0.2230
# Epoch [2/50], Val Mean mIoU: 0.2305
# road: Val mIoU = 0.8765
# sidewalk: Val mIoU = 0.2923
# building: Val mIoU = 0.7143
# wall: Val mIoU = 0.0000
# fence: Val mIoU = 0.0047
# pole: Val mIoU = 0.0333
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0073
# vegetation: Val mIoU = 0.7415
# terrain: Val mIoU = 0.0167
# sky: Val mIoU = 0.7358
# person: Val mIoU = 0.2454
# rider: Val mIoU = 0.0001
# car: Val mIoU = 0.6561
# truck: Val mIoU = 0.0002
# bus: Val mIoU = 0.0019
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0025
# bicycle: Val mIoU = 0.0505
# Model saved with Mean mIoU: 0.2305
# Epoch [3/50], Step [10/393], Loss: 0.7104
# Epoch [3/50], Step [20/393], Loss: 0.7100
# Epoch [3/50], Step [30/393], Loss: 0.7274
# Epoch [3/50], Step [40/393], Loss: 0.9828
# Epoch [3/50], Step [50/393], Loss: 0.8824
# Epoch [3/50], Step [60/393], Loss: 0.7595
# Epoch [3/50], Step [70/393], Loss: 0.9624
# Epoch [3/50], Step [80/393], Loss: 0.7084
# Epoch [3/50], Step [90/393], Loss: 0.6770
# Epoch [3/50], Step [100/393], Loss: 1.0226
# Epoch [3/50], Step [110/393], Loss: 0.7382
# Epoch [3/50], Step [120/393], Loss: 0.7126
# Epoch [3/50], Step [130/393], Loss: 0.8630
# Epoch [3/50], Step [140/393], Loss: 0.6382
# Epoch [3/50], Step [150/393], Loss: 0.6002
# Epoch [3/50], Step [160/393], Loss: 0.7376
# Epoch [3/50], Step [170/393], Loss: 0.9214
# Epoch [3/50], Step [180/393], Loss: 0.6805
# Epoch [3/50], Step [190/393], Loss: 0.7138
# Epoch [3/50], Step [200/393], Loss: 0.7432
# Epoch [3/50], Step [210/393], Loss: 1.0449
# Epoch [3/50], Step [220/393], Loss: 0.6982
# Epoch [3/50], Step [230/393], Loss: 0.5969
# Epoch [3/50], Step [240/393], Loss: 0.5778
# Epoch [3/50], Step [250/393], Loss: 0.8760
# Epoch [3/50], Step [260/393], Loss: 0.6545
# Epoch [3/50], Step [270/393], Loss: 0.7807
# Epoch [3/50], Step [280/393], Loss: 0.5705
# Epoch [3/50], Step [290/393], Loss: 0.7998
# Epoch [3/50], Step [300/393], Loss: 0.5422
# Epoch [3/50], Step [310/393], Loss: 0.8540
# Epoch [3/50], Step [320/393], Loss: 0.9428
# Epoch [3/50], Step [330/393], Loss: 0.6728
# Epoch [3/50], Step [340/393], Loss: 0.6949
# Epoch [3/50], Step [350/393], Loss: 0.7752
# Epoch [3/50], Step [360/393], Loss: 0.9409
# Epoch [3/50], Step [370/393], Loss: 0.7065
# Epoch [3/50], Step [380/393], Loss: 0.7532
# Epoch [3/50], Step [390/393], Loss: 0.5345
# Epoch [3/50], Loss: 0.7504
# Epoch [3/50], Train Mean mIoU: 0.2365
# Epoch [3/50], Val Mean mIoU: 0.2411
# road: Val mIoU = 0.8841
# sidewalk: Val mIoU = 0.3373
# building: Val mIoU = 0.7265
# wall: Val mIoU = 0.0000
# fence: Val mIoU = 0.0061
# pole: Val mIoU = 0.0452
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0053
# vegetation: Val mIoU = 0.7447
# terrain: Val mIoU = 0.0360
# sky: Val mIoU = 0.7642
# person: Val mIoU = 0.2886
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.6690
# truck: Val mIoU = 0.0001
# bus: Val mIoU = 0.0018
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0057
# bicycle: Val mIoU = 0.0668
# Model saved with Mean mIoU: 0.2411
# Epoch [4/50], Step [10/393], Loss: 0.6698
# Epoch [4/50], Step [20/393], Loss: 0.7266
# Epoch [4/50], Step [30/393], Loss: 0.6043
# Epoch [4/50], Step [40/393], Loss: 0.6462
# Epoch [4/50], Step [50/393], Loss: 0.9045
# Epoch [4/50], Step [60/393], Loss: 0.6722
# Epoch [4/50], Step [70/393], Loss: 0.7335
# Epoch [4/50], Step [80/393], Loss: 0.5254
# Epoch [4/50], Step [90/393], Loss: 0.7728
# Epoch [4/50], Step [100/393], Loss: 0.6906
# Epoch [4/50], Step [110/393], Loss: 0.6683
# Epoch [4/50], Step [120/393], Loss: 1.0546
# Epoch [4/50], Step [130/393], Loss: 0.6603
# Epoch [4/50], Step [140/393], Loss: 0.5068
# Epoch [4/50], Step [150/393], Loss: 0.6153
# Epoch [4/50], Step [160/393], Loss: 0.6215
# Epoch [4/50], Step [170/393], Loss: 0.7185
# Epoch [4/50], Step [180/393], Loss: 0.6162
# Epoch [4/50], Step [190/393], Loss: 0.6216
# Epoch [4/50], Step [200/393], Loss: 0.6123
# Epoch [4/50], Step [210/393], Loss: 0.8073
# Epoch [4/50], Step [220/393], Loss: 0.5657
# Epoch [4/50], Step [230/393], Loss: 0.9952
# Epoch [4/50], Step [240/393], Loss: 0.4819
# Epoch [4/50], Step [250/393], Loss: 0.5823
# Epoch [4/50], Step [260/393], Loss: 0.8385
# Epoch [4/50], Step [270/393], Loss: 0.6651
# Epoch [4/50], Step [280/393], Loss: 0.5801
# Epoch [4/50], Step [290/393], Loss: 0.6290
# Epoch [4/50], Step [300/393], Loss: 0.6794
# Epoch [4/50], Step [310/393], Loss: 0.5993
# Epoch [4/50], Step [320/393], Loss: 0.6709
# Epoch [4/50], Step [330/393], Loss: 0.8491
# Epoch [4/50], Step [340/393], Loss: 0.6538
# Epoch [4/50], Step [350/393], Loss: 0.7231
# Epoch [4/50], Step [360/393], Loss: 0.5129
# Epoch [4/50], Step [370/393], Loss: 0.7556
# Epoch [4/50], Step [380/393], Loss: 0.5387
# Epoch [4/50], Step [390/393], Loss: 0.6672
# Epoch [4/50], Loss: 0.6837
# Epoch [4/50], Train Mean mIoU: 0.2458
# Epoch [4/50], Val Mean mIoU: 0.2489
# road: Val mIoU = 0.8921
# sidewalk: Val mIoU = 0.3774
# building: Val mIoU = 0.7311
# wall: Val mIoU = 0.0000
# fence: Val mIoU = 0.0033
# pole: Val mIoU = 0.0375
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0051
# vegetation: Val mIoU = 0.7618
# terrain: Val mIoU = 0.0373
# sky: Val mIoU = 0.7821
# person: Val mIoU = 0.3298
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.6858
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0007
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0075
# bicycle: Val mIoU = 0.0769
# Model saved with Mean mIoU: 0.2489
# Epoch [5/50], Step [10/393], Loss: 0.6571
# Epoch [5/50], Step [20/393], Loss: 0.6488
# Epoch [5/50], Step [30/393], Loss: 0.6550
# Epoch [5/50], Step [40/393], Loss: 0.6832
# Epoch [5/50], Step [50/393], Loss: 0.5489
# Epoch [5/50], Step [60/393], Loss: 0.7327
# Epoch [5/50], Step [70/393], Loss: 0.5157
# Epoch [5/50], Step [80/393], Loss: 0.6511
# Epoch [5/50], Step [90/393], Loss: 0.5054
# Epoch [5/50], Step [100/393], Loss: 0.7922
# Epoch [5/50], Step [110/393], Loss: 0.5030
# Epoch [5/50], Step [120/393], Loss: 0.5479
# Epoch [5/50], Step [130/393], Loss: 0.8463
# Epoch [5/50], Step [140/393], Loss: 0.5242
# Epoch [5/50], Step [150/393], Loss: 0.5109
# Epoch [5/50], Step [160/393], Loss: 0.6254
# Epoch [5/50], Step [170/393], Loss: 0.5651
# Epoch [5/50], Step [180/393], Loss: 0.7788
# Epoch [5/50], Step [190/393], Loss: 0.6799
# Epoch [5/50], Step [200/393], Loss: 0.6212
# Epoch [5/50], Step [210/393], Loss: 0.6942
# Epoch [5/50], Step [220/393], Loss: 0.5663
# Epoch [5/50], Step [230/393], Loss: 0.7014
# Epoch [5/50], Step [240/393], Loss: 0.5549
# Epoch [5/50], Step [250/393], Loss: 0.6402
# Epoch [5/50], Step [260/393], Loss: 0.6617
# Epoch [5/50], Step [270/393], Loss: 0.5590
# Epoch [5/50], Step [280/393], Loss: 0.6351
# Epoch [5/50], Step [290/393], Loss: 0.6023
# Epoch [5/50], Step [300/393], Loss: 0.5823
# Epoch [5/50], Step [310/393], Loss: 0.5517
# Epoch [5/50], Step [320/393], Loss: 0.7864
# Epoch [5/50], Step [330/393], Loss: 0.4820
# Epoch [5/50], Step [340/393], Loss: 0.5506
# Epoch [5/50], Step [350/393], Loss: 1.0097
# Epoch [5/50], Step [360/393], Loss: 0.5898
# Epoch [5/50], Step [370/393], Loss: 0.5609
# Epoch [5/50], Step [380/393], Loss: 0.5344
# Epoch [5/50], Step [390/393], Loss: 0.5214
# Epoch [5/50], Loss: 0.6399
# Epoch [5/50], Train Mean mIoU: 0.2541
# Epoch [5/50], Val Mean mIoU: 0.2534
# road: Val mIoU = 0.8962
# sidewalk: Val mIoU = 0.3931
# building: Val mIoU = 0.7335
# wall: Val mIoU = 0.0000
# fence: Val mIoU = 0.0061
# pole: Val mIoU = 0.0483
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0054
# vegetation: Val mIoU = 0.7698
# terrain: Val mIoU = 0.0470
# sky: Val mIoU = 0.7919
# person: Val mIoU = 0.3397
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.6899
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0006
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0063
# bicycle: Val mIoU = 0.0868
# Model saved with Mean mIoU: 0.2534
# Epoch [6/50], Step [10/393], Loss: 0.4829
# Epoch [6/50], Step [20/393], Loss: 0.6950
# Epoch [6/50], Step [30/393], Loss: 0.6266
# Epoch [6/50], Step [40/393], Loss: 0.5336
# Epoch [6/50], Step [50/393], Loss: 0.6518
# Epoch [6/50], Step [60/393], Loss: 0.7633
# Epoch [6/50], Step [70/393], Loss: 0.5458
# Epoch [6/50], Step [80/393], Loss: 0.4406
# Epoch [6/50], Step [90/393], Loss: 0.8045
# Epoch [6/50], Step [100/393], Loss: 0.5814
# Epoch [6/50], Step [110/393], Loss: 0.6841
# Epoch [6/50], Step [120/393], Loss: 0.7701
# Epoch [6/50], Step [130/393], Loss: 0.5195
# Epoch [6/50], Step [140/393], Loss: 0.5881
# Epoch [6/50], Step [150/393], Loss: 0.5722
# Epoch [6/50], Step [160/393], Loss: 0.5490
# Epoch [6/50], Step [170/393], Loss: 0.4762
# Epoch [6/50], Step [180/393], Loss: 0.7626
# Epoch [6/50], Step [190/393], Loss: 0.8909
# Epoch [6/50], Step [200/393], Loss: 0.7005
# Epoch [6/50], Step [210/393], Loss: 0.6556
# Epoch [6/50], Step [220/393], Loss: 0.5779
# Epoch [6/50], Step [230/393], Loss: 0.6444
# Epoch [6/50], Step [240/393], Loss: 0.4932
# Epoch [6/50], Step [250/393], Loss: 0.5170
# Epoch [6/50], Step [260/393], Loss: 0.6826
# Epoch [6/50], Step [270/393], Loss: 0.6824
# Epoch [6/50], Step [280/393], Loss: 0.5493
# Epoch [6/50], Step [290/393], Loss: 0.5810
# Epoch [6/50], Step [300/393], Loss: 0.4797
# Epoch [6/50], Step [310/393], Loss: 0.5380
# Epoch [6/50], Step [320/393], Loss: 0.4908
# Epoch [6/50], Step [330/393], Loss: 0.5054
# Epoch [6/50], Step [340/393], Loss: 0.5294
# Epoch [6/50], Step [350/393], Loss: 1.0024
# Epoch [6/50], Step [360/393], Loss: 0.5947
# Epoch [6/50], Step [370/393], Loss: 0.4539
# Epoch [6/50], Step [380/393], Loss: 0.6299
# Epoch [6/50], Step [390/393], Loss: 0.6554
# Epoch [6/50], Loss: 0.6023
# Epoch [6/50], Train Mean mIoU: 0.2617
# Epoch [6/50], Val Mean mIoU: 0.2575
# road: Val mIoU = 0.8998
# sidewalk: Val mIoU = 0.4053
# building: Val mIoU = 0.7373
# wall: Val mIoU = 0.0002
# fence: Val mIoU = 0.0084
# pole: Val mIoU = 0.0453
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0065
# vegetation: Val mIoU = 0.7740
# terrain: Val mIoU = 0.0612
# sky: Val mIoU = 0.7985
# person: Val mIoU = 0.3528
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.6943
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0001
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0089
# bicycle: Val mIoU = 0.0992
# Model saved with Mean mIoU: 0.2575
# Epoch [7/50], Step [10/393], Loss: 0.5346
# Epoch [7/50], Step [20/393], Loss: 0.5848
# Epoch [7/50], Step [30/393], Loss: 0.4915
# Epoch [7/50], Step [40/393], Loss: 0.6324
# Epoch [7/50], Step [50/393], Loss: 0.5073
# Epoch [7/50], Step [60/393], Loss: 0.5635
# Epoch [7/50], Step [70/393], Loss: 0.6513
# Epoch [7/50], Step [80/393], Loss: 0.5344
# Epoch [7/50], Step [90/393], Loss: 0.9581
# Epoch [7/50], Step [100/393], Loss: 0.5427
# Epoch [7/50], Step [110/393], Loss: 0.6691
# Epoch [7/50], Step [120/393], Loss: 0.5473
# Epoch [7/50], Step [130/393], Loss: 0.6627
# Epoch [7/50], Step [140/393], Loss: 0.7663
# Epoch [7/50], Step [150/393], Loss: 0.5462
# Epoch [7/50], Step [160/393], Loss: 0.5940
# Epoch [7/50], Step [170/393], Loss: 0.5524
# Epoch [7/50], Step [180/393], Loss: 0.5845
# Epoch [7/50], Step [190/393], Loss: 0.7418
# Epoch [7/50], Step [200/393], Loss: 0.5117
# Epoch [7/50], Step [210/393], Loss: 0.5826
# Epoch [7/50], Step [220/393], Loss: 0.5356
# Epoch [7/50], Step [230/393], Loss: 0.4853
# Epoch [7/50], Step [240/393], Loss: 0.6310
# Epoch [7/50], Step [250/393], Loss: 0.4096
# Epoch [7/50], Step [260/393], Loss: 0.4741
# Epoch [7/50], Step [270/393], Loss: 0.4643
# Epoch [7/50], Step [280/393], Loss: 0.5038
# Epoch [7/50], Step [290/393], Loss: 0.5127
# Epoch [7/50], Step [300/393], Loss: 0.4968
# Epoch [7/50], Step [310/393], Loss: 0.4964
# Epoch [7/50], Step [320/393], Loss: 0.4794
# Epoch [7/50], Step [330/393], Loss: 0.4782
# Epoch [7/50], Step [340/393], Loss: 0.5540
# Epoch [7/50], Step [350/393], Loss: 0.6063
# Epoch [7/50], Step [360/393], Loss: 0.5083
# Epoch [7/50], Step [370/393], Loss: 0.6198
# Epoch [7/50], Step [380/393], Loss: 0.4936
# Epoch [7/50], Step [390/393], Loss: 0.5921
# Epoch [7/50], Loss: 0.5806
# Epoch [7/50], Train Mean mIoU: 0.2665
# Epoch [7/50], Val Mean mIoU: 0.2667
# road: Val mIoU = 0.8998
# sidewalk: Val mIoU = 0.4157
# building: Val mIoU = 0.7472
# wall: Val mIoU = 0.0002
# fence: Val mIoU = 0.0163
# pole: Val mIoU = 0.0506
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0074
# vegetation: Val mIoU = 0.7775
# terrain: Val mIoU = 0.1351
# sky: Val mIoU = 0.7980
# person: Val mIoU = 0.3721
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7101
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0004
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0114
# bicycle: Val mIoU = 0.1262
# Model saved with Mean mIoU: 0.2667
# Epoch [8/50], Step [10/393], Loss: 0.4806
# Epoch [8/50], Step [20/393], Loss: 0.4572
# Epoch [8/50], Step [30/393], Loss: 0.6003
# Epoch [8/50], Step [40/393], Loss: 0.4429
# Epoch [8/50], Step [50/393], Loss: 0.4756
# Epoch [8/50], Step [60/393], Loss: 0.8608
# Epoch [8/50], Step [70/393], Loss: 0.5438
# Epoch [8/50], Step [80/393], Loss: 0.7541
# Epoch [8/50], Step [90/393], Loss: 0.4170
# Epoch [8/50], Step [100/393], Loss: 0.8562
# Epoch [8/50], Step [110/393], Loss: 0.6505
# Epoch [8/50], Step [120/393], Loss: 0.5347
# Epoch [8/50], Step [130/393], Loss: 0.4916
# Epoch [8/50], Step [140/393], Loss: 0.5545
# Epoch [8/50], Step [150/393], Loss: 0.5347
# Epoch [8/50], Step [160/393], Loss: 0.4868
# Epoch [8/50], Step [170/393], Loss: 0.5186
# Epoch [8/50], Step [180/393], Loss: 0.6400
# Epoch [8/50], Step [190/393], Loss: 0.4926
# Epoch [8/50], Step [200/393], Loss: 0.9232
# Epoch [8/50], Step [210/393], Loss: 0.7109
# Epoch [8/50], Step [220/393], Loss: 0.5748
# Epoch [8/50], Step [230/393], Loss: 0.5791
# Epoch [8/50], Step [240/393], Loss: 0.5777
# Epoch [8/50], Step [250/393], Loss: 0.4605
# Epoch [8/50], Step [260/393], Loss: 0.5709
# Epoch [8/50], Step [270/393], Loss: 0.4379
# Epoch [8/50], Step [280/393], Loss: 0.4931
# Epoch [8/50], Step [290/393], Loss: 0.5300
# Epoch [8/50], Step [300/393], Loss: 0.6370
# Epoch [8/50], Step [310/393], Loss: 0.6125
# Epoch [8/50], Step [320/393], Loss: 0.5712
# Epoch [8/50], Step [330/393], Loss: 0.5022
# Epoch [8/50], Step [340/393], Loss: 0.5524
# Epoch [8/50], Step [350/393], Loss: 0.6786
# Epoch [8/50], Step [360/393], Loss: 0.5736
# Epoch [8/50], Step [370/393], Loss: 0.4709
# Epoch [8/50], Step [380/393], Loss: 0.5174
# Epoch [8/50], Step [390/393], Loss: 0.5986
# Epoch [8/50], Loss: 0.5614
# Epoch [8/50], Train Mean mIoU: 0.2744
# Epoch [8/50], Val Mean mIoU: 0.2730
# road: Val mIoU = 0.9068
# sidewalk: Val mIoU = 0.4521
# building: Val mIoU = 0.7470
# wall: Val mIoU = 0.0013
# fence: Val mIoU = 0.0224
# pole: Val mIoU = 0.0663
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0077
# vegetation: Val mIoU = 0.7801
# terrain: Val mIoU = 0.1475
# sky: Val mIoU = 0.8056
# person: Val mIoU = 0.3741
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7171
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0002
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0147
# bicycle: Val mIoU = 0.1433
# Model saved with Mean mIoU: 0.2730
# Epoch [9/50], Step [10/393], Loss: 0.8680
# Epoch [9/50], Step [20/393], Loss: 0.4965
# Epoch [9/50], Step [30/393], Loss: 0.4911
# Epoch [9/50], Step [40/393], Loss: 0.5547
# Epoch [9/50], Step [50/393], Loss: 0.6852
# Epoch [9/50], Step [60/393], Loss: 0.5207
# Epoch [9/50], Step [70/393], Loss: 0.5864
# Epoch [9/50], Step [80/393], Loss: 0.5277
# Epoch [9/50], Step [90/393], Loss: 0.6214
# Epoch [9/50], Step [100/393], Loss: 0.5560
# Epoch [9/50], Step [110/393], Loss: 0.5750
# Epoch [9/50], Step [120/393], Loss: 0.3746
# Epoch [9/50], Step [130/393], Loss: 0.5383
# Epoch [9/50], Step [140/393], Loss: 0.4549
# Epoch [9/50], Step [150/393], Loss: 0.4843
# Epoch [9/50], Step [160/393], Loss: 0.3503
# Epoch [9/50], Step [170/393], Loss: 0.4597
# Epoch [9/50], Step [180/393], Loss: 0.5185
# Epoch [9/50], Step [190/393], Loss: 0.5962
# Epoch [9/50], Step [200/393], Loss: 0.4053
# Epoch [9/50], Step [210/393], Loss: 0.5171
# Epoch [9/50], Step [220/393], Loss: 0.4209
# Epoch [9/50], Step [230/393], Loss: 0.5596
# Epoch [9/50], Step [240/393], Loss: 0.6557
# Epoch [9/50], Step [250/393], Loss: 0.7173
# Epoch [9/50], Step [260/393], Loss: 0.4213
# Epoch [9/50], Step [270/393], Loss: 0.7063
# Epoch [9/50], Step [280/393], Loss: 0.4758
# Epoch [9/50], Step [290/393], Loss: 0.5725
# Epoch [9/50], Step [300/393], Loss: 0.5674
# Epoch [9/50], Step [310/393], Loss: 0.5008
# Epoch [9/50], Step [320/393], Loss: 0.5776
# Epoch [9/50], Step [330/393], Loss: 0.4051
# Epoch [9/50], Step [340/393], Loss: 0.4404
# Epoch [9/50], Step [350/393], Loss: 0.4463
# Epoch [9/50], Step [360/393], Loss: 0.4853
# Epoch [9/50], Step [370/393], Loss: 0.5899
# Epoch [9/50], Step [380/393], Loss: 0.4741
# Epoch [9/50], Step [390/393], Loss: 0.5107
# Epoch [9/50], Loss: 0.5412
# Epoch [9/50], Train Mean mIoU: 0.2811
# Epoch [9/50], Val Mean mIoU: 0.2785
# road: Val mIoU = 0.9093
# sidewalk: Val mIoU = 0.4617
# building: Val mIoU = 0.7450
# wall: Val mIoU = 0.0008
# fence: Val mIoU = 0.0296
# pole: Val mIoU = 0.0658
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0105
# vegetation: Val mIoU = 0.7838
# terrain: Val mIoU = 0.1718
# sky: Val mIoU = 0.8113
# person: Val mIoU = 0.3827
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7231
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0003
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0183
# bicycle: Val mIoU = 0.1776
# Model saved with Mean mIoU: 0.2785
# Epoch [10/50], Step [10/393], Loss: 0.5070
# Epoch [10/50], Step [20/393], Loss: 0.6204
# Epoch [10/50], Step [30/393], Loss: 1.0881
# Epoch [10/50], Step [40/393], Loss: 0.4621
# Epoch [10/50], Step [50/393], Loss: 0.5253
# Epoch [10/50], Step [60/393], Loss: 0.4830
# Epoch [10/50], Step [70/393], Loss: 0.4054
# Epoch [10/50], Step [80/393], Loss: 0.6450
# Epoch [10/50], Step [90/393], Loss: 0.4934
# Epoch [10/50], Step [100/393], Loss: 0.5523
# Epoch [10/50], Step [110/393], Loss: 0.6764
# Epoch [10/50], Step [120/393], Loss: 0.4272
# Epoch [10/50], Step [130/393], Loss: 0.4544
# Epoch [10/50], Step [140/393], Loss: 0.5535
# Epoch [10/50], Step [150/393], Loss: 0.4865
# Epoch [10/50], Step [160/393], Loss: 0.5492
# Epoch [10/50], Step [170/393], Loss: 0.7480
# Epoch [10/50], Step [180/393], Loss: 0.4469
# Epoch [10/50], Step [190/393], Loss: 0.4949
# Epoch [10/50], Step [200/393], Loss: 0.4886
# Epoch [10/50], Step [210/393], Loss: 0.5482
# Epoch [10/50], Step [220/393], Loss: 0.6495
# Epoch [10/50], Step [230/393], Loss: 0.4610
# Epoch [10/50], Step [240/393], Loss: 0.6375
# Epoch [10/50], Step [250/393], Loss: 0.6982
# Epoch [10/50], Step [260/393], Loss: 0.5020
# Epoch [10/50], Step [270/393], Loss: 0.6037
# Epoch [10/50], Step [280/393], Loss: 0.6429
# Epoch [10/50], Step [290/393], Loss: 0.3934
# Epoch [10/50], Step [300/393], Loss: 0.5099
# Epoch [10/50], Step [310/393], Loss: 0.5626
# Epoch [10/50], Step [320/393], Loss: 0.4289
# Epoch [10/50], Step [330/393], Loss: 0.4082
# Epoch [10/50], Step [340/393], Loss: 0.4851
# Epoch [10/50], Step [350/393], Loss: 0.5001
# Epoch [10/50], Step [360/393], Loss: 0.5117
# Epoch [10/50], Step [370/393], Loss: 0.4771
# Epoch [10/50], Step [380/393], Loss: 0.5932
# Epoch [10/50], Step [390/393], Loss: 0.5808
# Epoch [10/50], Loss: 0.5266
# Epoch [10/50], Train Mean mIoU: 0.2873
# Epoch [10/50], Val Mean mIoU: 0.2813
# road: Val mIoU = 0.9098
# sidewalk: Val mIoU = 0.4674
# building: Val mIoU = 0.7581
# wall: Val mIoU = 0.0021
# fence: Val mIoU = 0.0515
# pole: Val mIoU = 0.0633
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0144
# vegetation: Val mIoU = 0.7836
# terrain: Val mIoU = 0.1987
# sky: Val mIoU = 0.8151
# person: Val mIoU = 0.3924
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7136
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0002
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0198
# bicycle: Val mIoU = 0.1551
# Model saved with Mean mIoU: 0.2813
# Epoch [11/50], Step [10/393], Loss: 0.5122
# Epoch [11/50], Step [20/393], Loss: 0.4898
# Epoch [11/50], Step [30/393], Loss: 0.7404
# Epoch [11/50], Step [40/393], Loss: 0.6395
# Epoch [11/50], Step [50/393], Loss: 0.4351
# Epoch [11/50], Step [60/393], Loss: 0.5771
# Epoch [11/50], Step [70/393], Loss: 0.3577
# Epoch [11/50], Step [80/393], Loss: 0.3801
# Epoch [11/50], Step [90/393], Loss: 0.6339
# Epoch [11/50], Step [100/393], Loss: 0.5044
# Epoch [11/50], Step [110/393], Loss: 0.5863
# Epoch [11/50], Step [120/393], Loss: 0.6611
# Epoch [11/50], Step [130/393], Loss: 0.4593
# Epoch [11/50], Step [140/393], Loss: 0.4229
# Epoch [11/50], Step [150/393], Loss: 0.5147
# Epoch [11/50], Step [160/393], Loss: 0.4587
# Epoch [11/50], Step [170/393], Loss: 0.4786
# Epoch [11/50], Step [180/393], Loss: 0.6079
# Epoch [11/50], Step [190/393], Loss: 0.4931
# Epoch [11/50], Step [200/393], Loss: 0.5817
# Epoch [11/50], Step [210/393], Loss: 0.6182
# Epoch [11/50], Step [220/393], Loss: 0.5778
# Epoch [11/50], Step [230/393], Loss: 0.5463
# Epoch [11/50], Step [240/393], Loss: 0.6274
# Epoch [11/50], Step [250/393], Loss: 0.5009
# Epoch [11/50], Step [260/393], Loss: 0.7269
# Epoch [11/50], Step [270/393], Loss: 0.4346
# Epoch [11/50], Step [280/393], Loss: 0.5664
# Epoch [11/50], Step [290/393], Loss: 0.5353
# Epoch [11/50], Step [300/393], Loss: 0.5211
# Epoch [11/50], Step [310/393], Loss: 0.4607
# Epoch [11/50], Step [320/393], Loss: 0.5025
# Epoch [11/50], Step [330/393], Loss: 0.5383
# Epoch [11/50], Step [340/393], Loss: 0.7535
# Epoch [11/50], Step [350/393], Loss: 0.4793
# Epoch [11/50], Step [360/393], Loss: 0.6284
# Epoch [11/50], Step [370/393], Loss: 0.5497
# Epoch [11/50], Step [380/393], Loss: 0.5282
# Epoch [11/50], Step [390/393], Loss: 0.4114
# Epoch [11/50], Loss: 0.5138
# Epoch [11/50], Train Mean mIoU: 0.2942
# Epoch [11/50], Val Mean mIoU: 0.2893
# road: Val mIoU = 0.9117
# sidewalk: Val mIoU = 0.4736
# building: Val mIoU = 0.7547
# wall: Val mIoU = 0.0008
# fence: Val mIoU = 0.0676
# pole: Val mIoU = 0.0671
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0177
# vegetation: Val mIoU = 0.7885
# terrain: Val mIoU = 0.2363
# sky: Val mIoU = 0.8199
# person: Val mIoU = 0.3924
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7308
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0003
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0307
# bicycle: Val mIoU = 0.2052
# Model saved with Mean mIoU: 0.2893
# Epoch [12/50], Step [10/393], Loss: 0.4128
# Epoch [12/50], Step [20/393], Loss: 0.9062
# Epoch [12/50], Step [30/393], Loss: 0.4527
# Epoch [12/50], Step [40/393], Loss: 0.9501
# Epoch [12/50], Step [50/393], Loss: 0.4295
# Epoch [12/50], Step [60/393], Loss: 0.4110
# Epoch [12/50], Step [70/393], Loss: 0.3454
# Epoch [12/50], Step [80/393], Loss: 0.4456
# Epoch [12/50], Step [90/393], Loss: 0.5718
# Epoch [12/50], Step [100/393], Loss: 0.4680
# Epoch [12/50], Step [110/393], Loss: 0.6058
# Epoch [12/50], Step [120/393], Loss: 0.4524
# Epoch [12/50], Step [130/393], Loss: 0.6024
# Epoch [12/50], Step [140/393], Loss: 0.3983
# Epoch [12/50], Step [150/393], Loss: 0.4072
# Epoch [12/50], Step [160/393], Loss: 0.5523
# Epoch [12/50], Step [170/393], Loss: 0.6841
# Epoch [12/50], Step [180/393], Loss: 0.4053
# Epoch [12/50], Step [190/393], Loss: 0.3791
# Epoch [12/50], Step [200/393], Loss: 0.4722
# Epoch [12/50], Step [210/393], Loss: 0.4483
# Epoch [12/50], Step [220/393], Loss: 0.6713
# Epoch [12/50], Step [230/393], Loss: 0.6162
# Epoch [12/50], Step [240/393], Loss: 0.4049
# Epoch [12/50], Step [250/393], Loss: 0.5846
# Epoch [12/50], Step [260/393], Loss: 0.5752
# Epoch [12/50], Step [270/393], Loss: 0.5234
# Epoch [12/50], Step [280/393], Loss: 0.3751
# Epoch [12/50], Step [290/393], Loss: 0.3066
# Epoch [12/50], Step [300/393], Loss: 0.4699
# Epoch [12/50], Step [310/393], Loss: 0.4343
# Epoch [12/50], Step [320/393], Loss: 0.4224
# Epoch [12/50], Step [330/393], Loss: 0.4932
# Epoch [12/50], Step [340/393], Loss: 0.4907
# Epoch [12/50], Step [350/393], Loss: 0.3856
# Epoch [12/50], Step [360/393], Loss: 0.4587
# Epoch [12/50], Step [370/393], Loss: 0.5731
# Epoch [12/50], Step [380/393], Loss: 0.4762
# Epoch [12/50], Step [390/393], Loss: 0.5010
# Epoch [12/50], Loss: 0.5018
# Epoch [12/50], Train Mean mIoU: 0.2982
# Epoch [12/50], Val Mean mIoU: 0.2925
# road: Val mIoU = 0.9104
# sidewalk: Val mIoU = 0.4639
# building: Val mIoU = 0.7609
# wall: Val mIoU = 0.0013
# fence: Val mIoU = 0.0911
# pole: Val mIoU = 0.0701
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0281
# vegetation: Val mIoU = 0.7819
# terrain: Val mIoU = 0.2630
# sky: Val mIoU = 0.8108
# person: Val mIoU = 0.3996
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7311
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0005
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0366
# bicycle: Val mIoU = 0.2084
# Model saved with Mean mIoU: 0.2925
# Epoch [13/50], Step [10/393], Loss: 0.6540
# Epoch [13/50], Step [20/393], Loss: 0.4012
# Epoch [13/50], Step [30/393], Loss: 0.5939
# Epoch [13/50], Step [40/393], Loss: 0.4969
# Epoch [13/50], Step [50/393], Loss: 0.5778
# Epoch [13/50], Step [60/393], Loss: 0.5015
# Epoch [13/50], Step [70/393], Loss: 0.7707
# Epoch [13/50], Step [80/393], Loss: 0.5335
# Epoch [13/50], Step [90/393], Loss: 0.3939
# Epoch [13/50], Step [100/393], Loss: 0.4612
# Epoch [13/50], Step [110/393], Loss: 0.4227
# Epoch [13/50], Step [120/393], Loss: 0.3726
# Epoch [13/50], Step [130/393], Loss: 0.4883
# Epoch [13/50], Step [140/393], Loss: 0.5355
# Epoch [13/50], Step [150/393], Loss: 0.3870
# Epoch [13/50], Step [160/393], Loss: 0.4024
# Epoch [13/50], Step [170/393], Loss: 0.5989
# Epoch [13/50], Step [180/393], Loss: 0.3701
# Epoch [13/50], Step [190/393], Loss: 0.4102
# Epoch [13/50], Step [200/393], Loss: 0.4611
# Epoch [13/50], Step [210/393], Loss: 0.3591
# Epoch [13/50], Step [220/393], Loss: 1.0826
# Epoch [13/50], Step [230/393], Loss: 0.5464
# Epoch [13/50], Step [240/393], Loss: 0.7818
# Epoch [13/50], Step [250/393], Loss: 0.6242
# Epoch [13/50], Step [260/393], Loss: 0.4668
# Epoch [13/50], Step [270/393], Loss: 0.6200
# Epoch [13/50], Step [280/393], Loss: 0.4093
# Epoch [13/50], Step [290/393], Loss: 0.4747
# Epoch [13/50], Step [300/393], Loss: 0.4204
# Epoch [13/50], Step [310/393], Loss: 0.4420
# Epoch [13/50], Step [320/393], Loss: 0.4242
# Epoch [13/50], Step [330/393], Loss: 0.6102
# Epoch [13/50], Step [340/393], Loss: 0.4316
# Epoch [13/50], Step [350/393], Loss: 0.3410
# Epoch [13/50], Step [360/393], Loss: 0.5218
# Epoch [13/50], Step [370/393], Loss: 0.7872
# Epoch [13/50], Step [380/393], Loss: 0.5082
# Epoch [13/50], Step [390/393], Loss: 0.5738
# Epoch [13/50], Loss: 0.4931
# Epoch [13/50], Train Mean mIoU: 0.3021
# Epoch [13/50], Val Mean mIoU: 0.2918
# road: Val mIoU = 0.9131
# sidewalk: Val mIoU = 0.4753
# building: Val mIoU = 0.7470
# wall: Val mIoU = 0.0049
# fence: Val mIoU = 0.0752
# pole: Val mIoU = 0.0760
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0267
# vegetation: Val mIoU = 0.7922
# terrain: Val mIoU = 0.2540
# sky: Val mIoU = 0.8189
# person: Val mIoU = 0.3906
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7361
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0005
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0297
# bicycle: Val mIoU = 0.2035
# Epoch [14/50], Step [10/393], Loss: 0.5453
# Epoch [14/50], Step [20/393], Loss: 0.4286
# Epoch [14/50], Step [30/393], Loss: 0.4649
# Epoch [14/50], Step [40/393], Loss: 0.4517
# Epoch [14/50], Step [50/393], Loss: 0.4906
# Epoch [14/50], Step [60/393], Loss: 0.3877
# Epoch [14/50], Step [70/393], Loss: 0.5507
# Epoch [14/50], Step [80/393], Loss: 0.3960
# Epoch [14/50], Step [90/393], Loss: 0.6318
# Epoch [14/50], Step [100/393], Loss: 0.6364
# Epoch [14/50], Step [110/393], Loss: 0.3847
# Epoch [14/50], Step [120/393], Loss: 0.4769
# Epoch [14/50], Step [130/393], Loss: 0.5141
# Epoch [14/50], Step [140/393], Loss: 0.5252
# Epoch [14/50], Step [150/393], Loss: 0.4355
# Epoch [14/50], Step [160/393], Loss: 0.4217
# Epoch [14/50], Step [170/393], Loss: 0.6021
# Epoch [14/50], Step [180/393], Loss: 0.4513
# Epoch [14/50], Step [190/393], Loss: 0.4148
# Epoch [14/50], Step [200/393], Loss: 0.4254
# Epoch [14/50], Step [210/393], Loss: 0.4111
# Epoch [14/50], Step [220/393], Loss: 0.9344
# Epoch [14/50], Step [230/393], Loss: 0.4471
# Epoch [14/50], Step [240/393], Loss: 0.5197
# Epoch [14/50], Step [250/393], Loss: 0.3653
# Epoch [14/50], Step [260/393], Loss: 0.3681
# Epoch [14/50], Step [270/393], Loss: 0.4807
# Epoch [14/50], Step [280/393], Loss: 0.5716
# Epoch [14/50], Step [290/393], Loss: 0.5235
# Epoch [14/50], Step [300/393], Loss: 0.5829
# Epoch [14/50], Step [310/393], Loss: 0.3490
# Epoch [14/50], Step [320/393], Loss: 0.4550
# Epoch [14/50], Step [330/393], Loss: 0.4062
# Epoch [14/50], Step [340/393], Loss: 0.5153
# Epoch [14/50], Step [350/393], Loss: 0.4612
# Epoch [14/50], Step [360/393], Loss: 0.3615
# Epoch [14/50], Step [370/393], Loss: 0.5231
# Epoch [14/50], Step [380/393], Loss: 0.3755
# Epoch [14/50], Step [390/393], Loss: 0.3507
# Epoch [14/50], Loss: 0.4855
# Epoch [14/50], Train Mean mIoU: 0.3090
# Epoch [14/50], Val Mean mIoU: 0.2982
# road: Val mIoU = 0.9160
# sidewalk: Val mIoU = 0.4930
# building: Val mIoU = 0.7645
# wall: Val mIoU = 0.0044
# fence: Val mIoU = 0.1092
# pole: Val mIoU = 0.0712
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0281
# vegetation: Val mIoU = 0.7943
# terrain: Val mIoU = 0.2717
# sky: Val mIoU = 0.8237
# person: Val mIoU = 0.4086
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7301
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0004
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0334
# bicycle: Val mIoU = 0.2172
# Model saved with Mean mIoU: 0.2982
# Epoch [15/50], Step [10/393], Loss: 0.3890
# Epoch [15/50], Step [20/393], Loss: 0.4177
# Epoch [15/50], Step [30/393], Loss: 0.3866
# Epoch [15/50], Step [40/393], Loss: 0.4344
# Epoch [15/50], Step [50/393], Loss: 0.6279
# Epoch [15/50], Step [60/393], Loss: 0.3146
# Epoch [15/50], Step [70/393], Loss: 0.3745
# Epoch [15/50], Step [80/393], Loss: 0.4308
# Epoch [15/50], Step [90/393], Loss: 0.5525
# Epoch [15/50], Step [100/393], Loss: 0.3494
# Epoch [15/50], Step [110/393], Loss: 0.5435
# Epoch [15/50], Step [120/393], Loss: 0.4852
# Epoch [15/50], Step [130/393], Loss: 0.4889
# Epoch [15/50], Step [140/393], Loss: 0.5580
# Epoch [15/50], Step [150/393], Loss: 0.4003
# Epoch [15/50], Step [160/393], Loss: 0.3507
# Epoch [15/50], Step [170/393], Loss: 0.7058
# Epoch [15/50], Step [180/393], Loss: 0.6817
# Epoch [15/50], Step [190/393], Loss: 0.4046
# Epoch [15/50], Step [200/393], Loss: 0.4005
# Epoch [15/50], Step [210/393], Loss: 0.3296
# Epoch [15/50], Step [220/393], Loss: 0.4273
# Epoch [15/50], Step [230/393], Loss: 0.5498
# Epoch [15/50], Step [240/393], Loss: 0.4803
# Epoch [15/50], Step [250/393], Loss: 0.4993
# Epoch [15/50], Step [260/393], Loss: 0.5333
# Epoch [15/50], Step [270/393], Loss: 0.5116
# Epoch [15/50], Step [280/393], Loss: 0.4573
# Epoch [15/50], Step [290/393], Loss: 0.5318
# Epoch [15/50], Step [300/393], Loss: 0.6035
# Epoch [15/50], Step [310/393], Loss: 0.5867
# Epoch [15/50], Step [320/393], Loss: 0.5796
# Epoch [15/50], Step [330/393], Loss: 0.5577
# Epoch [15/50], Step [340/393], Loss: 0.5556
# Epoch [15/50], Step [350/393], Loss: 0.5743
# Epoch [15/50], Step [360/393], Loss: 0.3578
# Epoch [15/50], Step [370/393], Loss: 0.3082
# Epoch [15/50], Step [380/393], Loss: 0.4285
# Epoch [15/50], Step [390/393], Loss: 0.6400
# Epoch [15/50], Loss: 0.4737
# Epoch [15/50], Train Mean mIoU: 0.3115
# Epoch [15/50], Val Mean mIoU: 0.3045
# road: Val mIoU = 0.9167
# sidewalk: Val mIoU = 0.4982
# building: Val mIoU = 0.7698
# wall: Val mIoU = 0.0050
# fence: Val mIoU = 0.1397
# pole: Val mIoU = 0.0761
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0399
# vegetation: Val mIoU = 0.7901
# terrain: Val mIoU = 0.2944
# sky: Val mIoU = 0.8230
# person: Val mIoU = 0.4129
# rider: Val mIoU = 0.0002
# car: Val mIoU = 0.7362
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0007
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0430
# bicycle: Val mIoU = 0.2390
# Model saved with Mean mIoU: 0.3045
# Epoch [16/50], Step [10/393], Loss: 0.3641
# Epoch [16/50], Step [20/393], Loss: 0.3360
# Epoch [16/50], Step [30/393], Loss: 0.5115
# Epoch [16/50], Step [40/393], Loss: 0.6990
# Epoch [16/50], Step [50/393], Loss: 0.5165
# Epoch [16/50], Step [60/393], Loss: 0.5861
# Epoch [16/50], Step [70/393], Loss: 0.5497
# Epoch [16/50], Step [80/393], Loss: 0.6166
# Epoch [16/50], Step [90/393], Loss: 0.3642
# Epoch [16/50], Step [100/393], Loss: 0.5868
# Epoch [16/50], Step [110/393], Loss: 0.4203
# Epoch [16/50], Step [120/393], Loss: 0.3875
# Epoch [16/50], Step [130/393], Loss: 0.4420
# Epoch [16/50], Step [140/393], Loss: 0.3285
# Epoch [16/50], Step [150/393], Loss: 0.3181
# Epoch [16/50], Step [160/393], Loss: 0.4057
# Epoch [16/50], Step [170/393], Loss: 0.4055
# Epoch [16/50], Step [180/393], Loss: 0.4135
# Epoch [16/50], Step [190/393], Loss: 0.4585
# Epoch [16/50], Step [200/393], Loss: 0.5398
# Epoch [16/50], Step [210/393], Loss: 0.3672
# Epoch [16/50], Step [220/393], Loss: 0.4247
# Epoch [16/50], Step [230/393], Loss: 0.4137
# Epoch [16/50], Step [240/393], Loss: 0.4448
# Epoch [16/50], Step [250/393], Loss: 0.4150
# Epoch [16/50], Step [260/393], Loss: 0.4864
# Epoch [16/50], Step [270/393], Loss: 0.3075
# Epoch [16/50], Step [280/393], Loss: 0.5139
# Epoch [16/50], Step [290/393], Loss: 0.5396
# Epoch [16/50], Step [300/393], Loss: 0.6010
# Epoch [16/50], Step [310/393], Loss: 0.3468
# Epoch [16/50], Step [320/393], Loss: 0.4331
# Epoch [16/50], Step [330/393], Loss: 0.3753
# Epoch [16/50], Step [340/393], Loss: 0.3111
# Epoch [16/50], Step [350/393], Loss: 0.5026
# Epoch [16/50], Step [360/393], Loss: 0.4057
# Epoch [16/50], Step [370/393], Loss: 0.3970
# Epoch [16/50], Step [380/393], Loss: 0.4608
# Epoch [16/50], Step [390/393], Loss: 0.4407
# Epoch [16/50], Loss: 0.4676
# Epoch [16/50], Train Mean mIoU: 0.3192
# Epoch [16/50], Val Mean mIoU: 0.3070
# road: Val mIoU = 0.9179
# sidewalk: Val mIoU = 0.5093
# building: Val mIoU = 0.7690
# wall: Val mIoU = 0.0080
# fence: Val mIoU = 0.1364
# pole: Val mIoU = 0.0820
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0435
# vegetation: Val mIoU = 0.7956
# terrain: Val mIoU = 0.3083
# sky: Val mIoU = 0.8252
# person: Val mIoU = 0.4146
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7390
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0007
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0372
# bicycle: Val mIoU = 0.2472
# Model saved with Mean mIoU: 0.3070
# Epoch [17/50], Step [10/393], Loss: 0.8773
# Epoch [17/50], Step [20/393], Loss: 0.6660
# Epoch [17/50], Step [30/393], Loss: 0.4081
# Epoch [17/50], Step [40/393], Loss: 0.5000
# Epoch [17/50], Step [50/393], Loss: 0.5544
# Epoch [17/50], Step [60/393], Loss: 0.3627
# Epoch [17/50], Step [70/393], Loss: 0.5368
# Epoch [17/50], Step [80/393], Loss: 0.3514
# Epoch [17/50], Step [90/393], Loss: 0.3549
# Epoch [17/50], Step [100/393], Loss: 0.5360
# Epoch [17/50], Step [110/393], Loss: 0.3927
# Epoch [17/50], Step [120/393], Loss: 0.3466
# Epoch [17/50], Step [130/393], Loss: 0.3585
# Epoch [17/50], Step [140/393], Loss: 0.7833
# Epoch [17/50], Step [150/393], Loss: 0.3290
# Epoch [17/50], Step [160/393], Loss: 0.4709
# Epoch [17/50], Step [170/393], Loss: 0.3256
# Epoch [17/50], Step [180/393], Loss: 0.3763
# Epoch [17/50], Step [190/393], Loss: 0.4262
# Epoch [17/50], Step [200/393], Loss: 0.4565
# Epoch [17/50], Step [210/393], Loss: 0.3790
# Epoch [17/50], Step [220/393], Loss: 0.5340
# Epoch [17/50], Step [230/393], Loss: 0.4680
# Epoch [17/50], Step [240/393], Loss: 0.5115
# Epoch [17/50], Step [250/393], Loss: 0.3891
# Epoch [17/50], Step [260/393], Loss: 0.4470
# Epoch [17/50], Step [270/393], Loss: 0.3342
# Epoch [17/50], Step [280/393], Loss: 0.4914
# Epoch [17/50], Step [290/393], Loss: 0.3832
# Epoch [17/50], Step [300/393], Loss: 0.4349
# Epoch [17/50], Step [310/393], Loss: 0.4012
# Epoch [17/50], Step [320/393], Loss: 0.3026
# Epoch [17/50], Step [330/393], Loss: 0.5881
# Epoch [17/50], Step [340/393], Loss: 0.4189
# Epoch [17/50], Step [350/393], Loss: 0.3887
# Epoch [17/50], Step [360/393], Loss: 0.4262
# Epoch [17/50], Step [370/393], Loss: 0.3611
# Epoch [17/50], Step [380/393], Loss: 0.5610
# Epoch [17/50], Step [390/393], Loss: 0.4484
# Epoch [17/50], Loss: 0.4608
# Epoch [17/50], Train Mean mIoU: 0.3224
# Epoch [17/50], Val Mean mIoU: 0.3106
# road: Val mIoU = 0.9187
# sidewalk: Val mIoU = 0.5087
# building: Val mIoU = 0.7700
# wall: Val mIoU = 0.0149
# fence: Val mIoU = 0.1509
# pole: Val mIoU = 0.0754
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0445
# vegetation: Val mIoU = 0.7961
# terrain: Val mIoU = 0.3206
# sky: Val mIoU = 0.8261
# person: Val mIoU = 0.4148
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7455
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0009
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0523
# bicycle: Val mIoU = 0.2614
# Model saved with Mean mIoU: 0.3106
# Epoch [18/50], Step [10/393], Loss: 0.3912
# Epoch [18/50], Step [20/393], Loss: 0.4057
# Epoch [18/50], Step [30/393], Loss: 0.5104
# Epoch [18/50], Step [40/393], Loss: 0.5109
# Epoch [18/50], Step [50/393], Loss: 0.3184
# Epoch [18/50], Step [60/393], Loss: 0.4837
# Epoch [18/50], Step [70/393], Loss: 0.4087
# Epoch [18/50], Step [80/393], Loss: 0.5617
# Epoch [18/50], Step [90/393], Loss: 0.3083
# Epoch [18/50], Step [100/393], Loss: 0.3150
# Epoch [18/50], Step [110/393], Loss: 0.3899
# Epoch [18/50], Step [120/393], Loss: 0.4669
# Epoch [18/50], Step [130/393], Loss: 0.4648
# Epoch [18/50], Step [140/393], Loss: 0.3780
# Epoch [18/50], Step [150/393], Loss: 0.3808
# Epoch [18/50], Step [160/393], Loss: 0.4078
# Epoch [18/50], Step [170/393], Loss: 0.4664
# Epoch [18/50], Step [180/393], Loss: 0.5060
# Epoch [18/50], Step [190/393], Loss: 0.5213
# Epoch [18/50], Step [200/393], Loss: 0.4286
# Epoch [18/50], Step [210/393], Loss: 0.5337
# Epoch [18/50], Step [220/393], Loss: 0.3450
# Epoch [18/50], Step [230/393], Loss: 0.4788
# Epoch [18/50], Step [240/393], Loss: 0.3042
# Epoch [18/50], Step [250/393], Loss: 0.4250
# Epoch [18/50], Step [260/393], Loss: 0.4049
# Epoch [18/50], Step [270/393], Loss: 0.4810
# Epoch [18/50], Step [280/393], Loss: 0.5591
# Epoch [18/50], Step [290/393], Loss: 0.4529
# Epoch [18/50], Step [300/393], Loss: 0.3714
# Epoch [18/50], Step [310/393], Loss: 0.6270
# Epoch [18/50], Step [320/393], Loss: 0.4674
# Epoch [18/50], Step [330/393], Loss: 0.4458
# Epoch [18/50], Step [340/393], Loss: 0.4840
# Epoch [18/50], Step [350/393], Loss: 0.5022
# Epoch [18/50], Step [360/393], Loss: 0.4547
# Epoch [18/50], Step [370/393], Loss: 0.3651
# Epoch [18/50], Step [380/393], Loss: 0.3549
# Epoch [18/50], Step [390/393], Loss: 0.3122
# Epoch [18/50], Loss: 0.4544
# Epoch [18/50], Train Mean mIoU: 0.3236
# Epoch [18/50], Val Mean mIoU: 0.3111
# road: Val mIoU = 0.9199
# sidewalk: Val mIoU = 0.5122
# building: Val mIoU = 0.7706
# wall: Val mIoU = 0.0145
# fence: Val mIoU = 0.1588
# pole: Val mIoU = 0.0803
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0546
# vegetation: Val mIoU = 0.7987
# terrain: Val mIoU = 0.3005
# sky: Val mIoU = 0.8297
# person: Val mIoU = 0.4178
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7414
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0006
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0468
# bicycle: Val mIoU = 0.2644
# Model saved with Mean mIoU: 0.3111
# Epoch [19/50], Step [10/393], Loss: 0.4450
# Epoch [19/50], Step [20/393], Loss: 0.5672
# Epoch [19/50], Step [30/393], Loss: 0.3945
# Epoch [19/50], Step [40/393], Loss: 0.4056
# Epoch [19/50], Step [50/393], Loss: 0.4197
# Epoch [19/50], Step [60/393], Loss: 0.4369
# Epoch [19/50], Step [70/393], Loss: 0.3632
# Epoch [19/50], Step [80/393], Loss: 0.4286
# Epoch [19/50], Step [90/393], Loss: 0.3387
# Epoch [19/50], Step [100/393], Loss: 0.4160
# Epoch [19/50], Step [110/393], Loss: 0.4570
# Epoch [19/50], Step [120/393], Loss: 0.5279
# Epoch [19/50], Step [130/393], Loss: 0.4902
# Epoch [19/50], Step [140/393], Loss: 0.4706
# Epoch [19/50], Step [150/393], Loss: 0.3506
# Epoch [19/50], Step [160/393], Loss: 0.4318
# Epoch [19/50], Step [170/393], Loss: 0.3971
# Epoch [19/50], Step [180/393], Loss: 0.8916
# Epoch [19/50], Step [190/393], Loss: 0.5373
# Epoch [19/50], Step [200/393], Loss: 0.8479
# Epoch [19/50], Step [210/393], Loss: 0.4492
# Epoch [19/50], Step [220/393], Loss: 0.3659
# Epoch [19/50], Step [230/393], Loss: 0.5033
# Epoch [19/50], Step [240/393], Loss: 0.4570
# Epoch [19/50], Step [250/393], Loss: 0.3688
# Epoch [19/50], Step [260/393], Loss: 0.4439
# Epoch [19/50], Step [270/393], Loss: 0.6618
# Epoch [19/50], Step [280/393], Loss: 0.5598
# Epoch [19/50], Step [290/393], Loss: 0.5440
# Epoch [19/50], Step [300/393], Loss: 0.3403
# Epoch [19/50], Step [310/393], Loss: 0.4145
# Epoch [19/50], Step [320/393], Loss: 0.3862
# Epoch [19/50], Step [330/393], Loss: 0.4791
# Epoch [19/50], Step [340/393], Loss: 0.3402
# Epoch [19/50], Step [350/393], Loss: 0.5604
# Epoch [19/50], Step [360/393], Loss: 0.3644
# Epoch [19/50], Step [370/393], Loss: 0.5339
# Epoch [19/50], Step [380/393], Loss: 0.3569
# Epoch [19/50], Step [390/393], Loss: 0.4959
# Epoch [19/50], Loss: 0.4493
# Epoch [19/50], Train Mean mIoU: 0.3284
# Epoch [19/50], Val Mean mIoU: 0.3157
# road: Val mIoU = 0.9202
# sidewalk: Val mIoU = 0.5167
# building: Val mIoU = 0.7706
# wall: Val mIoU = 0.0164
# fence: Val mIoU = 0.1698
# pole: Val mIoU = 0.0884
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0603
# vegetation: Val mIoU = 0.7988
# terrain: Val mIoU = 0.3318
# sky: Val mIoU = 0.8282
# person: Val mIoU = 0.4175
# rider: Val mIoU = 0.0000
# car: Val mIoU = 0.7520
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0008
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0503
# bicycle: Val mIoU = 0.2761
# Model saved with Mean mIoU: 0.3157
# Epoch [20/50], Step [10/393], Loss: 0.7539
# Epoch [20/50], Step [20/393], Loss: 0.4493
# Epoch [20/50], Step [30/393], Loss: 0.5783
# Epoch [20/50], Step [40/393], Loss: 0.4739
# Epoch [20/50], Step [50/393], Loss: 0.4441
# Epoch [20/50], Step [60/393], Loss: 0.4056
# Epoch [20/50], Step [70/393], Loss: 0.4444
# Epoch [20/50], Step [80/393], Loss: 0.6386
# Epoch [20/50], Step [90/393], Loss: 0.3976
# Epoch [20/50], Step [100/393], Loss: 0.5099
# Epoch [20/50], Step [110/393], Loss: 0.3144
# Epoch [20/50], Step [120/393], Loss: 0.3760
# Epoch [20/50], Step [130/393], Loss: 0.4592
# Epoch [20/50], Step [140/393], Loss: 0.3719
# Epoch [20/50], Step [150/393], Loss: 0.4070
# Epoch [20/50], Step [160/393], Loss: 0.4049
# Epoch [20/50], Step [170/393], Loss: 0.3614
# Epoch [20/50], Step [180/393], Loss: 0.5217
# Epoch [20/50], Step [190/393], Loss: 0.5920
# Epoch [20/50], Step [200/393], Loss: 0.3618
# Epoch [20/50], Step [210/393], Loss: 0.4682
# Epoch [20/50], Step [220/393], Loss: 0.6425
# Epoch [20/50], Step [230/393], Loss: 0.3745
# Epoch [20/50], Step [240/393], Loss: 0.4335
# Epoch [20/50], Step [250/393], Loss: 0.5185
# Epoch [20/50], Step [260/393], Loss: 0.4445
# Epoch [20/50], Step [270/393], Loss: 0.3859
# Epoch [20/50], Step [280/393], Loss: 0.3593
# Epoch [20/50], Step [290/393], Loss: 0.6181
# Epoch [20/50], Step [300/393], Loss: 0.4360
# Epoch [20/50], Step [310/393], Loss: 0.3903
# Epoch [20/50], Step [320/393], Loss: 0.5580
# Epoch [20/50], Step [330/393], Loss: 0.5507
# Epoch [20/50], Step [340/393], Loss: 0.3512
# Epoch [20/50], Step [350/393], Loss: 0.3984
# Epoch [20/50], Step [360/393], Loss: 0.3437
# Epoch [20/50], Step [370/393], Loss: 0.3872
# Epoch [20/50], Step [380/393], Loss: 0.3479
# Epoch [20/50], Step [390/393], Loss: 0.3331
# Epoch [20/50], Loss: 0.4464
# Epoch [20/50], Train Mean mIoU: 0.3336
# Epoch [20/50], Val Mean mIoU: 0.3192
# road: Val mIoU = 0.9206
# sidewalk: Val mIoU = 0.5185
# building: Val mIoU = 0.7741
# wall: Val mIoU = 0.0133
# fence: Val mIoU = 0.1649
# pole: Val mIoU = 0.0951
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.0817
# vegetation: Val mIoU = 0.7996
# terrain: Val mIoU = 0.3283
# sky: Val mIoU = 0.8299
# person: Val mIoU = 0.4195
# rider: Val mIoU = 0.0002
# car: Val mIoU = 0.7526
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0007
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0704
# bicycle: Val mIoU = 0.2952
# Model saved with Mean mIoU: 0.3192
# Epoch [21/50], Step [10/393], Loss: 0.4434
# Epoch [21/50], Step [20/393], Loss: 0.4301
# Epoch [21/50], Step [30/393], Loss: 0.4634
# Epoch [21/50], Step [40/393], Loss: 0.5210
# Epoch [21/50], Step [50/393], Loss: 0.3161
# Epoch [21/50], Step [60/393], Loss: 0.3320
# Epoch [21/50], Step [70/393], Loss: 0.2984
# Epoch [21/50], Step [80/393], Loss: 0.5213
# Epoch [21/50], Step [90/393], Loss: 0.2852
# Epoch [21/50], Step [100/393], Loss: 0.3993
# Epoch [21/50], Step [110/393], Loss: 0.4317
# Epoch [21/50], Step [120/393], Loss: 0.4034
# Epoch [21/50], Step [130/393], Loss: 0.5121
# Epoch [21/50], Step [140/393], Loss: 0.4091
# Epoch [21/50], Step [150/393], Loss: 0.5556
# Epoch [21/50], Step [160/393], Loss: 0.5493
# Epoch [21/50], Step [170/393], Loss: 0.2765
# Epoch [21/50], Step [180/393], Loss: 0.3609
# Epoch [21/50], Step [190/393], Loss: 0.3955
# Epoch [21/50], Step [200/393], Loss: 0.3344
# Epoch [21/50], Step [210/393], Loss: 0.3106
# Epoch [21/50], Step [220/393], Loss: 0.3604
# Epoch [21/50], Step [230/393], Loss: 0.4545
# Epoch [21/50], Step [240/393], Loss: 0.4083
# Epoch [21/50], Step [250/393], Loss: 0.6050
# Epoch [21/50], Step [260/393], Loss: 0.5700
# Epoch [21/50], Step [270/393], Loss: 0.3494
# Epoch [21/50], Step [280/393], Loss: 0.3288
# Epoch [21/50], Step [290/393], Loss: 0.3772
# Epoch [21/50], Step [300/393], Loss: 0.5782
# Epoch [21/50], Step [310/393], Loss: 0.5132
# Epoch [21/50], Step [320/393], Loss: 0.4490
# Epoch [21/50], Step [330/393], Loss: 0.3485
# ...
# Epoch [44/50], Step [80/393], Loss: 0.4210
# Epoch [44/50], Step [90/393], Loss: 0.4194
# Epoch [44/50], Step [100/393], Loss: 0.5099
# Epoch [44/50], Step [110/393], Loss: 0.3544
# Epoch [44/50], Step [120/393], Loss: 0.4066
# Epoch [44/50], Step [130/393], Loss: 0.3505
# Epoch [44/50], Step [140/393], Loss: 0.4223
# Epoch [44/50], Step [150/393], Loss: 0.3654
# Epoch [44/50], Step [160/393], Loss: 0.4495
# Epoch [44/50], Step [170/393], Loss: 0.4792
# Epoch [44/50], Step [180/393], Loss: 0.2870
# Epoch [44/50], Step [190/393], Loss: 0.2787
# Epoch [44/50], Step [200/393], Loss: 0.4859
# Epoch [44/50], Step [210/393], Loss: 0.3196
# Epoch [44/50], Step [220/393], Loss: 0.3371
# Epoch [44/50], Step [230/393], Loss: 0.3048
# Epoch [44/50], Step [240/393], Loss: 0.4880
# Epoch [44/50], Step [250/393], Loss: 0.2788
# Epoch [44/50], Step [260/393], Loss: 0.3660
# Epoch [44/50], Step [270/393], Loss: 0.4019
# Epoch [44/50], Step [280/393], Loss: 0.3913
# Epoch [44/50], Step [290/393], Loss: 0.4022
# Epoch [44/50], Step [300/393], Loss: 0.3542
# Epoch [44/50], Step [310/393], Loss: 0.3573
# Epoch [44/50], Step [320/393], Loss: 0.4006
# Epoch [44/50], Step [330/393], Loss: 0.2691
# Epoch [44/50], Step [340/393], Loss: 0.6865
# Epoch [44/50], Step [350/393], Loss: 0.5161
# Epoch [44/50], Step [360/393], Loss: 0.4766
# Epoch [44/50], Step [370/393], Loss: 0.5561
# Epoch [44/50], Step [380/393], Loss: 0.5566
# Epoch [44/50], Step [390/393], Loss: 0.3405
# Epoch [44/50], Loss: 0.3884
# Epoch [44/50], Train Mean mIoU: 0.3711
# Epoch [44/50], Val Mean mIoU: 0.3434
# road: Val mIoU = 0.9272
# sidewalk: Val mIoU = 0.5500
# building: Val mIoU = 0.7884
# wall: Val mIoU = 0.0389
# fence: Val mIoU = 0.2198
# pole: Val mIoU = 0.1195
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1541
# vegetation: Val mIoU = 0.8096
# terrain: Val mIoU = 0.3743
# sky: Val mIoU = 0.8395
# person: Val mIoU = 0.4437
# rider: Val mIoU = 0.0009
# car: Val mIoU = 0.7706
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0011
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.1024
# bicycle: Val mIoU = 0.3840
# Model saved with Mean mIoU: 0.3434
# Epoch [45/50], Step [10/393], Loss: 0.3359
# Epoch [45/50], Step [20/393], Loss: 0.3422
# Epoch [45/50], Step [30/393], Loss: 0.2822
# Epoch [45/50], Step [40/393], Loss: 0.3928
# Epoch [45/50], Step [50/393], Loss: 0.3202
# Epoch [45/50], Step [60/393], Loss: 0.6182
# Epoch [45/50], Step [70/393], Loss: 0.2978
# Epoch [45/50], Step [80/393], Loss: 0.2560
# Epoch [45/50], Step [90/393], Loss: 0.3266
# Epoch [45/50], Step [100/393], Loss: 0.5488
# Epoch [45/50], Step [110/393], Loss: 0.3598
# Epoch [45/50], Step [120/393], Loss: 0.4609
# Epoch [45/50], Step [130/393], Loss: 0.3250
# Epoch [45/50], Step [140/393], Loss: 0.3371
# Epoch [45/50], Step [150/393], Loss: 0.4484
# Epoch [45/50], Step [160/393], Loss: 0.3112
# Epoch [45/50], Step [170/393], Loss: 0.3101
# Epoch [45/50], Step [180/393], Loss: 0.4508
# Epoch [45/50], Step [190/393], Loss: 0.6831
# Epoch [45/50], Step [200/393], Loss: 0.3475
# Epoch [45/50], Step [210/393], Loss: 0.2885
# Epoch [45/50], Step [220/393], Loss: 0.3640
# Epoch [45/50], Step [230/393], Loss: 0.3979
# Epoch [45/50], Step [240/393], Loss: 0.4826
# Epoch [45/50], Step [250/393], Loss: 0.3552
# Epoch [45/50], Step [260/393], Loss: 0.4272
# Epoch [45/50], Step [270/393], Loss: 0.4256
# Epoch [45/50], Step [280/393], Loss: 0.2642
# Epoch [45/50], Step [290/393], Loss: 0.2419
# Epoch [45/50], Step [300/393], Loss: 0.3623
# Epoch [45/50], Step [310/393], Loss: 0.4214
# Epoch [45/50], Step [320/393], Loss: 0.4160
# Epoch [45/50], Step [330/393], Loss: 0.6120
# Epoch [45/50], Step [340/393], Loss: 0.3099
# Epoch [45/50], Step [350/393], Loss: 0.3981
# Epoch [45/50], Step [360/393], Loss: 0.4020
# Epoch [45/50], Step [370/393], Loss: 0.3312
# Epoch [45/50], Step [380/393], Loss: 0.3245
# Epoch [45/50], Step [390/393], Loss: 0.3593
# Epoch [45/50], Loss: 0.3867
# Epoch [45/50], Train Mean mIoU: 0.3721
# Epoch [45/50], Val Mean mIoU: 0.3446
# road: Val mIoU = 0.9276
# sidewalk: Val mIoU = 0.5509
# building: Val mIoU = 0.7889
# wall: Val mIoU = 0.0502
# fence: Val mIoU = 0.2341
# pole: Val mIoU = 0.1163
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1509
# vegetation: Val mIoU = 0.8115
# terrain: Val mIoU = 0.3644
# sky: Val mIoU = 0.8419
# person: Val mIoU = 0.4442
# rider: Val mIoU = 0.0013
# car: Val mIoU = 0.7730
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0017
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.1030
# bicycle: Val mIoU = 0.3867
# Model saved with Mean mIoU: 0.3446
# Epoch [46/50], Step [10/393], Loss: 0.4163
# Epoch [46/50], Step [20/393], Loss: 0.3614
# Epoch [46/50], Step [30/393], Loss: 0.5881
# Epoch [46/50], Step [40/393], Loss: 0.2778
# Epoch [46/50], Step [50/393], Loss: 0.6326
# Epoch [46/50], Step [60/393], Loss: 0.2901
# Epoch [46/50], Step [70/393], Loss: 0.3457
# Epoch [46/50], Step [80/393], Loss: 0.4056
# Epoch [46/50], Step [90/393], Loss: 0.4892
# Epoch [46/50], Step [100/393], Loss: 0.3298
# Epoch [46/50], Step [110/393], Loss: 0.3733
# Epoch [46/50], Step [120/393], Loss: 0.2993
# Epoch [46/50], Step [130/393], Loss: 0.3880
# Epoch [46/50], Step [140/393], Loss: 0.3213
# Epoch [46/50], Step [150/393], Loss: 0.3906
# Epoch [46/50], Step [160/393], Loss: 0.2487
# Epoch [46/50], Step [170/393], Loss: 0.4230
# Epoch [46/50], Step [180/393], Loss: 0.3197
# Epoch [46/50], Step [190/393], Loss: 0.2998
# Epoch [46/50], Step [200/393], Loss: 0.7063
# Epoch [46/50], Step [210/393], Loss: 0.5834
# Epoch [46/50], Step [220/393], Loss: 0.3691
# Epoch [46/50], Step [230/393], Loss: 0.3528
# Epoch [46/50], Step [240/393], Loss: 0.3796
# Epoch [46/50], Step [250/393], Loss: 0.3423
# Epoch [46/50], Step [260/393], Loss: 0.4759
# Epoch [46/50], Step [270/393], Loss: 0.3140
# Epoch [46/50], Step [280/393], Loss: 0.3250
# Epoch [46/50], Step [290/393], Loss: 0.2494
# Epoch [46/50], Step [300/393], Loss: 0.7738
# Epoch [46/50], Step [310/393], Loss: 0.5601
# Epoch [46/50], Step [320/393], Loss: 0.3488
# Epoch [46/50], Step [330/393], Loss: 0.2722
# Epoch [46/50], Step [340/393], Loss: 0.3605
# Epoch [46/50], Step [350/393], Loss: 0.3434
# Epoch [46/50], Step [360/393], Loss: 0.4980
# Epoch [46/50], Step [370/393], Loss: 0.4113
# Epoch [46/50], Step [380/393], Loss: 0.3095
# Epoch [46/50], Step [390/393], Loss: 0.3832
# Epoch [46/50], Loss: 0.3878
# Epoch [46/50], Train Mean mIoU: 0.3711
# Epoch [46/50], Val Mean mIoU: 0.3420
# road: Val mIoU = 0.9277
# sidewalk: Val mIoU = 0.5512
# building: Val mIoU = 0.7878
# wall: Val mIoU = 0.0619
# fence: Val mIoU = 0.2249
# pole: Val mIoU = 0.1054
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1542
# vegetation: Val mIoU = 0.8125
# terrain: Val mIoU = 0.3451
# sky: Val mIoU = 0.8412
# person: Val mIoU = 0.4429
# rider: Val mIoU = 0.0007
# car: Val mIoU = 0.7649
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0010
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0881
# bicycle: Val mIoU = 0.3877
# Epoch [47/50], Step [10/393], Loss: 0.5924
# Epoch [47/50], Step [20/393], Loss: 0.3264
# Epoch [47/50], Step [30/393], Loss: 0.3104
# Epoch [47/50], Step [40/393], Loss: 0.4090
# Epoch [47/50], Step [50/393], Loss: 0.3382
# Epoch [47/50], Step [60/393], Loss: 0.4356
# Epoch [47/50], Step [70/393], Loss: 0.4432
# Epoch [47/50], Step [80/393], Loss: 0.8442
# Epoch [47/50], Step [90/393], Loss: 0.2596
# Epoch [47/50], Step [100/393], Loss: 0.4617
# Epoch [47/50], Step [110/393], Loss: 0.3491
# Epoch [47/50], Step [120/393], Loss: 0.3750
# Epoch [47/50], Step [130/393], Loss: 0.3441
# Epoch [47/50], Step [140/393], Loss: 0.3700
# Epoch [47/50], Step [150/393], Loss: 0.4226
# Epoch [47/50], Step [160/393], Loss: 0.5660
# Epoch [47/50], Step [170/393], Loss: 0.3577
# Epoch [47/50], Step [180/393], Loss: 0.4695
# Epoch [47/50], Step [190/393], Loss: 0.4115
# Epoch [47/50], Step [200/393], Loss: 0.3238
# Epoch [47/50], Step [210/393], Loss: 0.2751
# Epoch [47/50], Step [220/393], Loss: 0.3839
# Epoch [47/50], Step [230/393], Loss: 0.3366
# Epoch [47/50], Step [240/393], Loss: 0.4640
# Epoch [47/50], Step [250/393], Loss: 0.4390
# Epoch [47/50], Step [260/393], Loss: 0.4445
# Epoch [47/50], Step [270/393], Loss: 0.3620
# Epoch [47/50], Step [280/393], Loss: 0.3742
# Epoch [47/50], Step [290/393], Loss: 0.4236
# Epoch [47/50], Step [300/393], Loss: 0.5887
# Epoch [47/50], Step [310/393], Loss: 0.4273
# Epoch [47/50], Step [320/393], Loss: 0.3286
# Epoch [47/50], Step [330/393], Loss: 0.3860
# Epoch [47/50], Step [340/393], Loss: 0.3313
# Epoch [47/50], Step [350/393], Loss: 0.3078
# Epoch [47/50], Step [360/393], Loss: 0.3579
# Epoch [47/50], Step [370/393], Loss: 0.3402
# Epoch [47/50], Step [380/393], Loss: 0.4647
# Epoch [47/50], Step [390/393], Loss: 0.3434
# Epoch [47/50], Loss: 0.3888
# Epoch [47/50], Train Mean mIoU: 0.3711
# Epoch [47/50], Val Mean mIoU: 0.3422
# road: Val mIoU = 0.9278
# sidewalk: Val mIoU = 0.5492
# building: Val mIoU = 0.7907
# wall: Val mIoU = 0.0606
# fence: Val mIoU = 0.2390
# pole: Val mIoU = 0.1027
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1518
# vegetation: Val mIoU = 0.8066
# terrain: Val mIoU = 0.3624
# sky: Val mIoU = 0.8411
# person: Val mIoU = 0.4404
# rider: Val mIoU = 0.0018
# car: Val mIoU = 0.7663
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0009
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0851
# bicycle: Val mIoU = 0.3750
# Epoch [48/50], Step [10/393], Loss: 0.5002
# Epoch [48/50], Step [20/393], Loss: 0.4338
# Epoch [48/50], Step [30/393], Loss: 0.3566
# Epoch [48/50], Step [40/393], Loss: 0.4011
# Epoch [48/50], Step [50/393], Loss: 0.4233
# Epoch [48/50], Step [60/393], Loss: 0.3496
# Epoch [48/50], Step [70/393], Loss: 0.5117
# Epoch [48/50], Step [80/393], Loss: 0.6337
# Epoch [48/50], Step [90/393], Loss: 0.3071
# Epoch [48/50], Step [100/393], Loss: 0.4617
# Epoch [48/50], Step [110/393], Loss: 0.4015
# Epoch [48/50], Step [120/393], Loss: 0.3383
# Epoch [48/50], Step [130/393], Loss: 0.4964
# Epoch [48/50], Step [140/393], Loss: 0.3586
# Epoch [48/50], Step [150/393], Loss: 0.4236
# Epoch [48/50], Step [160/393], Loss: 0.3776
# Epoch [48/50], Step [170/393], Loss: 0.3062
# Epoch [48/50], Step [180/393], Loss: 0.4633
# Epoch [48/50], Step [190/393], Loss: 0.3551
# Epoch [48/50], Step [200/393], Loss: 0.3228
# Epoch [48/50], Step [210/393], Loss: 0.4397
# Epoch [48/50], Step [220/393], Loss: 0.2808
# Epoch [48/50], Step [230/393], Loss: 0.3695
# Epoch [48/50], Step [240/393], Loss: 0.3511
# Epoch [48/50], Step [250/393], Loss: 0.4304
# Epoch [48/50], Step [260/393], Loss: 0.2790
# Epoch [48/50], Step [270/393], Loss: 0.3803
# Epoch [48/50], Step [280/393], Loss: 0.4621
# Epoch [48/50], Step [290/393], Loss: 0.3591
# Epoch [48/50], Step [300/393], Loss: 0.3488
# Epoch [48/50], Step [310/393], Loss: 0.4079
# Epoch [48/50], Step [320/393], Loss: 0.2955
# Epoch [48/50], Step [330/393], Loss: 0.3707
# Epoch [48/50], Step [340/393], Loss: 0.3736
# Epoch [48/50], Step [350/393], Loss: 0.4132
# Epoch [48/50], Step [360/393], Loss: 0.4276
# Epoch [48/50], Step [370/393], Loss: 0.5909
# Epoch [48/50], Step [380/393], Loss: 0.3452
# Epoch [48/50], Step [390/393], Loss: 0.3754
# Epoch [48/50], Loss: 0.3897
# Epoch [48/50], Train Mean mIoU: 0.3705
# Epoch [48/50], Val Mean mIoU: 0.3431
# road: Val mIoU = 0.9280
# sidewalk: Val mIoU = 0.5498
# building: Val mIoU = 0.7905
# wall: Val mIoU = 0.0548
# fence: Val mIoU = 0.2351
# pole: Val mIoU = 0.1098
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1575
# vegetation: Val mIoU = 0.8101
# terrain: Val mIoU = 0.3588
# sky: Val mIoU = 0.8379
# person: Val mIoU = 0.4451
# rider: Val mIoU = 0.0013
# car: Val mIoU = 0.7675
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0012
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0911
# bicycle: Val mIoU = 0.3805
# Epoch [49/50], Step [10/393], Loss: 0.3000
# Epoch [49/50], Step [20/393], Loss: 0.4223
# Epoch [49/50], Step [30/393], Loss: 0.2940
# Epoch [49/50], Step [40/393], Loss: 0.3879
# Epoch [49/50], Step [50/393], Loss: 0.4012
# Epoch [49/50], Step [60/393], Loss: 0.2561
# Epoch [49/50], Step [70/393], Loss: 0.5892
# Epoch [49/50], Step [80/393], Loss: 0.4027
# Epoch [49/50], Step [90/393], Loss: 0.3951
# Epoch [49/50], Step [100/393], Loss: 0.3749
# Epoch [49/50], Step [110/393], Loss: 0.3884
# Epoch [49/50], Step [120/393], Loss: 0.3501
# Epoch [49/50], Step [130/393], Loss: 0.2959
# Epoch [49/50], Step [140/393], Loss: 0.4060
# Epoch [49/50], Step [150/393], Loss: 0.3189
# Epoch [49/50], Step [160/393], Loss: 0.2868
# Epoch [49/50], Step [170/393], Loss: 0.3413
# Epoch [49/50], Step [180/393], Loss: 0.3773
# Epoch [49/50], Step [190/393], Loss: 0.4265
# Epoch [49/50], Step [200/393], Loss: 0.2967
# Epoch [49/50], Step [210/393], Loss: 0.5927
# Epoch [49/50], Step [220/393], Loss: 0.3931
# Epoch [49/50], Step [230/393], Loss: 0.4055
# Epoch [49/50], Step [240/393], Loss: 0.4043
# Epoch [49/50], Step [250/393], Loss: 0.3883
# Epoch [49/50], Step [260/393], Loss: 0.2643
# Epoch [49/50], Step [270/393], Loss: 0.2842
# Epoch [49/50], Step [280/393], Loss: 0.3804
# Epoch [49/50], Step [290/393], Loss: 0.3893
# Epoch [49/50], Step [300/393], Loss: 0.5130
# Epoch [49/50], Step [310/393], Loss: 0.4436
# Epoch [49/50], Step [320/393], Loss: 0.3934
# Epoch [49/50], Step [330/393], Loss: 0.2354
# Epoch [49/50], Step [340/393], Loss: 0.3865
# Epoch [49/50], Step [350/393], Loss: 0.4855
# Epoch [49/50], Step [360/393], Loss: 0.4696
# Epoch [49/50], Step [370/393], Loss: 0.3552
# Epoch [49/50], Step [380/393], Loss: 0.4372
# Epoch [49/50], Step [390/393], Loss: 0.4778
# Epoch [49/50], Loss: 0.3874
# Epoch [49/50], Train Mean mIoU: 0.3695
# Epoch [49/50], Val Mean mIoU: 0.3423
# road: Val mIoU = 0.9273
# sidewalk: Val mIoU = 0.5470
# building: Val mIoU = 0.7907
# wall: Val mIoU = 0.0544
# fence: Val mIoU = 0.2403
# pole: Val mIoU = 0.1053
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1448
# vegetation: Val mIoU = 0.8022
# terrain: Val mIoU = 0.3683
# sky: Val mIoU = 0.8400
# person: Val mIoU = 0.4449
# rider: Val mIoU = 0.0019
# car: Val mIoU = 0.7680
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0007
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.0873
# bicycle: Val mIoU = 0.3816
# Epoch [50/50], Step [10/393], Loss: 0.4833
# Epoch [50/50], Step [20/393], Loss: 0.3408
# Epoch [50/50], Step [30/393], Loss: 0.3222
# Epoch [50/50], Step [40/393], Loss: 0.3716
# Epoch [50/50], Step [50/393], Loss: 0.7421
# Epoch [50/50], Step [60/393], Loss: 0.2503
# Epoch [50/50], Step [70/393], Loss: 0.5072
# Epoch [50/50], Step [80/393], Loss: 0.3209
# Epoch [50/50], Step [90/393], Loss: 0.3500
# Epoch [50/50], Step [100/393], Loss: 0.4240
# Epoch [50/50], Step [110/393], Loss: 0.4539
# Epoch [50/50], Step [120/393], Loss: 0.4505
# Epoch [50/50], Step [130/393], Loss: 0.5911
# Epoch [50/50], Step [140/393], Loss: 0.3665
# Epoch [50/50], Step [150/393], Loss: 0.4477
# Epoch [50/50], Step [160/393], Loss: 0.2976
# Epoch [50/50], Step [170/393], Loss: 0.2892
# Epoch [50/50], Step [180/393], Loss: 0.4448
# Epoch [50/50], Step [190/393], Loss: 0.4153
# Epoch [50/50], Step [200/393], Loss: 0.5723
# Epoch [50/50], Step [210/393], Loss: 0.2233
# Epoch [50/50], Step [220/393], Loss: 0.3734
# Epoch [50/50], Step [230/393], Loss: 0.3678
# Epoch [50/50], Step [240/393], Loss: 0.4974
# Epoch [50/50], Step [250/393], Loss: 0.3372
# Epoch [50/50], Step [260/393], Loss: 0.3659
# Epoch [50/50], Step [270/393], Loss: 0.4303
# Epoch [50/50], Step [280/393], Loss: 0.2792
# Epoch [50/50], Step [290/393], Loss: 0.3244
# Epoch [50/50], Step [300/393], Loss: 0.5958
# Epoch [50/50], Step [310/393], Loss: 0.3166
# Epoch [50/50], Step [320/393], Loss: 0.3541
# Epoch [50/50], Step [330/393], Loss: 0.3636
# Epoch [50/50], Step [340/393], Loss: 0.3244
# Epoch [50/50], Step [350/393], Loss: 0.5437
# Epoch [50/50], Step [360/393], Loss: 0.5281
# Epoch [50/50], Step [370/393], Loss: 0.3568
# Epoch [50/50], Step [380/393], Loss: 0.5482
# Epoch [50/50], Step [390/393], Loss: 0.2866
# Epoch [50/50], Loss: 0.3879
# Epoch [50/50], Train Mean mIoU: 0.3714
# Epoch [50/50], Val Mean mIoU: 0.3462
# road: Val mIoU = 0.9275
# sidewalk: Val mIoU = 0.5509
# building: Val mIoU = 0.7913
# wall: Val mIoU = 0.0523
# fence: Val mIoU = 0.2342
# pole: Val mIoU = 0.1198
# traffic light: Val mIoU = 0.0000
# traffic sign: Val mIoU = 0.1704
# vegetation: Val mIoU = 0.8107
# terrain: Val mIoU = 0.3622
# sky: Val mIoU = 0.8383
# person: Val mIoU = 0.4473
# rider: Val mIoU = 0.0011
# car: Val mIoU = 0.7691
# truck: Val mIoU = 0.0000
# bus: Val mIoU = 0.0013
# train: Val mIoU = 0.0000
# motorcycle: Val mIoU = 0.1013
# bicycle: Val mIoU = 0.3998
# Model saved with Mean mIoU: 0.3462

# %%
epochs = range(1, num_epochs + 1)
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
plt.plot(epochs, train_losses, 'b-', label='Training Loss')
plt.plot(epochs, val_losses, 'g-', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(epochs, train_mIoUs, 'b-', label='Training mIoU')
plt.plot(epochs, val_mIoUs, 'r-', label='Validation mIoU')
plt.xlabel('Epoch')
plt.ylabel('mIoU')
plt.title('Training and Validation mIoU')
plt.legend()

plt.show()
